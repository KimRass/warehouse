# %%
import pandas as pd
import urllib
import json
import datetime
from tqdm.notebook import tqdm
import traceback
import psycopg2
from psycopg2.extras import RealDictCursor
import pymssql
from dateutil.relativedelta import relativedelta
import pickle as pk

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 구글 애널리틱스
# - https://ga-dev-tools.appspot.com/query-explorer/
#
# ### MAU
# - metrics: "ga:users", "ga:pageviews"
# - dimentions: "ga:yearMonth"

# %%
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2021, 7, 31)
token = "ya29.a0ARrdaM8NE8YPegZVgbU81SfaeY3ih5yx2WpxAbTlTPSXT9fA_HKe6-0o-Pk6XmrhTPTDQVIb5WiXd1kS8FXGYvZ077BTJCleaiND8GNyR9znl685xFLlPaDvfkcA96GOK-Z4LmbO1d-MS-J8aSESqk7YRRxVRNw"

# %%
url = f"https://www.googleapis.com/analytics/v3/data/ga?ids=ga%3A206525354&start-date={start.strftime('%Y-%m-%d')}&end-date={end.strftime('%Y-%m-%d')}&metrics=ga%3Ausers%2Cga%3Apageviews&dimensions=ga%3AyearMonth&access_token={token}"
req = urllib.request.urlopen(url).read().decode("utf8")
js = json.loads(req)

mau = pd.DataFrame(js["rows"], columns=pd.DataFrame(js["columnHeaders"])["name"].str.split(":").str[1].tolist())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-11896b59dfca> in <module>
#       1 url = f"https://www.googleapis.com/analytics/v3/data/ga?ids=ga:206525354&dimensions=ga:yearMonth&metrics=ga:users,ga:pageviews&start-date=2017-01-01&end-date=yesterday"
# ----> 2 req = urllib.request.urlopen(url).read().decode("utf8")
#       3 js = json.loads(req)
#       4
#       5 mau = pd.DataFrame(js["rows"], columns=pd.DataFrame(js["columnHeaders"])["name"].str.split(":").str[1].tolist())
#
# ~\Anaconda3\envs\tf2.3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\envs\tf2.3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\envs\tf2.3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\envs\tf2.3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\envs\tf2.3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\envs\tf2.3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 401: Unauthorized

# %%
# mau.to_csv(f"D:/디지털혁신팀/태블로/마이호미/마이호미_FINAL/mau_{end.strftime('%Y-%m-%d')}.csv", encoding="euc-kr", index=False)
# mau.tail()

# %% [markdown]
# ## mall.csv

# %%
f = open("D:/Github/Work/Tableau/mall_password.txt", "r")
password = f.readline()
conn = pymssql.connect(server="125.60.68.233", database="eiparkclub", user="myhomie", password=password, charset="utf8")
cur = conn.cursor()
query = """
SELECT
    주문번호 AS order_id,
    임직원아이디 AS mbr_id,
    CAST(_상품ID AS VARCHAR(6)) AS prod_id,
    상품명 AS prod_name,
    수량 AS qnt,
    상품금액 AS sales,
    주문일자 AS order_date,
    _모바일주문여부 AS mob_yn
FROM
    vwAdjustDetail;
"""
mall = pd.read_sql(query, conn)

# %%
mall.to_csv(f"D:/Github/Work/Tableau/Myhomie/mall_{end.strftime('%Y-%m-%d')}.csv", encoding="euc-kr", index=False)
# data.head()

# %% [markdown]
# # 다운로드(iOS)

# %%
# with open("D:/AuthKey_BB99VD4S7X.p8", "r") as f:
#     key_file = f.read()
# api = Api(key_id="BB99VD4S7X", key_file=key_file, issuer_id="252fd97c-ea6e-45b9-a795-693f38f8dbaf")
# api.download_sales_and_trends_reports(filters={"frequency": "DAILY", "reportSubType":"DETAILED", "reportType":"SALES", "vendorNumber": "88755846"})
# # , save_to="report.csv")

# %%
# views = pd.DataFrame()
# for i in tqdm(range(100)):
#     try:
#         start = end - datetime.timedelta(days=10*(i+1))
#         end = end - datetime.timedelta(days=10*i)
#         url = f"https://www.googleapis.com/analytics/v3/data/ga?ids=ga%3A206525354&start-date={start.strftime('%Y-%m-%d')}&end-date={end.strftime('%Y-%m-%d')}&metrics=ga%3Ausers%2Cga%3Apageviews&dimensions=ga%3ApageTitle%2Cga%3Adate&sort=-ga%3Adate&access_token={token}"
#         req = urllib.request.urlopen(url).read().decode("utf8")
#         js = json.loads(req)
        
#         df = pd.DataFrame(js["rows"], columns=pd.DataFrame(js["columnHeaders"])["name"].str.split(":").str[1].tolist())
#         views = pd.concat([views, df])
#     except:
#         break

# %% [markdown]
# ## 개발사 데이터
#
# ## sys_code

# %%
# with open("D:/디지털혁신팀/태블로/signup_password.pkl", "rb") as f:
#      password = pk.load(f)
# conn = psycopg2.connect(host="postgresql-production1.cluster-ro-cxb5zwyq1mu5.ap-northeast-2.rds.amazonaws.com", dbname="hdc", user="postgres", password=password)
# cur = conn.cursor(cursor_factory=RealDictCursor)
# query = f"SELECT * FROM hdc_sys.sys_code;"
# cur.execute(query)
# result = cur.fetchall()

# sys_code = pd.DataFrame(result)

# %%
# sys_code.head()

# %% [markdown]
# ## apt_mst.csv

# %%
f = open("D:/Github/Work/Tableau/signup_password.txt", "r")
password = f.readline()
conn = psycopg2.connect(host="postgresql-production1.cluster-ro-cxb5zwyq1mu5.ap-northeast-2.rds.amazonaws.com", dbname="hdc", user="postgres", password=password)
cur = conn.cursor(cursor_factory=RealDictCursor)
query = """
SELECT
    *
FROM
    hdc_apt.apt_mst;
"""
apt_mst = pd.read_sql(query, conn)
# Out:
# dtRW2aj14KYl7aQl8oZd

# %%
apt_mst
# Out:
#            apt_id            apt_name apt_zipcode  \
# 0   APT0000001681          잠실 HDC 아파트
# 1   APT0000092369        별내역 아이파크 스위트       12113
# 2   APT0000007902         목동센트럴아이파크위브       08066
# 3   APT0000006347       청주가경 아이파크 2단지
# 4   APT0000070522            동남 힐데스하임
# 5   APT0000007914           HDC현대산업개발
# 6   APT0000002590        동탄 호수공원 아이파크       18506
# 7   APT0000000000             모두의 아파트           1
# 8   APT0000007926        목동센트럴아이파크위브3
# 9   APT0000018255  목동 센트럴 아이파크 위브 4단지
# 10  APT0000079481        캐슬앤파밀리에시티1단지
# 11  APT0000084660            꿈의숲 아이파크
# 12  APT0000055389          운정신도시 아이파크
# 13  APT0000076863          알 수 없는 아파트       10136
# 14  APT0000114912           테스트용 아이파크
# 15  APT0000115038            포항항 아이파크
# 16  APT0000109911       청주가경 아이파크 3단지
# 17  APT0000094182         병점역 아이파크 캐슬       18367
# 18  APT0000102074          대구 복현 아이파크
# 19  APT0000089360           일산2차 아이파크
# 20  APT0000043153           산성역 포레스티아       13260
# 21  APT0000000921       잠실 올림픽공원 아이파크
# 22  APT0000115086             포항 아이파크
# 23  APT0000114909            포항항 아이파크
# 24  APT0000115620      대전 아이파크 시티 1단지       34202
# 25  APT0000115049              테스트입니다
#
#                                           apt_address apt_address_detail  \
# 0   서울시 송파구 234길 ,서울시 송파구 234길 ,서울시 송파구 234길 ,서울시 ...               None
# 1                          경기도 남양주시 별내중앙로 10                        None
# 2               신월동 551번지 일대                                        None
# 3                         충청북도 청주시 가경동 323                          None
# 4                   충청북도 청주시 상당구 용암동 2944-103                       None
# 5                             서울특별시 용산구 한강대로23길 55                  None
# 6                              경기도 화성시 장지동 산120-58                  None
# 7                                                   1                  1
# 8                            신월동 55번지일대                             None
# 9                              충청북도 청주시 흥덕구 서현로 62                  None
# 10                            고촌읍 인향로 92-111                        None
# 11                              서울시 성북구 장위동 189-3                   None
# 12          경기도 파주시 교하읍 동패동 파주운정택지개발지구 내 A26블록                      None
# 13                      고촌읍 태리 김포신곡6지구 도시개발사업구역 A1블록                None
# 14                경북 포항시 남구 오천읍 용산리 360-13                          None
# 15                       경북 포항시 남구 오천읍 용산리 360-13                   None
# 16                        충청북도 청주시 흥덕구 서현로 62                       None
# 17                              경기도 화성시 병점노을로 31 일원                 None
# 18                             대구 북구 복현동 201-3                      None
# 19                            일산동구 중산로 60                           None
# 20            경기도 성남시 수정구 수정로 319                                   None
# 21  풍납동 288-7, 389 2필지 ,풍납동 288-7, 389 2필지 ,풍납동 28...               None
# 22                         경북 포항시 남구 오천읍 용산리 360-13                 None
# 23                           경북 포항시 남구 오천읍 용산리 360-13
# 24                 대전광역시 유성구 복용동로79번길 30 아이파크 시티 1단지                None
# 25
#
#    apt_admin_url apt_homepage_url apt_household_number apt_inhabitant_status  \
# 0           None             None                  697            C000014001
# 1           None             None                 1100            C000014001
# 2           None             None                 3045            C000014001
# 3           None             None                  664            C000014001
# 4           None             None                  910            C000014001
# 5           None             None                 3045            C000014001
# 6           None             None                  774            C000014001
# 7              1                1                    1                    선택
# 8           None             None                 3045            C000014001
# 9           None             None                  983            C000014001
# 10          None             None                 2255            C000014001
# 11          None             None                 1711            C000014001
# 12          None             None                 3042            C000014001
# 13          None             None                 2255            C000014001
# 14          None             None                 1144            C000014001
# 15          None             None                 1144            C000014001
# 16          None             None                  983            C000014001
# 17          None             None                 2666            C000014001
# 18          None             None                  585            C000014001
# 19          None             None                  214            C000014001
# 20          None             None                 4089            C000014001
# 21          None             None                  697            C000014001
# 22          None             None                 1144            C000014001
# 23          None             None                 1144            C000014001
# 24          None             None                 1254            C000014001
# 25          None             None                                 C000014001
#
#    apt_inhabitant_dt apt_addr_code  apt_payment_due_date apt_service_stop_yn  \
# 0         2019-10-01    C015001001                     3                   S
# 1         2021-02-28    C015002007                     1                   N
# 2         2020-03-31    C015001003                     3                   N
# 3         2020-02-20    C005003001                     3                   N
# 4         2020-09-25    C005003001                     3                   N
# 5         2020-10-01    C015001004                     3                   N
# 6         2019-09-30    C015002002                     3                   N
# 7         2019-10-01    C015001001                     1                   N
# 8         2020-10-01    C015001003                     3                   S
# 9         2020-10-01    C005003001                     1                   S
# 10        2020-11-30    C015002005                     3                   N
# 11        2020-12-31    C015001005                     3                   N
# 12        2020-07-31    C015002004                     3                   N
# 13        2020-10-10    C015002001                     3                   S
# 14               NaT    C005005001                     2                   S
# 15               NaT    C005005001                     3                   E
# 16        2021-05-31    C005003001                     1                   N
# 17        2021-03-31    C015002002                     1                   N
# 18        2021-03-31    C005004001                     1                   N
# 19        2019-09-30    C015002006                     2                   N
# 20        2020-07-31    C015002003                     3                   N
# 21        2019-11-16    C015001001                     3                   N
# 22               NaT    C005005001                     3                   E
# 23               NaT          None                     2                   N
# 24        2021-11-30    C005009001                     3                   N
# 25               NaT    C015001001                     1                   N
#
#    apt_service_stop_reason apt_service_stop_id        apt_service_stop_dt  \
# 0            테스트용 서비스입니다.        MBR0000000000 2020-11-20 23:01:57.453545
# 1                     None       MBR0000000000 2021-02-03 11:08:27.463505
# 2                     None       MBR0000000000 2020-02-14 17:11:49.359985
# 3                     None       MBR0000000000 2020-01-21 15:51:45.530653
# 4                     None       MBR0000000000 2020-08-11 09:00:03.662053
# 5                     None       MBR0000000000 2020-09-03 13:34:52.665917
# 6                     None                None                        NaT
# 7                     None                None                        NaT
# 8                     test       MBR0000000000 2020-02-12 16:42:33.542882
# 9                      테스트       MBR0000000000 2021-04-13 15:25:40.207742
# 10                    None       MBR0000000000 2020-10-23 17:23:55.544973
# 11                    None       MBR0000000000 2020-11-20 16:12:34.264469
# 12                    None       MBR0000000000 2020-06-19 18:28:29.816148
# 13                               MBR0000000000 2020-10-12 10:49:20.607943
# 14               sap id 오류       MBR0000000000 2021-07-02 13:40:44.924654
# 15                    None       MBR0000000000 2021-07-08 09:13:39.007680
# 16                    None       MBR0000000000 2021-04-15 19:01:05.457779
# 17                    None       MBR0000000000 2021-02-19 17:33:22.273238
# 18                    None       MBR0000000000 2021-03-10 14:48:55.680976
# 19                    None       MBR0000000000 2021-02-25 16:35:15.014189
# 20                    None       MBR0000000000 2020-05-28 17:15:35.784025
# 21                    None                None                        NaT
# 22                    None       MBR0000000000 2021-08-11 13:26:13.671800
# 23                    None                None                        NaT
# 24                    None                None                        NaT
# 25                    None                None                        NaT
#
#                     regist_dt      regist_id                  update_dt  \
# 0  2019-10-23 17:28:57.531549  MBR0000000000 2020-11-20 23:01:57.453545
# 1  2021-01-20 08:45:17.105865  MBR0000000000 2021-06-18 15:22:27.783439
# 2  2020-02-12 16:38:52.685790  MBR0000000000 2021-04-29 17:42:32.382275
# 3  2020-01-20 10:31:00.367069  MBR0000000000 2021-04-29 17:42:55.301968
# 4  2020-08-04 17:33:55.985549  MBR0000000000 2020-12-03 14:51:15.507654
# 5  2020-02-12 16:38:59.157711  MBR0000000000 2020-09-03 13:36:39.000496
# 6  2019-11-12 13:49:29.994852  MBR0000000000 2021-04-29 17:43:06.736954
# 7  2019-07-30 14:59:45.097000  MBR0000000000 2019-08-14 11:40:01.758000
# 8  2020-02-12 16:41:43.402399  MBR0000000000 2020-02-14 15:43:24.313385
# 9  2020-02-13 09:06:07.563834  MBR0000000000 2021-04-13 15:52:44.967279
# 10 2020-10-22 10:56:53.793327  MBR0000000000 2021-04-22 09:00:18.197182
# 11 2020-11-17 14:40:43.435140  MBR0000000000 2021-04-29 17:41:52.129736
# 12 2020-06-17 17:29:33.935428  MBR0000000000 2021-04-29 17:42:05.445629
# 13 2020-10-12 10:36:38.479394  MBR0000000000 2020-10-22 14:06:47.890294
# 14 2021-07-01 13:57:58.904952  MBR0000000000 2021-07-08 09:12:55.293580
# 15 2021-07-07 16:11:28.007274  MBR0000000000 2021-07-08 13:04:22.897820
# 16 2021-04-13 15:29:33.110993  MBR0000000000 2021-07-08 14:51:03.686956
# 17 2021-02-02 08:57:10.427812  MBR0000000000 2021-04-29 17:41:12.490385
# 18 2021-03-03 14:20:55.135401  MBR0000000000 2021-04-29 17:41:21.830925
# 19 2020-12-23 14:03:47.296000  MBR0000000000 2021-04-29 17:41:32.629021
# 20 2020-05-25 15:47:58.837564  MBR0000000000 2021-04-29 17:42:17.858862
# 21 2019-10-22 19:55:23.065989  MBR0000000000 2021-04-29 17:43:22.643048
# 22 2021-07-08 09:16:03.614346  MBR0000000000 2021-08-11 13:26:13.671800
# 23 2021-07-01 13:55:36.583891  MBR0000000000 2021-07-01 13:55:36.583891
# 24 2021-08-11 13:25:14.268286  MBR0000000000 2021-08-11 13:35:42.564099
# 25 2021-07-07 16:53:51.811423  MBR0000000000 2021-07-07 16:53:51.811423
#
#         update_id apt_join_start_dt apt_join_start_yn apt_sap_id
# 0   MBR0000000000              None                 N       None
# 1   MBR0000000000              None                 N       C026
# 2   MBR0000000000              None                 N       D010
# 3   MBR0000000000              None                 N       B018
# 4   MBR0000000000              None                 N       None
# 5   MBR0000000000              None                 N       None
# 6   MBR0000000000              None                 N       H003
# 7   MBR0000000000              None                 N       None
# 8   MBR0000000000              None                 N       None
# 9   MBR0000000000              None                 N       None
# 10  MBR0000000000              None                 N       None
# 11  MBR0000000000              None                 N       D021
# 12  MBR0000000000              None                 N       C025
# 13  MBR0000000000              None                 N       None
# 14  MBR0000000000              None                 N     123123
# 15  MBR0000000000              None                 N    1231233
# 16  MBR0000000000              None                 N       C031
# 17  MBR0000000000              None                 N       C036
# 18  MBR0000000000              None                 N       D026
# 19  MBR0000000000              None                 N       C024
# 20  MBR0000000000              None                 N       D018
# 21  MBR0000000000              None                 N       D012
# 22  MBR0000000000              None                 N     123123
# 23  MBR0000000000              None                 N          8
# 24  MBR0000000000              None                 N
# 25  MBR0000000000              None                 N

# %%
# apt_mst.to_csv(f"D:/디지털혁신팀/태블로/마이호미/마이호미_FINAL/apt_mst_{end.strftime('%Y-%m-%d')}.csv", encoding="euc-kr",  index=False)
# apt_mst.head()

# %% [markdown]
# ## signup.csv

# %%
# 대표, 세대원
f = open("D:/Github/Work/Tableau/signup_password.txt", "r")
password = f.readline()
conn = psycopg2.connect(host="postgresql-production1.cluster-ro-cxb5zwyq1mu5.ap-northeast-2.rds.amazonaws.com", dbname="hdc", user="postgres", password=password)
cur = conn.cursor(cursor_factory=RealDictCursor)
query = """
SELECT A.*
          FROM (
        SELECT MBRMST.MBR_ID
        	 , MBRMST.LOGIN_ID
             , APTMST.APT_NAME
             , AUI.DNG_NO
             , AUI.HO_NO
             , AUI.SEP_NO
             , CONCAT(MBRMST.MBR_NAME,'(',MBRMST.LOGIN_ID, ')') AS MBR_NAME
             , MBRMST.MBR_SEX
             , MBRMST.MBR_BIRTH
             , MBRMST.MBR_NICKNAME
             , MBRMST.MBR_PHONE
             , MBRMST.MBR_SYS_TY
             , C1.CRD_NAME AS MBR_SYS_TY_NAME
             , MBRMST.MBR_ST
             , C2.CRD_NAME AS MBR_ST_NAME
             , MBRMST.REGIST_DT
             , HMMD.MBR_LAST_ACCESS_DT
             , MBRCERT.MBR_ACERT_ID
             , APTMST.APT_ID
             , C3.CRD_GROUP AS LOC1
             , APTMST.APT_ADDR_CODE
             , MBRMST.MBR_MEMO
             , TO_CHAR(MBRMST.MBR_LEAVING_EXPECTED_DATE, 'YYYY/MM/DD') AS MBR_LEAVING_EXPECTED_DATE 
             , AUI.UNIT_ID
             , MBRMST.MBR_ADMIN_YN
             , MBRMST.MBR_FAMILLY_TY
             , CASE WHEN MBRMST.MBR_DELETE_DATE IS NULL THEN ''
                    WHEN MBRMST.MBR_DELETE_DATE IS NOT NULL THEN TO_CHAR(MBRMST.MBR_DELETE_DATE,'YYYY/MM/DD')
                END MBR_DELETE_DATE 
          FROM HDC_MBR.MBR_MST MBRMST
	 LEFT JOIN HDC_MBR.MBR_DEVICE HMMD ON MBRMST.MBR_ID = HMMD.MBR_ID
     LEFT JOIN HDC_SYS.SYS_CODE C1 ON MBRMST.MBR_SYS_TY = C1.CRD
     LEFT JOIN HDC_SYS.SYS_CODE C2 ON MBRMST.MBR_ST = C2.CRD
	INNER JOIN HDC_MBR.MBR_CERT MBRCERT ON MBRMST.MBR_ID = MBRCERT.MBR_ID
	INNER JOIN HDC_MBR.MBR_APT_CERT_HIS ACH ON MBRCERT.MBR_ACERT_ID = ACH.APT_CERT_ID
	INNER JOIN HDC_APT.APT_MST APTMST ON ACH.APT_ID = APTMST.APT_ID
    INNER JOIN HDC_APT.APT_UNIT_INFO AUI ON ACH.APT_UNIT_ID = AUI.UNIT_ID
	 LEFT JOIN HDC_SYS.SYS_CODE C3 ON APTMST.APT_ADDR_CODE = C3.CRD
	  UNION
        SELECT MBRMST.MBR_ID
             , MBRMST.LOGIN_ID
             , APTMST.APT_NAME
             , AUI.DNG_NO
             , AUI.HO_NO
             , AUI.SEP_NO
             , CONCAT(MBRMST.MBR_NAME,'(',MBRMST.LOGIN_ID, ')') AS MBR_NAME
             , MBRMST.MBR_SEX
             , MBRMST.MBR_BIRTH
             , MBRMST.MBR_NICKNAME
             , MBRMST.MBR_PHONE
             , MBRMST.MBR_SYS_TY
             , C1.CRD_NAME AS MBR_SYS_TY_NAME
             , MBRMST.MBR_ST
             , C2.CRD_NAME AS MBR_ST_NAME
             , MBRMST.REGIST_DT
             , HMMD.MBR_LAST_ACCESS_DT
             , MBRCERT.MBR_ACERT_ID
             , APTMST.APT_ID
             , C3.CRD_GROUP AS LOC1
             , APTMST.APT_ADDR_CODE
             , MBRMST.MBR_MEMO
             , TO_CHAR(MBRMST.MBR_LEAVING_EXPECTED_DATE, 'YYYY/MM/DD') AS MBR_LEAVING_EXPECTED_DATE 
             , AUI.UNIT_ID
             , MBRMST.MBR_ADMIN_YN
             , MBRMST.MBR_FAMILLY_TY
             , CASE WHEN MBRMST.MBR_DELETE_DATE IS NULL THEN ''
                    WHEN MBRMST.MBR_DELETE_DATE IS NOT NULL THEN TO_CHAR(MBRMST.MBR_DELETE_DATE,'YYYY/MM/DD')
                END MBR_DELETE_DATE
          FROM HDC_MBR.MBR_MST MBRMST
     LEFT JOIN HDC_MBR.MBR_DEVICE HMMD ON MBRMST.MBR_ID = HMMD.MBR_ID
     LEFT JOIN HDC_SYS.SYS_CODE C1 ON MBRMST.MBR_SYS_TY = C1.CRD
     LEFT JOIN HDC_SYS.SYS_CODE C2 ON MBRMST.MBR_ST = C2.CRD
	 
	INNER JOIN HDC_MBR.MBR_GROUP_MBR MGM ON MBRMST.MBR_ID = MGM.MBR_ID AND MGM.GROUP_MBR_INVITE_ST != 'C000002009'
	
    INNER JOIN HDC_MBR.MBR_GROUP MG ON MGM.GRP_ID = MG.GRP_ID
 	 LEFT JOIN HDC_MBR.MBR_CERT MBRCERT ON MG.GRP_OWNER = MBRCERT.MBR_ID
 	 LEFT JOIN HDC_MBR.MBR_APT_CERT_HIS ACH ON MBRCERT.MBR_ACERT_ID = ACH.APT_CERT_ID
 	 LEFT JOIN HDC_APT.APT_MST APTMST ON ACH.APT_ID = APTMST.APT_ID
     LEFT JOIN HDC_APT.APT_UNIT_INFO AUI ON ACH.APT_UNIT_ID = AUI.UNIT_ID
	 LEFT JOIN HDC_SYS.SYS_CODE C3 ON APTMST.APT_ADDR_CODE = C3.CRD
	 ) A
	WHERE 1=1
	AND A.MBR_ADMIN_YN = 'N'
	AND	A.MBR_SYS_TY IN ('C000004003','C000004004')
    ORDER BY A.REGIST_DT DESC
"""
cur.execute(query)
result = cur.fetchall()
b = pd.DataFrame(result)
# b.to_csv("D:/Github/Work/Tableau/Myhomie/대표, 세대원.csv", encoding="euc-kr")

# %%
b[(b["regist_dt"] >= "2020.02.01") & (b["regist_dt"] < "2020.03.01") & (b["mbr_st_name"] != "탈퇴")]
# Out:
#              mbr_id    login_id       apt_name dng_no ho_no sep_no  \
# 5884  MBR0000004592    msmk0208   동탄 호수공원 아이파크   3125  1403   None
# 5886  MBR0000004587  zerono1014   동탄 호수공원 아이파크   3125  1403   None
# 5887  MBR0000004585   makim0723   동탄 호수공원 아이파크   3125  1403   None
# 5888  MBR0000004560   tjdfkr007    목동센트럴아이파크위브    108  1002   None
# 5889  MBR0000004532     asj6020    목동센트럴아이파크위브    204  1905   None
# ...             ...         ...            ...    ...   ...    ...
# 6250  MBR0000002784      koo002   동탄 호수공원 아이파크   3122   902   None
# 6251  MBR0000002783    sara3359   동탄 호수공원 아이파크   3123  2003   None
# 6252  MBR0000002782    kuipokyl   동탄 호수공원 아이파크   3123  1403   None
# 6253  MBR0000002781   ok0260222  청주가경 아이파크 2단지    202  2404   None
# 6254  MBR0000002779      wlgnfl   동탄 호수공원 아이파크   3123   704   None
#
#              mbr_name mbr_sex mbr_birth mbr_nickname    mbr_phone  mbr_sys_ty  \
# 5884    김미경(msmk0208)       1  19811125          영투맘  01050442449  C000004004
# 5886  김영노(zerono1014)       0  20041014       zerono  01087322449  C000004004
# 5887   김민수(makim0723)       0  19730723        MSKIM  01049282449  C000004003
# 5888   최성락(tjdfkr007)       0  19890829          최성락  01051928608  C000004003
# 5889     안상준(asj6020)       0  19810602          웰채스  01071639070  C000004003
# ...               ...     ...       ...          ...          ...         ...
# 6250      구철회(koo002)       0  19761009          Koo  01094262782  C000004003
# 6251    허윤정(sara3359)       1  19871230        또복또복맘  01090142570  C000004003
# 6252    정용구(kuipokyl)       0  19810301            용  01063230979  C000004004
# 6253   안현우(ok0260222)       0  19810318       anbogo  01024890990  C000004003
# 6254      이민욱(wlgnfl)       0  19881217   MinukEthan  01036541389  C000004003
#
#      mbr_sys_ty_name      mbr_st mbr_st_name                  regist_dt  \
# 5884        입주자(세대원)  C000002001          정상 2020-02-29 20:59:22.382915
# 5886        입주자(세대원)  C000002001          정상 2020-02-29 20:46:13.546742
# 5887         입주자(대표)  C000002001          정상 2020-02-29 20:19:11.834751
# 5888         입주자(대표)  C000002001          정상 2020-02-29 14:10:58.620740
# 5889         입주자(대표)  C000002001          정상 2020-02-29 08:21:01.918212
# ...              ...         ...         ...                        ...
# 6250         입주자(대표)  C000002001          정상 2020-02-01 08:31:59.572902
# 6251         입주자(대표)  C000002001          정상 2020-02-01 08:16:16.066144
# 6252        입주자(세대원)  C000002001          정상 2020-02-01 07:16:21.076343
# 6253         입주자(대표)  C000002001          정상 2020-02-01 07:08:15.953333
# 6254         입주자(대표)  C000002001          정상 2020-02-01 01:05:24.623815
#
#              mbr_last_access_dt   mbr_acert_id         apt_id        loc1  \
# 5884 2021-08-09 10:20:13.712142  ACT0000008010  APT0000002590  C000015002
# 5886 2021-07-08 22:10:47.914663  ACT0000008010  APT0000002590  C000015002
# 5887 2021-07-21 14:16:42.041617  ACT0000008010  APT0000002590  C000015002
# 5888 2021-05-28 22:19:08.294742  ACT0000007960  APT0000007902  C000015001
# 5889 2021-02-23 18:53:11.393105  ACT0000007905  APT0000007902  C000015001
# ...                         ...            ...            ...         ...
# 6250 2020-11-26 17:30:11.945230  ACT0000004814  APT0000002590  C000015002
# 6251 2021-07-22 18:16:36.273529  ACT0000004811  APT0000002590  C000015002
# 6252 2020-12-24 11:40:31.441946  ACT0000001834  APT0000002590  C000015002
# 6253 2021-04-04 17:23:22.420267  ACT0000004805  APT0000006347  C000015003
# 6254 2021-08-12 23:24:56.084200  ACT0000004803  APT0000002590  C000015002
#
#      apt_addr_code mbr_memo mbr_leaving_expected_date        unit_id  \
# 5884    C015002002     None                      None  UNI0000004719
# 5886    C015002002     None                      None  UNI0000004719
# 5887    C015002002     None                      None  UNI0000004719
# 5888    C015001003     None                      None  UNI0000035225
# 5889    C015001003     None                      None  UNI0000035670
# ...            ...      ...                       ...            ...
# 6250    C015002002                               None  UNI0000004297
# 6251    C015002002     None                      None  UNI0000004438
# 6252    C015002002     None                      None  UNI0000004444
# 6253    C005003001     None                      None  UNI0000006575
# 6254    C015002002     None                      None  UNI0000004479
#
#      mbr_admin_yn mbr_familly_ty mbr_delete_date
# 5884            N     C000017002
# 5886            N     C000017003
# 5887            N     C000017001
# 5888            N     C000017001
# 5889            N     C000017001
# ...           ...            ...             ...
# 6250            N     C000017001
# 6251            N     C000017001
# 6252            N     C000017002
# 6253            N     C000017001
# 6254            N     C000017001
#
# [348 rows x 27 columns]

# %%
# with open("D:/Github/Work/Tableau/signup_password.pkl", "rb") as f:
#      password = pk.load(f)
# conn = psycopg2.connect(host="postgresql-production1.cluster-ro-cxb5zwyq1mu5.ap-northeast-2.rds.amazonaws.com", dbname="hdc", user="postgres", password=password)
# cur = conn.cursor(cursor_factory=RealDictCursor)
# query = f"SELECT hdc_mbr.mbr_mst.mbr_id, \
# CASE hdc_mbr.mbr_mst.mbr_sys_ty  \
# WHEN 'C000004001' THEN '입주예정자' \
# WHEN 'C000004003' THEN '입주자(대표)' \
# WHEN 'C000004004' THEN '입주자(세대원)' \
# END AS mbr_sys_ty, \
# CASE hdc_mbr.mbr_mst.mbr_sex \
# WHEN '0' THEN '남자' \
# WHEN '1' THEN '여자' \
# END AS mbr_sex, \
# hdc_mbr.mbr_mst.mbr_birth, hdc_mbr.mbr_mst.regist_dt, hdc_mbr.mbr_mst.mbr_delete_date, \
# CASE hdc_mbr.mbr_mst.mbr_st \
# WHEN 'C000002001' THEN '정상' \
# WHEN 'C000002005' THEN' 탈퇴' \
# WHEN 'C000002007' THEN '퇴거' \
# WHEN 'C000002008' THEN '휴면상태' \
# END AS mbr_st, \
# hdc_apt.apt_unit_mbr.mbr_id, \
# hdc_apt.apt_unit_info.dng_no, hdc_apt.apt_unit_info.ho_no, \
# hdc_apt.apt_mst.apt_name  \
# FROM hdc_mbr.mbr_mst  \
# LEFT OUTER JOIN hdc_apt.apt_unit_mbr  \
# LEFT OUTER JOIN hdc_apt.apt_unit_info  \
# LEFT OUTER JOIN hdc_apt.apt_mst  \
# ON hdc_apt.apt_unit_info.apt_id = hdc_apt.apt_mst.apt_id  \
# ON hdc_apt.apt_unit_mbr.unit_id = hdc_apt.apt_unit_info.unit_id  \
# ON hdc_mbr.mbr_mst.mbr_id = hdc_apt.apt_unit_mbr.mbr_id;"
# cur.execute(query)
# result = cur.fetchall()
# signup = pd.DataFrame(result)

# %%
signup.to_csv("signup.csv", encoding="euc-kr")

# %%
# signup = signup[signup["apt_name"].notna()]
# signup["mbr_sys_ty"] = signup["mbr_sys_ty"].map({"C000004001":"입주예정자", "C000004003":"입주자(대표)", "C000004004":"입주자(세대원)"})
# signup["mbr_sex"] = signup["mbr_sex"].map({"0":"남자", "1":"여자"})
# signup["mbr_st"] = signup["mbr_st"].map({"C000002001":"정상", "C000002005":"탈퇴", "C000002007":"퇴거", "C000002008":"휴면상태"})
# signup = signup.rename({"mbr_id":"아이디", "apt_name":"아파트 명", "dng_no":"동", "ho_no":"호", "mbr_sys_ty":"회원유형", "mbr_st":"회원상태", "mbr_sex":"성별", "mbr_birth":"생년월일", "regist_dt":"가입일", "mbr_delete_date":"탈퇴일"}, axis=1)
# signup["성별/생년월일"] = signup["성별"] + "/" + signup["생년월일"]
# signup = signup[["아이디", "아파트 명", "동", "호", "회원유형", "회원상태", "성별/생년월일", "가입일", "탈퇴일"]]

# %%
signup.to_csv(f"D:/Github/Work/Tableau/Myhomie/signup_{end.strftime('%Y-%m-%d')}.csv", encoding="euc-kr")
