# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preparing" data-toc-modified-id="Data-Preparing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preparing</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Modeling</a></span></li><li><span><a href="#Inference" data-toc-modified-id="Inference-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Inference</a></span></li></ul></div>

# %%
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold, GroupKFold, LeaveOneOut, LeaveOneGroupOut
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
import tensorflow as tf
from tensorflow.keras import Input, Model, Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Layer, Dense, Flatten, Dropout, Concatenate, Add, Dot, Multiply, Reshape, Activation, BatchNormalization, LayerNormalization, SimpleRNNCell, RNN, SimpleRNN, LSTM, Embedding, Bidirectional, TimeDistributed, Conv1D, Conv1DTranspose
, Conv2D, Conv2DTranspose
, MaxPool1D, MaxPool2D, GlobalMaxPool1D, GlobalMaxPool2D, AveragePooling1D, AveragePooling2D, GlobalAveragePooling1D, GlobalAveragePooling2D, ZeroPadding2D, RepeatVector
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.optimizers import SGD, Adagrad, Adam
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
# MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError, BinaryCrossentropy, CategoricalCrossentropy, SparseCategoricalCrossentropy, CosineSimilarity
from tensorflow.keras import losses
# MeanSquaredError, RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError, BinaryCrossentropy, CategoricalCrossentropy, SparseCategoricalCrossentropy, CosineSimilarity
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.activations import linear, sigmoid, relu
from tensorflow.keras.initializers import RandomNormal, glorot_uniform, he_uniform, Constant
import pandas_datareader.data as web
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
import statsmodels.api as sm

warnings.filterwarnings("ignore")
plt.style.use("dark_background")

# %%
# gpu_devices = tf.config.experimental.list_physical_devices("GPU")
# if gpu_devices:
#     print("Using GPU")
#     tf.config.experimental.set_memory_growth(gpu_devices[0], True)
# else:
#     print("Using CPU")

# sb.set_style("whitegrid")
# np.random.seed(42)

# %%
# hists_path = Path("hists", "multivariate_time_series")
# if not hists_path.exists():
#     hists_path.mkdir(parents=True)

# %% [markdown]
# # Data Preparing

# %%
data = web.DataReader(name=["UMCSENT", "IPGMFN"], data_source="fred", start="1980", end="2021-12")
data.columns = ["cs", "ip"]
data = data.dropna()

# %%
data.plot.line(figsize=(10, 6));

# %%
# Data Transformation
data_tf = pd.DataFrame()
data_tf["cs"] = data["cs"].diff(12).dropna()
data_tf["ip"] = data["ip"].diff(12).dropna()
data_tf["ip"] = np.log(data["ip"]).diff(12)

# Feature Scaling
sc = StandardScaler()
# sc = MinMaxScaler()
data_tf = pd.DataFrame(sc.fit_transform(data_tf), index=data_tf.index, columns=data_tf.columns)

# %%
data_tf.plot.line(figsize=(10, 6));

# %%
def blocked_cv(data, window_size, h, step=1):
    X = list()
    y = list()
    for i in range(0, len(data) - window_size - h + 1, step):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size:i + window_size + h])
    return np.array(X), np.array(y)

window_size = 20
h = 1
X, y = blocked_cv(data_tf, window_size, h)
y = y[:, 0, :]

print(X.shape)
print(y.shape)

X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=24, shuffle=False)
# Out:
# (472, 20, 2)
# (472, 2)

# %% [markdown]
# # Modeling

# %%
n_features = 2

inputs = Input(shape=(window_size, n_features))

z = LSTM(units=200, dropout=0.1, recurrent_dropout=0.1, return_sequences=False)(inputs)
z = Dense(units=128)(z)
outputs = Dense(units=n_features)(z)

model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 2)]           0
#
#  lstm (LSTM)                 (None, 200)               162400
#
#  dense (Dense)               (None, 128)               25728
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 188,386
# Trainable params: 188,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mse"])
es = EarlyStopping(monitor="val_loss", mode="auto", verbose=1, patience=10)
model_path = "cs_ip_LSTM.h5"
mc = ModelCheckpoint(filepath=model_path, monitor="val_loss", mode="auto", verbose=1, save_best_only=True)
hist = model.fit(x=X_tr, y=y_tr, validation_split=0.2, epochs=100, batch_size=32, verbose=2, shuffle=False, callbacks=[es, mc])
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.33034, saving model to cs_ip_LSTM.h5
# 12/12 - 3s - loss: 0.5541 - mse: 0.5541 - val_loss: 0.3303 - val_mse: 0.3303 - 3s/epoch - 228ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.33034 to 0.23192, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.3379 - mse: 0.3379 - val_loss: 0.2319 - val_mse: 0.2319 - 848ms/epoch - 71ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.23192 to 0.18769, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.2547 - mse: 0.2547 - val_loss: 0.1877 - val_mse: 0.1877 - 835ms/epoch - 70ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.18769
# 12/12 - 1s - loss: 0.2321 - mse: 0.2321 - val_loss: 0.2068 - val_mse: 0.2068 - 718ms/epoch - 60ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.18769
# 12/12 - 1s - loss: 0.2145 - mse: 0.2145 - val_loss: 0.1973 - val_mse: 0.1973 - 778ms/epoch - 65ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.18769
# 12/12 - 1s - loss: 0.2090 - mse: 0.2090 - val_loss: 0.1902 - val_mse: 0.1902 - 786ms/epoch - 65ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.18769 to 0.18112, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.2187 - mse: 0.2187 - val_loss: 0.1811 - val_mse: 0.1811 - 775ms/epoch - 65ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.18112 to 0.16684, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.2442 - mse: 0.2442 - val_loss: 0.1668 - val_mse: 0.1668 - 816ms/epoch - 68ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.16684
# 12/12 - 1s - loss: 0.2360 - mse: 0.2360 - val_loss: 0.2161 - val_mse: 0.2161 - 792ms/epoch - 66ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.16684
# 12/12 - 1s - loss: 0.1958 - mse: 0.1958 - val_loss: 0.1884 - val_mse: 0.1884 - 771ms/epoch - 64ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.16684 to 0.16568, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.1965 - mse: 0.1965 - val_loss: 0.1657 - val_mse: 0.1657 - 787ms/epoch - 66ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.2247 - mse: 0.2247 - val_loss: 0.1680 - val_mse: 0.1680 - 750ms/epoch - 63ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1904 - mse: 0.1904 - val_loss: 0.1689 - val_mse: 0.1689 - 766ms/epoch - 64ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.2178 - mse: 0.2178 - val_loss: 0.1780 - val_mse: 0.1780 - 735ms/epoch - 61ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1825 - mse: 0.1825 - val_loss: 0.1717 - val_mse: 0.1717 - 796ms/epoch - 66ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1909 - mse: 0.1909 - val_loss: 0.1686 - val_mse: 0.1686 - 760ms/epoch - 63ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1829 - mse: 0.1829 - val_loss: 0.1743 - val_mse: 0.1743 - 790ms/epoch - 66ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1992 - mse: 0.1992 - val_loss: 0.1853 - val_mse: 0.1853 - 745ms/epoch - 62ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1762 - mse: 0.1762 - val_loss: 0.1731 - val_mse: 0.1731 - 771ms/epoch - 64ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.16568
# 12/12 - 1s - loss: 0.1831 - mse: 0.1831 - val_loss: 0.1723 - val_mse: 0.1723 - 749ms/epoch - 62ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.16568 to 0.16460, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.1793 - mse: 0.1793 - val_loss: 0.1646 - val_mse: 0.1646 - 802ms/epoch - 67ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.16460
# 12/12 - 1s - loss: 0.1740 - mse: 0.1740 - val_loss: 0.1679 - val_mse: 0.1679 - 779ms/epoch - 65ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.16460
# 12/12 - 1s - loss: 0.2052 - mse: 0.2052 - val_loss: 0.1755 - val_mse: 0.1755 - 772ms/epoch - 64ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.16460 to 0.16301, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.1886 - mse: 0.1886 - val_loss: 0.1630 - val_mse: 0.1630 - 847ms/epoch - 71ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.16301
# 12/12 - 1s - loss: 0.1748 - mse: 0.1748 - val_loss: 0.1768 - val_mse: 0.1768 - 757ms/epoch - 63ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.16301
# 12/12 - 1s - loss: 0.2104 - mse: 0.2104 - val_loss: 0.1732 - val_mse: 0.1732 - 764ms/epoch - 64ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.16301
# 12/12 - 1s - loss: 0.2062 - mse: 0.2062 - val_loss: 0.1888 - val_mse: 0.1888 - 741ms/epoch - 62ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.16301 to 0.16277, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.2078 - mse: 0.2078 - val_loss: 0.1628 - val_mse: 0.1628 - 778ms/epoch - 65ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.16277
# 12/12 - 1s - loss: 0.2086 - mse: 0.2086 - val_loss: 0.1692 - val_mse: 0.1692 - 774ms/epoch - 64ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.16277 to 0.16012, saving model to cs_ip_LSTM.h5
# 12/12 - 1s - loss: 0.1791 - mse: 0.1791 - val_loss: 0.1601 - val_mse: 0.1601 - 775ms/epoch - 65ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.2013 - mse: 0.2013 - val_loss: 0.1702 - val_mse: 0.1702 - 751ms/epoch - 63ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1732 - mse: 0.1732 - val_loss: 0.1874 - val_mse: 0.1874 - 767ms/epoch - 64ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.2039 - mse: 0.2039 - val_loss: 0.1792 - val_mse: 0.1792 - 726ms/epoch - 61ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1675 - mse: 0.1675 - val_loss: 0.1891 - val_mse: 0.1891 - 748ms/epoch - 62ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1697 - mse: 0.1697 - val_loss: 0.1752 - val_mse: 0.1752 - 744ms/epoch - 62ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1972 - mse: 0.1972 - val_loss: 0.1685 - val_mse: 0.1685 - 751ms/epoch - 63ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1966 - mse: 0.1966 - val_loss: 0.1774 - val_mse: 0.1774 - 741ms/epoch - 62ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.2062 - mse: 0.2062 - val_loss: 0.1816 - val_mse: 0.1816 - 744ms/epoch - 62ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1958 - mse: 0.1958 - val_loss: 0.1827 - val_mse: 0.1827 - 769ms/epoch - 64ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.16012
# 12/12 - 1s - loss: 0.1921 - mse: 0.1921 - val_loss: 0.1632 - val_mse: 0.1632 - 770ms/epoch - 64ms/step
# Epoch 40: early stopping

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 8))
axes.plot(hist.history["loss"][1:], label="loss");
axes.plot(hist.history["val_loss"][1:], label="val_loss");
axes.legend();

# %% [markdown]
# # Inference

# %%
temp = data_tf.tail(24)
y_pred = pd.DataFrame(model.predict(X_te), columns=temp.columns, index=temp.index)
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 17))
pd.DataFrame(hist.history).rename(columns={"loss": "Training",
                                              "val_loss": "Validation"}).plot(ax=axes[0], title="Train & Validiation Error")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("MAE")
col_dict = {"ip": "Industrial Production", "cs": "cs"}

for i, col in enumerate(y_pred.columns, 1):
    y_tr.loc["2010":, col].plot(ax=axes[i], label="training", title=col_dict[col])
    y_te[col].plot(ax=axes[i], label="out-of-sample")
    y_pred[col].plot(ax=axes[i], label="prediction")
    axes[i].set_xlabel("")

axes[1].set_ylim(.5, .9)
axes[1].fill_between(x=y_te.index, y1=0.5, y2=0.9, color="grey", alpha=.5)

axes[2].set_ylim(.3, .9)
axes[2].fill_between(x=y_te.index, y1=0.3, y2=0.9, color="grey", alpha=.5)

plt.legend()
fig.suptitle("Multivariate Forecast - hists | Test MAE = {:.4f}".format(test_mae), fontsize=14)
sb.despine()
fig.tight_layout()
fig.subplots_adjust(top=.85)
fig.savefig(hists_path / "multivariate_hists", dpi=300);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-3504c010408d> in <module>
#       7
#       8 for i, col in enumerate(y_pred.columns, 1):
# ----> 9     y_tr.loc["2010":, col].plot(ax=axes[i], label="training", title=col_dict[col])
#      10     y_te[col].plot(ax=axes[i], label="out-of-sample")
#      11     y_pred[col].plot(ax=axes[i], label="prediction")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'loc'
