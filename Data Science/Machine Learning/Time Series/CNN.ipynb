# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from datetime import datetime, timedelta

# %%
df = pd.read_csv("./Datasets/Gemini_ETHUSD_d.csv",  
                 skiprows=1, 
                 parse_dates=True, 
                 index_col='Date')

df = df.sort_index().drop(['Symbol','Unix Timestamp'] , axis=1)
df.head()
# Out:
#              Open   High    Low  Close  Volume ETH  Volume USD
# Date
# 2016-05-09  12.00  12.00   9.36   9.98     1317.90    12885.06
# 2016-05-10   9.98   9.98   9.36   9.68      672.06     6578.20
# 2016-05-11   9.68  10.47   9.68  10.43     3052.51    30978.11
# 2016-05-12  10.43  12.00   9.92  10.20     2072.56    22183.39
# 2016-05-13  10.20  11.59  10.20  10.69     1769.71    18923.55

# %%
df['Close'].plot()

# %%
df.index.max()
# Out:
# Timestamp('2020-11-20 00:00:00')

# %%
# Block
test_cutoff_date = df.index.max() - timedelta(days=90)

df_test = df[df.index > test_cutoff_date]['Close']
df_train = df[df.index <= test_cutoff_date]['Close']

# %% [markdown]
# Single Step

# %%
df_train.plot()

# %%
df_test.plot()

# %%
from numpy import array

# Block

def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		end_ix = i + n_steps
		if end_ix > len(sequence)-1:
			break
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

raw_seq = df_train
n_steps = 30

X, y = split_sequence(raw_seq, n_steps)

n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))

# %%
X.shape
# Out:
# (1537, 30, 1)

# %%
y.shape
# Out:
# (1537,)

# %%
# CNN 모델을 만드는 부분.
# TCN (Temporal Conv. NN)
model = keras.Sequential()
                       # 요약된 정보의 차원 갯수, 요약을 할 time window의 크기.              #30, 1
model.add(layers.Conv1D(
    filters=64, 
    kernel_size=2, 
    activation='relu', 
    input_shape=(n_steps, 1))) # 29, 64
model.add(layers.MaxPooling1D(pool_size=2)) # 14,64
model.add(layers.Conv1D(filters=128, kernel_size=2, activation='relu', input_shape=(n_steps, 1))) # 13,128
model.add(layers.MaxPooling1D(pool_size=2)) # 6,128
model.add(layers.Conv1D(filters=256, kernel_size=2, activation='relu', input_shape=(n_steps, 1))) # 5, 256
model.add(layers.MaxPooling1D(pool_size=2)) # 2, 256
model.add(layers.Flatten()) # 512
model.add(layers.Dense(50, activation='relu')) # 뉴럴 네트워크
model.add(layers.Dense(1))

        # 그라이언트를 계산
model.compile(optimizer='adam', loss='mae')
# model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 29, 64)            192
#
#  max_pooling1d (MaxPooling1D  (None, 14, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 13, 128)           16512
#
#  max_pooling1d_1 (MaxPooling  (None, 6, 128)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 256)            65792
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 50)                25650
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 108,197
# Trainable params: 108,197
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 14s 10ms/step - loss: 87.9285
# Epoch 2/100
# 25/25 [==============================] - 0s 7ms/step - loss: 48.0956
# Epoch 3/100
# 25/25 [==============================] - 0s 8ms/step - loss: 44.5483
# Epoch 4/100
# 25/25 [==============================] - 0s 8ms/step - loss: 47.6673
# Epoch 5/100
# 25/25 [==============================] - 0s 7ms/step - loss: 42.6592
# Epoch 6/100
# 25/25 [==============================] - 0s 8ms/step - loss: 42.3332
# Epoch 7/100
# 25/25 [==============================] - 0s 8ms/step - loss: 39.3716
# Epoch 8/100
# 25/25 [==============================] - 0s 8ms/step - loss: 39.3172
# Epoch 9/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.9840
# Epoch 10/100
# 25/25 [==============================] - 0s 8ms/step - loss: 39.3280
# Epoch 11/100
# 25/25 [==============================] - 0s 8ms/step - loss: 49.5895
# Epoch 12/100
# 25/25 [==============================] - 0s 7ms/step - loss: 65.2116
# Epoch 13/100
# 25/25 [==============================] - 0s 8ms/step - loss: 41.3383
# Epoch 14/100
# 25/25 [==============================] - 0s 7ms/step - loss: 38.5367
# Epoch 15/100
# 25/25 [==============================] - 0s 7ms/step - loss: 38.0827
# Epoch 16/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.5837
# Epoch 17/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.2307
# Epoch 18/100
# 25/25 [==============================] - 0s 8ms/step - loss: 40.1797
# Epoch 19/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.2181
# Epoch 20/100
# 25/25 [==============================] - 0s 8ms/step - loss: 39.7649
# Epoch 21/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.0576
# Epoch 22/100
# 25/25 [==============================] - 0s 7ms/step - loss: 37.4796
# Epoch 23/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.7262
# Epoch 24/100
# 25/25 [==============================] - 0s 7ms/step - loss: 39.3603
# Epoch 25/100
# 25/25 [==============================] - 0s 8ms/step - loss: 42.7247
# Epoch 26/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.3243
# Epoch 27/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.8519
# Epoch 28/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.5132
# Epoch 29/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.5008
# Epoch 30/100
# 25/25 [==============================] - 0s 8ms/step - loss: 39.0153
# Epoch 31/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.2432
# Epoch 32/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.5486
# Epoch 33/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.2181
# Epoch 34/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.7788
# Epoch 35/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.9718
# Epoch 36/100
# 25/25 [==============================] - 0s 8ms/step - loss: 44.5652
# Epoch 37/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.1655
# Epoch 38/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.1899
# Epoch 39/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.5826
# Epoch 40/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.3727
# Epoch 41/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.7491
# Epoch 42/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.0766
# Epoch 43/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.7665
# Epoch 44/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.6203
# Epoch 45/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.4393
# Epoch 46/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.9767
# Epoch 47/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.2071
# Epoch 48/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.4331
# Epoch 49/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.9507
# Epoch 50/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.4824
# Epoch 51/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.4562
# Epoch 52/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.7771
# Epoch 53/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.3526
# Epoch 54/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.7445
# Epoch 55/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.1129
# Epoch 56/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.9756
# Epoch 57/100
# 25/25 [==============================] - 0s 7ms/step - loss: 38.9290
# Epoch 58/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.6851
# Epoch 59/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.0629
# Epoch 60/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.7527
# Epoch 61/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.6143
# Epoch 62/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.7073
# Epoch 63/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.4482
# Epoch 64/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.0357
# Epoch 65/100
# 25/25 [==============================] - 0s 7ms/step - loss: 36.8487
# Epoch 66/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.5704
# Epoch 67/100
# 25/25 [==============================] - 0s 8ms/step - loss: 50.6112
# Epoch 68/100
# 25/25 [==============================] - 0s 7ms/step - loss: 38.0219
# Epoch 69/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.0774
# Epoch 70/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.4346
# Epoch 71/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.1969
# Epoch 72/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.8788
# Epoch 73/100
# 25/25 [==============================] - 0s 8ms/step - loss: 41.3396
# Epoch 74/100
# 25/25 [==============================] - 0s 8ms/step - loss: 37.3561
# Epoch 75/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.5125
# Epoch 76/100
# 25/25 [==============================] - 0s 8ms/step - loss: 36.0895
# Epoch 77/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.0552
# Epoch 78/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.6977
# Epoch 79/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.6096
# Epoch 80/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.1419
# Epoch 81/100
# 25/25 [==============================] - 0s 9ms/step - loss: 35.5069
# Epoch 82/100
# 25/25 [==============================] - 0s 7ms/step - loss: 34.9229
# Epoch 83/100
# 25/25 [==============================] - 0s 8ms/step - loss: 40.7752
# Epoch 84/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.2038
# Epoch 85/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.6716
# Epoch 86/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.5841
# Epoch 87/100
# 25/25 [==============================] - 0s 7ms/step - loss: 38.6463
# Epoch 88/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.7587
# Epoch 89/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.1867
# Epoch 90/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.1837
# Epoch 91/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.4965
# Epoch 92/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.6759
# Epoch 93/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.8184
# Epoch 94/100
# 25/25 [==============================] - 0s 8ms/step - loss: 45.2249
# Epoch 95/100
# 25/25 [==============================] - 0s 7ms/step - loss: 35.3271
# Epoch 96/100
# 25/25 [==============================] - 0s 8ms/step - loss: 38.7046
# Epoch 97/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.0901
# Epoch 98/100
# 25/25 [==============================] - 0s 8ms/step - loss: 34.8137
# Epoch 99/100
# 25/25 [==============================] - 0s 8ms/step - loss: 33.8028
# Epoch 100/100
# 25/25 [==============================] - 0s 8ms/step - loss: 35.3658

# %%
train_pred = model.predict(X)

# %%
train_pred
# Out:
# array([[ 15.037706],
#        [ 15.201775],
#        [ 14.913753],
#        ...,
#        [363.3316  ],
#        [399.99667 ],
#        [418.41458 ]], dtype=float32)

# %%
train_mae_loss = np.mean(np.abs(train_pred - y), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("train MAE loss")
plt.ylabel("No of samples")
plt.show()

# %%
train_df_with_pred = df_train.to_frame()[n_steps:]
train_df_with_pred['pred'] = train_pred

# %%
train_df_with_pred
# Out:
#              Close        pred
# Date
# 2016-06-08   14.51   15.037706
# 2016-06-09   14.47   15.201775
# 2016-06-10   13.97   14.913753
# 2016-06-11   14.11   15.027351
# 2016-06-12   15.75   15.354088
# ...            ...         ...
# 2020-08-18  422.30  388.672119
# 2020-08-19  407.55  371.706299
# 2020-08-20  414.53  363.331604
# 2020-08-21  388.07  399.996674
# 2020-08-22  395.98  418.414581
#
# [1537 rows x 2 columns]

# %%
# Lagging = 예측값이 실제 값보다 N 스텝 앞에 있는 경우
# Forwarding = 예측값이 실제 값보다 N 스텝 뒤에 있는 경우
fig, ax = plt.subplots(figsize=(10,10))
train_df_with_pred['pred'].plot(ax=ax, legend=True)
train_df_with_pred['Close'].plot(ax=ax, legend=True)

# %%
test_raw_seq = df_test

test_X, test_y = split_sequence(test_raw_seq, n_steps)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1], n_features))

# %%
test_X.shape
# Out:
# (60, 30, 1)

# %%
y_pred = model.predict(test_X)

# %%
y_pred.shape
# Out:
# (60, 1)

# %%
test_mae_loss = np.mean(np.abs(y_pred - test_y), axis=1)

plt.hist(test_mae_loss, bins=50)
plt.xlabel("Test MAE loss")
plt.ylabel("No of samples")
plt.show()

# %%
test_df_with_pred = df_test.to_frame()[n_steps:]
test_df_with_pred['pred'] = y_pred

# %%
test_df_with_pred
# Out:
#              Close        pred
# Date
# 2020-09-22  344.17  371.725525
# 2020-09-23  320.06  354.281769
# 2020-09-24  351.40  386.543091
# 2020-09-25  351.94  350.861603
# 2020-09-26  354.10  357.095093
# 2020-09-27  357.31  369.133636
# 2020-09-28  354.06  362.593750
# 2020-09-29  359.55  361.332367
# 2020-09-30  359.59  359.726776
# 2020-10-01  353.35  370.112885
# 2020-10-02  345.74  356.383118
# 2020-10-03  346.15  336.504547
# 2020-10-04  352.51  338.269226
# 2020-10-05  353.57  356.654938
# 2020-10-06  340.67  351.621399
# 2020-10-07  342.00  345.677643
# 2020-10-08  351.47  338.631958
# 2020-10-09  365.44  362.087799
# 2020-10-10  371.18  358.579193
# 2020-10-11  374.41  345.658630
# 2020-10-12  386.80  335.778076
# 2020-10-13  380.97  326.403717
# 2020-10-14  379.41  326.968781
# 2020-10-15  377.95  322.827057
# 2020-10-16  365.58  322.132690
# 2020-10-17  368.68  332.562744
# 2020-10-18  378.14  364.604553
# 2020-10-19  379.61  372.216003
# 2020-10-20  368.87  383.566223
# 2020-10-21  391.58  372.782349
# 2020-10-22  414.78  377.860107
# 2020-10-23  409.79  381.032074
# 2020-10-24  412.68  386.025574
# 2020-10-25  406.34  372.372070
# 2020-10-26  393.62  357.580414
# 2020-10-27  403.96  355.670410
# 2020-10-28  388.89  354.366272
# 2020-10-29  387.50  364.819092
# 2020-10-30  382.89  396.188354
# 2020-10-31  386.99  398.568268
# 2020-11-01  396.86  403.649841
# 2020-11-02  384.15  399.452087
# 2020-11-03  388.39  402.364594
# 2020-11-04  402.73  402.536713
# 2020-11-05  417.09  402.740021
# 2020-11-06  456.46  395.882751
# 2020-11-07  435.60  380.663391
# 2020-11-08  454.57  375.204193
# 2020-11-09  444.51  375.842560
# 2020-11-10  451.00  365.571716
# 2020-11-11  463.81  365.909729
# 2020-11-12  463.94  376.754974
# 2020-11-13  476.92  388.050659
# 2020-11-14  461.19  457.293488
# 2020-11-15  448.97  424.875763
# 2020-11-16  460.73  435.171844
# 2020-11-17  482.81  444.243561
# 2020-11-18  479.49  465.901611
# 2020-11-19  472.06  459.473145
# 2020-11-20  472.93  456.365143

# %%
fig, ax = plt.subplots(figsize=(10,10))
test_df_with_pred['pred'].plot(ax=ax, legend=True)
test_df_with_pred['Close'].plot(ax=ax, legend=True)

# %% [markdown]
# Multi Step

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		if out_end_ix > len(sequence):
			break
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
raw_seq = df_train

n_steps_in, n_steps_out = 60, 7
X, y = split_sequence(raw_seq, n_steps_in, n_steps_out)
n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))

# %%
X.shape
# Out:
# (1501, 60, 1)

# %%
model = keras.Sequential()
model.add(layers.Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(50, activation='relu'))
# 모델을 추가. (Seq2seq, Encoder-Decoder)
# 내가 출력할 시계열에 어떤 특징이 없을때
model.add(layers.Dense(n_steps_out))
model.compile(optimizer='adam', loss='mae')
# model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 59, 64)            192
#
#  max_pooling1d_3 (MaxPooling  (None, 29, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1856)              0
#
#  dense_2 (Dense)             (None, 50)                92850
#
#  dense_3 (Dense)             (None, 7)                 357
#
# =================================================================
# Total params: 93,399
# Trainable params: 93,399
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 5ms/step - loss: 71.5031
# Epoch 2/100
# 47/47 [==============================] - 0s 4ms/step - loss: 39.9305
# Epoch 3/100
# 47/47 [==============================] - 0s 4ms/step - loss: 35.1119
# Epoch 4/100
# 47/47 [==============================] - 0s 4ms/step - loss: 33.6355
# Epoch 5/100
# 47/47 [==============================] - 0s 4ms/step - loss: 31.9250
# Epoch 6/100
# 47/47 [==============================] - 0s 5ms/step - loss: 31.0863
# Epoch 7/100
# 47/47 [==============================] - 0s 5ms/step - loss: 29.6755
# Epoch 8/100
# 47/47 [==============================] - 0s 4ms/step - loss: 30.4280
# Epoch 9/100
# 47/47 [==============================] - 0s 4ms/step - loss: 29.3942
# Epoch 10/100
# 47/47 [==============================] - 0s 4ms/step - loss: 29.9303
# Epoch 11/100
# 47/47 [==============================] - 0s 4ms/step - loss: 28.2522
# Epoch 12/100
# 47/47 [==============================] - 0s 4ms/step - loss: 29.6102
# Epoch 13/100
# 47/47 [==============================] - 0s 4ms/step - loss: 29.1235
# Epoch 14/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.9791
# Epoch 15/100
# 47/47 [==============================] - 0s 4ms/step - loss: 27.8315
# Epoch 16/100
# 47/47 [==============================] - 0s 5ms/step - loss: 26.4273
# Epoch 17/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.3844
# Epoch 18/100
# 47/47 [==============================] - 0s 4ms/step - loss: 27.6864
# Epoch 19/100
# 47/47 [==============================] - 0s 4ms/step - loss: 27.3051
# Epoch 20/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.0835
# Epoch 21/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.4729
# Epoch 22/100
# 47/47 [==============================] - 0s 4ms/step - loss: 27.0237
# Epoch 23/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.8912
# Epoch 24/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.0540
# Epoch 25/100
# 47/47 [==============================] - 0s 5ms/step - loss: 25.9290
# Epoch 26/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.6813
# Epoch 27/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.2541
# Epoch 28/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.2471
# Epoch 29/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.8397
# Epoch 30/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.0319
# Epoch 31/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.1018
# Epoch 32/100
# 47/47 [==============================] - 0s 5ms/step - loss: 24.7571
# Epoch 33/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.4665
# Epoch 34/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.4183
# Epoch 35/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.6801
# Epoch 36/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.1814
# Epoch 37/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.1386
# Epoch 38/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.7145
# Epoch 39/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.5259
# Epoch 40/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.3522
# Epoch 41/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.3751
# Epoch 42/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.7586
# Epoch 43/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.2511
# Epoch 44/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.0665
# Epoch 45/100
# 47/47 [==============================] - 0s 5ms/step - loss: 24.5175
# Epoch 46/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.2270
# Epoch 47/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.4570
# Epoch 48/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6111
# Epoch 49/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6869
# Epoch 50/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.3302
# Epoch 51/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.8832
# Epoch 52/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.3739
# Epoch 53/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.8898
# Epoch 54/100
# 47/47 [==============================] - 0s 4ms/step - loss: 26.2673
# Epoch 55/100
# 47/47 [==============================] - 0s 5ms/step - loss: 23.7887
# Epoch 56/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6492
# Epoch 57/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.9736
# Epoch 58/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.5855
# Epoch 59/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4581
# Epoch 60/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4335
# Epoch 61/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.5440
# Epoch 62/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.5431
# Epoch 63/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.7018
# Epoch 64/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.9554
# Epoch 65/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6675
# Epoch 66/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.5870
# Epoch 67/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.5858
# Epoch 68/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4726
# Epoch 69/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.3934
# Epoch 70/100
# 47/47 [==============================] - 0s 5ms/step - loss: 23.5939
# Epoch 71/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.7789
# Epoch 72/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.8221
# Epoch 73/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.6796
# Epoch 74/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.0760
# Epoch 75/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6419
# Epoch 76/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4488
# Epoch 77/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.7948
# Epoch 78/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.5575
# Epoch 79/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6779
# Epoch 80/100
# 47/47 [==============================] - 0s 5ms/step - loss: 23.5381
# Epoch 81/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6026
# Epoch 82/100
# 47/47 [==============================] - 0s 4ms/step - loss: 25.2835
# Epoch 83/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.0036
# Epoch 84/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.2991
# Epoch 85/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.7879
# Epoch 86/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.9319
# Epoch 87/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4406
# Epoch 88/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6695
# Epoch 89/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.1335
# Epoch 90/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.1992
# Epoch 91/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.6443
# Epoch 92/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4423
# Epoch 93/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4631
# Epoch 94/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.8243
# Epoch 95/100
# 47/47 [==============================] - 0s 5ms/step - loss: 23.7109
# Epoch 96/100
# 47/47 [==============================] - 0s 5ms/step - loss: 23.5818
# Epoch 97/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.4530
# Epoch 98/100
# 47/47 [==============================] - 0s 4ms/step - loss: 23.2952
# Epoch 99/100
# 47/47 [==============================] - 0s 4ms/step - loss: 24.0085
# Epoch 100/100
# 47/47 [==============================] - 0s 4ms/step - loss: 22.9941

# %%
train_pred = model.predict(X)

train_mae_loss = np.mean(np.abs(train_pred - y), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("train MAE loss")
plt.ylabel("No of samples")
plt.show()

# %%
train_pred.shape
# Out:
# (1501, 7)

# %%
for i, pred in enumerate(train_pred[:5]):
  train_df_with_pred = df_train[i:i+n_steps_out]
  train_df_with_pred['pred'] = pred
  
  fig, ax = plt.subplots(figsize=(10,10))
  test_df_with_pred['pred'].plot(ax=ax, legend=True)
  test_df_with_pred['Close'].plot(ax=ax, legend=True)
  plt.show()

# %%
# TODO: TEST에 대해서도 똑같은 검증을 해보세요.
