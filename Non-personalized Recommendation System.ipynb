# %%
import requests
from io import BytesIO
from PIL import Image
import os
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import pymysql

# %%
# 영화 포스터를 가져와 주피터에서 볼 수 있도록 만들어주는 메소드
def display_posters(movieId_list):
    def get_poster(movieId):
        url = "https://pai-datasets.s3.ap-northeast-2.amazonaws.com/recommender_systems/movielens/img/POSTER_20M_FULL/{}.jpg".format(movieId)
        try:
            response = requests.get(url)
            b = BytesIO(response.content)
            img = np.asarray(Image.open(b))
        except:
            img = np.zeros((200,100,3))
        return img
    
    images = []
    for i in movieId_list:
        img = get_poster(i)
        images.append(img)

    columns = 5
    rows = (len(movieId_list) - 1) // columns + 1
    fig, axes = plt.subplots(rows, columns)
    axes = axes.flatten()
    fig.set_size_inches((20,rows * 5))
        
    for ind, img in enumerate(images):
        c_id = ind % columns
        r_id = ind // columns
        ax = axes[r_id*columns + c_id]
        ax.set_title(movieId_list[ind])
        ax.imshow(img)

    plt.tight_layout()

# %%
movies_df = pd.read_csv("D:/추천 시스템/movies.csv", index_col=0)
genres_df = pd.read_csv("D:/추천 시스템/genres.csv", index_col=0)
ratings_df = pd.read_csv("D:/추천 시스템/ratings.csv", index_col=0)
# Out:
# C:\Users\5CG7092POZ\Anaconda3\envs\tf2.0\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
cnt_genre = genres_df.groupby("movie_id", as_index=False).count()

# %%
cnt_genre
# Out:
#        movie_id  genre
# 0             1      5
# 1             2      3
# 2             3      2
# 3             4      3
# 4             5      1
# ...         ...    ...
# 27273    131254      1
# 27274    131256      1
# 27275    131258      1
# 27276    131260      1
# 27277    131262      3
#
# [27278 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 6))

ax.hist(cnt_genre["genre"])

fig.savefig("hist.png")

# %%
ratings_df["rated_at"] = pd.to_datetime(ratings_df["rated_at"], unit="s")

# %%
fig, ax = plt.subplots(figsize=(6, 6))

ax.hist(ratings_df["rating"])

fig.savefig("hist.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f5c97aed2cae> in <module>
#       1 fig, ax = plt.subplots(figsize=(6, 6))
#       2
# ----> 3 ax.hist(ratings_df["rating"])
#       4
#       5 fig.savefig("hist.png")
#
# ~\Anaconda3\envs\tf2.0\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\tf2.0\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6566
#    6567         # Massage 'x' for processing.
# -> 6568         x = cbook._reshape_2D(x, 'x')
#    6569         nx = len(x)  # number of datasets
#    6570
#
# ~\Anaconda3\envs\tf2.0\lib\site-packages\matplotlib\cbook\__init__.py in _reshape_2D(X, name)
#    1377         if nd > 1:
#    1378             raise ValueError(f'{name} must have 2 or fewer dimensions')
# -> 1379         result.append(xi.reshape(-1))
#    1380
#    1381     if is_1d:
#
# KeyboardInterrupt:

# %%
gr_cnt = ratings_df.groupby("movie_id").count()
cnt_over300 = ratings_df[ratings_df["movie_id"].isin(gr_cnt[gr_cnt["rating"]>=300].index)]
cnt_over300.groupby("movie_id").mean().sort_values("rating", ascending=False)

top10 = cnt_over300.groupby("movie_id").mean().sort_values("rating", ascending=False).nlargest(10, ["rating"], keep="all")

# %%
display_posters(top10.index)

# %%
horrows = set(genres_df[genres_df["genre"]=="Horror"]["movie_id"])
horrow_ratings = ratings_df[ratings_df["movie_id"].isin(horrows)]
gr_cnt = horrow_ratings.groupby("movie_id").count()
cnt_over300 = horrow_ratings[horrow_ratings["movie_id"].isin(gr_cnt[gr_cnt["rating"]>=300].index)]
cnt_over300.groupby("movie_id").mean().sort_values("rating", ascending=False)

top10_horrow = cnt_over300.groupby("movie_id").mean().sort_values("rating", ascending=False).nlargest(10, ["rating"], keep="all")

# %%
display_posters(top10_horrow.index)

# %%
recent_yr = movies_df["release_year"].max()
recent_movies = movies_df[movies_df["release_year"].isin([recent_yr, recent_yr-1, recent_yr-2])]["id"].values
recent_ratings = ratings_df[ratings_df["movie_id"].isin(recent_movies)]
recent_top10 = recent_ratings.groupby(by=["movie_id"]).mean().sort_values("rating", ascending=False).head(10).index

# %%
display_posters(recent_top10)
