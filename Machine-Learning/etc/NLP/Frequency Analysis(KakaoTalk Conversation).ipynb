# %%
import pandas as pd
import nltk
import MeCab
import re
import string
import matplotlib as mpl
import matplotlib.pyplot as plt
import platform
from wordcloud import WordCloud
import numpy as np

path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Darwin":
    mpl.rc("font", family="AppleGothic")
elif platform.system() == "Windows":
    font_name = mpl.font_manager.FontProperties(fname=path).get_name()
    mpl.rc('font', family=font_name)

# %%
def pos(text):
    p = re.compile(".+\t[A-Z]+")
    return [tuple(p.match(line).group().split("\t")) for line in MeCab.Tagger().parse(text).splitlines()[:-1]]

def morphs(text):
    p = re.compile(".+\t[A-Z]+")
    return [p.match(line).group().split("\t")[0] for line in MeCab.Tagger().parse(text).splitlines()[:-1]]

def nouns(text):
    p = re.compile(".+\t[A-Z]+")
    temp = [tuple(p.match(line).group().split("\t")) for line in MeCab.Tagger().parse(text).splitlines()[:-1]]
    nouns=[]
    for word in temp:
        if word[1] in ["NNG", "NNP", "NNB", "NNBC", "NP", "NR"]:
            nouns.append(word[0])
    return nouns

def cln(text):
    return re.sub("[^ㄱ-ㅣ가-힣 ]", "", text)

def def_sw(path):
    sw = set()
    for i in string.punctuation:
        sw.add(i)
    with open(path, encoding="utf-8") as f:
        for word in f:
            sw.add(word.split("\n")[0])
    return sw

sw = def_sw("stopwords-ko.txt")

# %%
raw_data = pd.read_excel("카톡.xlsx", index_col=0)

# %%
data = raw_data

msgs = [msg for msg in data["msg"]]

# %%
msgs
# Out:
# ['새우당 예약불가네..',
#  '빨리 갈수 있는사람 가서 웨이팅 고고',
#  '그정도 식당임?',
#  '전 빨리 못갑니다',
#  '오키도키',
#  '님들 다 7시에 도착가능?',
#  '7시10분 아님?',
#  '7시10분 고',
#  '아 ㅋㅋ',
#  '깨알 10분',
#  '다들 어디?',
#  '샤로수길!',
#  '올',
#  '나 샤대역',
#  '난',
#  '낙성대',
#  '야들아 나 목 간지러움',
#  '망한거?',
#  '?',
#  '긁어',
#  'ㄴㄴ 목 안쪽이 가렵다고',
#  '왜',
#  '몰러 마스크 오래껴서 그런가',
#  '이제내림',
#  '한정거장 빠른거 탔나보다 니가 ㅋㅋ',
#  '여기 사람 별로 없다',
#  '도착?',
#  '다 도착',
#  '알아서 시키삼',
#  'ㅇㅋ',
#  '간장새우 시킴',
#  '거의다옴',
#  '재밌었다 안뇽',
#  'ㅋㅋㅋㅋ난 아직 사당도 못감',
#  '거노 생일즈음에 봅시다',
#  '너도 택시타 ㅋㅋ',
#  '재미있었다 ㅋㅋㅋㅋ 오키도키 ㅌㅋㅋ',
#  '이미 지하철탐ㅌㅋㅋㅋ',
#  '술집 48000 분식 6천 편 5천100',
#  '거노가 대접했으니까',
#  '둘이 내자',
#  '어 나 벌써 보내버림',
#  'ㅋㅋㅋ',
#  '아 감사',
#  '맞아 둘이 먹은 술값이 얼만데!',
#  '그렇다면 다음 모임에서 사줘',
#  'ㅋㅋㅋ',
#  '그래 근데 다음에도 3차는 너네집',
#  'ㅋㅋㅋ이런',
#  '그러네 ㅋㅋㅋㅋㅋ',
#  'array에서 shape 함수 쓰면 몇행 몇열인지 알려주자나',
#  '근데 (34,23,3) 이러면',
#  '3은 무슨 의미냐?',
#  '세번째 인자는 뭘 나타내는겨',
#  '저는 모든걸 알고 있지는 않기 때문에 ㅋㅋㅋ',
#  '코드를 같이 올려주시길 ㅋㅋ',
#  '나 위쪽 함수 써본적 없어서 ㅋㅋ',
#  '세번째 차원의 크기',
#  '넘파이 쓰는거지?',
#  '응',
#  '세번째 차원이 대체 뭐지',
#  'def create_dataset(data,look_back):',
#  'train은 2차원인데 trainX는 3차원이네',
#  '사진',
#  'lstm 쓰려고 52개씩 묶었을 뿐인데 1이 왜생김?',
#  'ㅋㅋㅋlstm이 입력으로 몇차원이 필요한지 찾아봐',
#  '그거에 맞춰서 데이터 형태 변형 많이해ㅋㅋ',
#  '51행1열로 297개를 만든건가보군',
#  'ㅋㅋㅇㅇ',
#  '님들',
#  '주피터에서 plt.show()로 그래프 그리고 자유롭게 확대 축소 하려면 어떻게 해야되냐?',
#  '그 팝업창 뜨지 않어? 어디서 띄움?',
#  '쥬피터?',
#  '응',
#  '별도 창 안뜨고',
#  '그냥 그려지는데?',
#  '아 그 코드를 걍 파이썬 파일로 실행시켜봐',
#  '주피터 말고?',
#  '코드 복사해서 .py 파일로 만들어서 실행시키면',
#  '크기 조절 가능한 창 뜸',
#  '음 주피터는 원래 별도창 안뜨나',
#  '%matplotlib tk',
#  '이렇게 했더니 별도창 뜨는데 돌기만 하다 멈춰버린다',
#  '어 검색해보면 방법이 있을수도🤔',
#  '방법은 맞는거 같은데 마우스 포인터 빙빙 돌기만하고 응답없음 되는건',
#  '컴이 문젠가봐..',
#  'ㅋㅋㅋ내가 알려준 방법으로도 해봐!',
#  '알게쏘',
#  'visual studio로 실행시켜볼랬더니',
#  '모듈 다 깔아야되네 ㅋㅋㅋㅋㅋㅋ',
#  '에라이...',
#  'Vs code',
#  '그냥 파이썬으로 실행하려고 했는데 창 열리더니 걍 꺼짐 ㅋㅋ',
#  '엥 ㅋㅋ',
#  '이정도면 컴이 병신인거냐;;',
#  '아닐껄ㅋㅋ',
#  '세팅이 젤 어려워 첨에',
#  '아 짱나!',
#  '잘래',
#  'ㅋㅋㅋ고생했슈',
#  '한주 또 화이팅 합시더..',
#  'ㅋㅋ열심히 사는걸보니 내가 다 뿌듯하네',
#  'ㅋㅋㅋㅋ멋지넹 ㅋㅋ 시도하는 게 이미 반은 성공한겨',
#  '고프로가 배터리는 한시간 조금 넘나보네',
#  '너꺼 고프로 뭐냐?',
#  '7',
#  '배터리 얼마나 가?',
#  '체감상으로?',
#  '보조배터리로 충전되지?',
#  '음 계속쓰면 한시간반?',
#  '두시간?',
#  '모드 따라 다른데',
#  '나는 그래서 여분 배터리 3개 더 삼',
#  '아 교체할수있어?',
#  '내장형 아님!',
#  '하 얘들아',
#  '동적 크롤링좀 할줄아니...',
#  '막혔는데 진행이 안된다.. 왜 안되는줄 모르곘음 ㅠㅠ',
#  '???',
#  '사진 고고',
#  '자 봐봐',
#  'from selenium import webdriver',
#  '여기까지 실행을 하면',
#  '사진',
#  '이 화면이 나오고',
#  '저 위에 검색창에 어떤 검색어를 넣으려고 하는데',
#  "driver.find_element_by_css_selector('#mainframe\\.VFrameSet\\.HFrameSet\\.VFrameSet1\\.frameTop\\.form\\.edtMenuSearch\\:input').send_keys('cost center')",
#  '왜 이 코드로 되지 않는 것이니',
#  "driver.find_element_by_css_selector('.VFrameSet #nexacontainer .nexainput').send_keys('cost center')",
#  '이것도 안되고',
#  '왜... 왜 안돼!',
#  '흠..오류 메시지좀',
#  '사진',
#  '저 엘레먼트를 못찾어',
#  '사진',
#  '원래 있는 기능이여?',
#  '여기선 찾는데 왜 못찾니',
#  '응 당연하지',
#  '배운대로 했는데 안돼..',
#  '나 지금 술 먹어서',
#  '파악이 안 된다 ㅠㅠ',
#  '내일 고고하자 오늘은 자고',
#  '미안허이 ㅠㅠㅠ',
#  '흐극',
#  '혜영이랑 영화는 봤냐',
#  'ㅋㅋㅋㅋㅋ',
#  '저때 리얼로 술취해서 파악이 안 됐다 ㅋㅋ',
#  'ㄴㄴ 아직',
#  '오늘 알바하는 곳 놀러가긴 함',
#  '알바 뭐하는데??',
#  '대박사건',
#  '근데 나 저거좀 해결해주고 가면 안되냐',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '개웃기네 ㅋㅋㅋㅋㅋ',
#  '우선 이동해야하므로',
#  '이동하면서 볼게 ㅋㅋㅋ',
#  '구랫... ㅠㅠ',
#  '알바 어디서 하는데?',
#  '아니 무슨 알바?',
#  '카페알바ㅋㅋㅋ',
#  '몇시에 끝나는데 ㅋㅋ',
#  '일산 ㅋㅋㅋ 멀다 ㅋㅋㅋ',
#  '알바 끝나는거 기다려서',
#  '둘이 만나서 데이트 한다...',
#  'ㄴㄴ 불가',
#  '이건 완전 연인인데',
#  '12시반에 끝남',
#  '뭐여..',
#  '그럼에도 불구하고 그 지극정성은',
#  'ㅋㅋㅋ',
#  '남친 있는지 확인했냐?',
#  '화요일날 만나니까',
#  '그때 확인하려고',
#  '늦나??',
#  '그때 뭐하기로 했는데?',
#  '같이 밥먹기로 했음',
#  '저녁?',
#  '그냥 밥만?',
#  '메뉴는?',
#  '아직 안 정함',
#  '그럼 소주에 삼겹살 먹는거 어때',
#  '아 정한건 있다',
#  '회 먹자고 했으 ㅋㅋ',
#  '회 먹으면 무조건 소주 아녀?',
#  'ㅋㅋㅋㅋ제안은 해봐야할듯',
#  '종범쓰 저거 아직 해결못함?',
#  '다른거 처리할게 좀 있어서 이제 볼 수 있을거 같은디',
#  '안돼서 포기하고 딴거하는중..',
#  '그 검색창에 검색어를 넣으려면',
#  'css selector을 뭘 넣으면 되는지좀 ㅠㅠ',
#  '그거말고 무슨 버튼 클릭하는거 해볼려고 해도 안된다;;',
#  'ㅋㅋㅋㅋㅋㅋ ㅠㅠ 오키도키',
#  'find_element_by_class',
#  '이걸로 쓰면 안되는건가?',
#  'class_name 써도 되지',
#  '찾기만 하면 상관없어',
#  'ㅇㅇ 그걸로 해봐',
#  '그렇게 해도 안돼..',
#  '흠? 그 기능으로',
#  '다른 element는 찾아짐?',
#  '너가 원하는거 말고 다른거',
#  '응 찾아지더라구',
#  '근데 찾는걸 못찾곘어',
#  '검색창이랑 +버튼 같은거',
#  '흠 저건 돌려봐야 알거 같은디',
#  '너 카페에 있는거야?',
#  'ㄴㄴ 아직 이동중',
#  '개멀엌ㅋㅋㅋ',
#  '가서 뭐하게?',
#  '공부',
#  '진짜 좋아하는 구나 내영아',
#  'ㅋㅋㅋ종로쪽에 약 살거 있어서 간 김에 가는건디',
#  '이렇게 멀줄 예상못했다 ㅋㅋㅋ',
#  '종로랑 일산이랑 뭔상관이여 ㅋㅋㅋㅋㅋ',
#  '서울가는 김에 ㅋㅋㅋㅋ 가보려고 했지 ㅋㅋㅋ',
#  '그냥 좋다고 말해 ㅋㅋㅋ',
#  'https://stackoverflow.com/questions/19536954/what-is-the-best-way-to-avoid-nosuchelementexception-in-selenium',
#  '그거 element가 없어서 그런 게 아니라 시간문제 때문에 그런듯',
#  '링크건 거 두번째 답 읽어봐봐',
#  '페이지가 넘어가기 전에 엘레멘트를 찾았다는 건가?',
#  '아직 안 읽어봤지만',
#  'ㅇㅇ 맞음',
#  '그래서 페이지 다 받아지고 아서로 변경해봐봐',
#  '그걸 어떻게 하는데??',
#  'wait?',
#  '답변 되어있잖수',
#  'ㅇㅇㅇ',
#  '그거대로 설정해서 돌려봐',
#  '영어가 너무 길면 읽기 싫어져...',
#  '오케이! 해볼게',
#  '보통 오류났을 때 오류메시지 구글에서 찾고',
#  '그거 해보는 식으로',
#  '문제해결 하는 게 젤 빠름',
#  '한글만 찾아서 ㅋㅋㅋㅋ',
#  '알게써!',
#  'ㅋㅋㅋㅋ한글로는 잘 안 나옴ㅋㅋㅋ',
#  '이거 되면 내영이 업어준다',
#  '이열ㅋㅋㅋ',
#  '안되는디... ㅠ',
#  'driver.find_element_by_xpath("//input[@class=\'nexainput\']").send_keys(\'협력회사조회\')',
#  '일케 하니까 되네....',
#  'Xpath로 해야하는건가',
#  '이유를 찾아봐야겠네',
#  '이해가 안간다',
#  '왜 그런지',
#  '근데 이번엔 또 double_click() 일케 하면',
#  'reacterable하지 않다고 함',
#  '아 여기 사이트는',
#  '왜 더블클릭만 안되지',
#  '아 됐다 ㅋㅋㅋㅋ',
#  'ActionChains 쓰니까 되네',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '굳굳ㅋㅋㅋ',
#  '집이여?',
#  'ㄴㄴ 집 가는 길',
#  '계속 카페에 있었어? ㅋㅋ',
#  'ㄴㄴㄴ 저녁약속 있어서 ㅋㅋㅋ',
#  '애들 만나고 집에 가는중 ㅋㅋ',
#  '일산에서?',
#  'ㄴㄴ 사당',
#  '겁나 인싸다 내영이',
#  '이동거리 ㅎㄷㄷ',
#  '나는 방금 막',
#  '내가 바라던대로 코딩을 완료하였다',
#  '모든 메뉴에 한번씩 들어가서 스크린샷 찍고 닫고 들어가서 찍고 닫고',
#  '하는것 ',
#  '힣',
#  '크',
#  '멋지다',
#  '이것을 만들었음',
#  '동영상',
#  '존나 거노 도와주지도 않고 ㅜㅜ',
#  '건호는 너가 스스로 잘할 수 있다고 믿고 지켜보는 역할이야 ㅋㅋㅋ',
#  '이열 ㅋㅋㅋㅋ 잘했구만',
#  '크으 멋지다 ㅋㅋㅋㅋ 자극받고 잡니당 ㅋㅋ',
#  'ㅋㅋㅋ',
#  '무슨 주인공 성장하는 소년만화여?',
#  '발뻗고 자겠다!',
#  '다들 굿밤~',
#  '예압~ 굿밤 ㅋㅋ',
#  '히밤 잠이 안옴',
#  '출근해여되는데',
#  '눈감고 누워있어 ㅋㅋㅋㅋ',
#  '넌 왜안자',
#  '곧 자려고 ㅋㅋㅋㅋ',
#  '님들아',
#  '어떤 숫자들이 쫙 있을때',
#  '10이상 15미만 15이상 30미만 30이상',
#  '뭐 이런식으로 몇줄로 구간 나누는 함수 있니??',
#  '단 몇줄만으로 나눌수 있는 코드??',
#  '구간 갯수만큼 if문 쓰는거 말고??',
#  'Case문 ㄱㄱ 따로 함수로 만들어져 있는건 input과 output에 정의를 어떤걸 원하느냐에 따라 달라서',
#  'Switch 문이군 ㅋㅋㅋ 여튼 검색 ㄱ',
#  '오키 찾아보겠음',
#  '근디 저거 써도 똑같은거 아녀?',
#  'switch는 부등호 못쓰는거 아냐?',
#  '엇 생각해보니 구간이구나',
#  '안되겠군 ㅋㅋ ㅠ',
#  'ㅋㅋ',
#  '얘들아 머신러닝에서',
#  '계약년월이라는 feature를 20190324 이런식으로 넣었을때',
#  '테스트 셋에서 계약년월이 가까운게 먼것보다 가격에 영향이 있을거 아냐',
#  '그런 시간적인 가까움과 멂을 학습해서 가격에 반영할 수가 있나?',
#  '그냥 단순히 숫자로 20190324라던지 20200120이라던지 숫자를 집어넣어도',
#  '?',
#  '시간을 시간으로서 고려하는게 아니라 단순히 숫자로써 고려하는 건가?',
#  '저걸 시작점에서부터 시간적거리?',
#  '거리?',
#  '같은걸로 변환하거나',
#  '해야지',
#  '시간 차이가 얼마나 나나',
#  '그냥 년월일로 넣으면',
#  '안된다?',
#  '2020.1.1을 0으로 잡으면',
#  '2020.2.1은 31?',
#  '기준 년월일을 잡고 변환해야한다?',
#  '이런식으로?',
#  '저 수치를 보고 컴터가 그냥 어케 이해해',
#  '그러면',
#  '만약 년도만 있어',
#  '그럼 2016,2017,2018,2019',
#  '이렇게 넣으나',
#  '0,1,2,3, 이렇게 넣으나 동일한건가?',
#  '컴퓨터에게는 단지 서로 다른 숫자일 뿐인가?',
#  '만약에 컴퓨터에게 단지 숫자에 불과하다고 하면',
#  '2016 이 더 헷갈릴걸?',
#  '0,1000,23,34 이렇게 아무렇게나 넣은거랑 동일한가?',
#  '데이터 노멀라이즈 찾아봐',
#  '데이터 정규화',
#  '잘 모르겠어',
#  '찾아봐',
#  '공부하세욧!',
#  '야이씨 ㅋㅋㅋ',
#  '아 근데 어떤 feature에서 일정한 상수를 다 빼고 돌려봐도 feature importance가 동일하게 나오는데..',
#  '다른 feature 들은 뭔데?',
#  '그니까',
#  '정리해서 보여줌',
#  '사진',
#  '이것을 가지고 price를 예측하는 머신러닝을 구축한다고 할때',
#  '저대로 학습시킨것과',
#  'lat에서 127을 전부다 빼서 0.161875 이렇게만 만든것 lat으로 둔 것이랑',
#  '학습시켰을때 결과가 거의 똑같더라구',
#  '그럼 정규화의 의미가 없다라는 결론이 나올 수 있는거 아냐?',
#  'ㅋㅋ모델은 뭐임?',
#  'xgb',
#  '하나만 정규화하니까 그렇지',
#  '입력이 지금 여러 컬럼이 들어가는데',
#  '하나의 입력만 크기를 정규화한다고 되는게 아니고',
#  '정규화의 목적이 feature간의 숫자 크기를 통일시킨다 아냐?',
#  '“Feature 간”이라고 말했지만',
#  '127을 뺀다는건',
#  '127 언저리의 큰값을 다 0. 얼마로 줄였는데도 왜 결과가 똑같지',
#  'Feature 내',
#  '니까',
#  '정규화는 모든 feature에 대해 다 해야하는 것이지?',
#  'target value도 해야하나?',
#  '타겟이 분류야 아니면 수치야?',
#  '수치',
#  'price를 예측하는 거니까',
#  '공부해야곘다... ㅋㅋ',
#  '아니 인턴놈들도',
#  '엄청 잘아는거 같다가도 어떨떄 보면 잘몰라',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '종범이 거의 뭐 ㅋㅋㅋㅋ 전공생 되어가네 ㅋㅋㅋ',
#  'ㅎ',
#  '늦게 시작했으니 빨리 배워야지',
#  '크으~멋지구만ㅋㅋㅋ',
#  '진짜',
#  '좀 깊게들어가니까',
#  '죄다 수학이구나',
#  '오 이걸 이렇게 빨리 깨닫다니',
#  'ㅋㅋㅋㅋㅋㅋ종범이 학습능력 개쩌네 ㅋㅋㅋ',
#  '아니 그것은 아니고',
#  '블로그탐방하다보니',
#  '별별 수학개념이 다나오네',
#  '주변에 쉬는 회사 없냐 ㅋㅋ',
#  '농협 안쉬냐?',
#  'ㄴㄴ 안 쉼',
#  '오늘 무슨날임??',
#  '코로나데이 몰라?',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '코로나 시즌이자나 요즘',
#  '둠스데이 시즌',
#  '사재기 하러 가야겠다',
#  '뭐사게',
#  '통조림',
#  '음 참치랑',
#  '고추참치?!',
#  '라면?',
#  '지금 벌써 사놔야되나',
#  '?',
#  '고추참치는 뭐야 ㅋㅋ 배부른걸 사야지않아?',
#  '고추참치는 별미',
#  '오래 보관할수 있는걸로 생각한건데',
#  '배부른곤 뭐가 있을까',
#  '쌀이랑 즉석밥',
#  '하긴 참치있어도',
#  '비벼먹고 뭐해먹고는 되겠다',
#  '아 햇반 사야지ㅋㅋ',
#  '참치 좋지 ㅋㅋㅋ',
#  '오늘 몰에 쉑쉑 오픈해서 가봤다',
#  '첨 먹어봄',
#  '엄청 맛있진 않네',
#  '사진',
#  '하 얘들아 ㅋㅋ',
#  '쫌 도와주라...',
#  'query랑 parse.urlencode 한거랑',
#  '왜 ServiceKey 값이 달라지는 것이지???',
#  '정말 노이핸데???',
#  '사진',
#  '대체 왜 값이 달라지지???',
#  'urlencode를 쓰는게 아닌건가..',
#  '%3 => %253 이렇게 읽히는거 같은디?',
#  'https://stackoverflow.com/questions/4858108/url-to-uri-encoding-changes-a-3d-to-253d',
#  '한글이 아닌데 urlencode를 쓴것이 잘못인ㄱ ㅓ같어',
#  '오',
#  '스스로 해결?!',
#  '오호?',
#  '그럼 딕셔너리 타입의 쿼리를 url이랑 합칠라면',
#  '뭐 어캐해야하는거지',
#  '내가 링크건 거 읽어보면 될듯?',
#  '%3D가 의미하는 걸 저대로 넣지 말고 바꿔서 넣어봐',
#  'Therefore, it is in this final step that, for example, ":" becomes "%3A" (good) and "%3A" becomes "%253A" (bad). Since you are putting in URLs which are already-encoded*, you don\'t want to encode them again.',
#  '이해 못하겠음.. ㅋㅋ',
#  'encode 된 걸 넣느냐 아니면 encode 되기 전껄 넣느냐의 차이인듯',
#  '그니까 인코딩 안하고 딕셔너리를 =이거로 묶어서 넣으려면',
#  '무슨 함수를 써야하는지 모르겠어',
#  '저거 코드 보내봐봐',
#  "url='http://apis.data.go.kr/1611000/AptListService/getRoadnameAptList?'",
#  'full_url을 저렇게 더하기 말고 짧게 하고픔',
#  'query={a:b,c:d}',
#  'query={"roadCode":roadCode}',
#  'url 말고 uri라는것도 있냐.. ㅋㅋ',
#  '첨들어봤네',
#  '공부 고고고',
#  '우리 거노생파 어캐함?',
#  '건호집에서 해야지',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '코로나여서 외부는 좀 그러니까',
#  '건호집에서 비싼 음식 시켜먹자',
#  '어때?',
#  '그래 건호집에서 하자',
#  '건호참석 못하면',
#  '건호없는 건호생파',
#  'ㅋㅋ',
#  '좋네 ㅋㅋㅋㅋㅋ',
#  '뭘먹으면 좋지',
#  '회? 족발? 치킨?',
#  '음 회도 괜찮겠군',
#  '포장해가도 되고',
#  '보쌈족발도 좋겠군',
#  '노량진에서 포장해가도 괜찮을거 같은데',
#  '딱히 멀지 않으니까',
#  '택시타고?',
#  '나 글고 담주 재택이라',
#  '6시 바로 출발 가능 ㅋㅋㅋ',
#  '오잉',
#  '나 생파해?!ㅋㅋㅋ',
#  '그런듯',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '케잌 뭐 좋아함?ㅋㅋㅋ',
#  '샵검색: #투썸 딸기초코 케이크',
#  '요거ㅋㅋㅋ',
#  '우리도 재택근무 ㅇㅇ',
#  '머먹을까',
#  '족보+회+생일케잌 고?',
#  '족보?',
#  '아 족발보쌈',
#  '와 재택근무 개부럽..',
#  '삼성 망해라!',
#  '삼성 망하면 안돼 ㅋㅋㅋ',
#  '주식 샀단말이얔ㅋㅋㅋㅋ',
#  '여튼 그러면 수욜날보는건가?',
#  '빨 정해주셈',
#  '건호쓰 가능?',
#  '헐 생일 당일날?',
#  '잠시만!',
#  '아니면 그 담날이라든가',
#  '헐은 무슨',
#  '언제보자는줄 알었냐',
#  'ㅋㅋ주중은 생각도 못함',
#  '그럼 금욜?',
#  '근데 뭐 엄청 술마시지도 않을거잖어',
#  '주중이어도 상관없을거같은데 ㅋ',
#  '오키 주말내로 답을 주겠슴다',
#  '오키도키 굳굳 ㅋㅋㅋ',
#  '에이블루 커블체어 - http://abluestore.com/product/%EC%BB%A4%EB%B8%94%EC%B2%B4%EC%96%B4-%EB%B0%94%EB%A5%B8%EC%9E%90%EC%84%B8-%EA%B5%90%EC%A0%95%EC%9D%98%EC%9E%90/25/',
#  '이거 좋으려나',
#  '써보고',
#  '후기좀ㅋㅋㅋㅋ',
#  '괜찮으면 사게 ㅋㅋㅋ',
#  '와이더로 세개주문함',
#  'ㅇㅋ',
#  '수요일 ㄱ!',
#  '오키도키',
#  'ㄱ',
#  '낼 출근할듯.. ㅋㅋ',
#  '뭐 먹어 우리',
#  '거노아저씨 머드시고 싶으세요',
#  '거노아자씨',
#  '답이 없네잉 ㅠ',
#  'ㅋㅋ급하구만',
#  '오늘 저냑부터 먹고 답하겠음',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오키도키',
#  '왜냐면 하루전이기 때문이지 ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '소설 양장본을 지를까 말까',
#  '고민중이다',
#  '샵검색: #기다려 훈련',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '모먹!',
#  '근처 마트에서',
#  '와인사갈까',
#  '좋은 아이디어인듯?',
#  '건호 지금 고기 구워먹느라',
#  '정신없음ㅋㅋㅋ',
#  '오 근처에 gs 슈퍼마켓도 있음!',
#  '오늘은 일찍 자련다',
#  '오키도키 ㅋㅋ',
#  '아 저 출근이 늦음 ㅎㅎ;',
#  '일단 집주소좀',
#  '지도: 프라비다162오피스텔',
#  '7시좀 넘어서 도착할듯',
#  'ㅇㅋㅇㅋ',
#  '내영이형도?',
#  '난 아마 7시정도?',
#  '거기 마트커?',
#  '겁나큼',
#  '그럼 딱만나서',
#  '장보고',
#  '배달시킬건 배달하고',
#  '그러자',
#  '오키도키',
#  '그러면 7시 10분정도까지',
#  '도착하면 되나',
#  '?',
#  'ㅇㅋㅇㅋ',
#  '굳',
#  '거노 코로나라는데',
#  'ㅋㅋㅋ',
#  '??',
#  'ㅋㅋㅋㅋ',
#  '근데 병원에선 괜찮다고 함',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '이새끼 신천지 신도 아님?',
#  'ㅋㅋㅋ',
#  '개생뚱맞넼ㅋㅋㅋㅋ',
#  '이만희개새끼!',
#  'ㅋㅋㅋㅋㅋㅋㅋ',
#  '인증 했습니다',
#  '빠른 탈출ㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋ',
#  '코로나 검사하러 감??',
#  '가볼까?',
#  '우선 일반병원가서 감기인지 아니면 다른거인지 확인해보는 게',
#  '좋지 않은감??',
#  '저번주에는 걍 건강하댔음',
#  '하지만 이번주는 코로나?',
#  '퇴근하고 가볼게',
#  'ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ나도 그런줄 알아서 엑스레이랑 ct다 찍었는데',
#  '결론은 역류성식도염ㅋㅋㅋ',
#  '아진짜?!',
#  '스트레스 받아서 그런건가',
#  '아니면 맨날 술먹고 자서?',
#  '음 직장 다니면서 커피+술이 늘다보니까',
#  '그런듯??',
#  '그래서 요새 커피 아예 안 먹고 물만 마시고 술은 거의 안 마시고 있지 ㅋㅋㅋ',
#  '오호',
#  '기관지가 아니고 식도쪽이었그만',
#  '가슴 답답하고 목에 뭐 걸린거 같아서',
#  '기관지인줄 ㅋㅋㅋ',
#  '헐 나돈데!',
#  '자기전에 간식먹고 자서 그런가ㅠ',
#  '내과 가먄 돼?',
#  'ㅇㅇ 그럴 수도 있으',
#  '얍얍',
#  '기침이나 열, 오한같은 거 없으면',
#  '괜찮을거여',
#  '열은 없음ㅋㅋ',
#  '몇주동안 회사에서 계속 체온재는데',
#  '36.7이 맥스',
#  '그럼 크게 문제없을거 같은디',
#  '기침도 없는거 아님?',
#  '기침은 함',
#  '밤에 먹고자는게',
#  '진짜 안좋아',
#  '어제도 밤에 치즈케익 먹고 잤는디',
#  'ㅠ',
#  '우선 내과 가서 여러가지 진단 해보는게 좋을듯',
#  '나 옛날에 야식먹는거 좋아했는데',
#  '이제 잘안머금',
#  '6시반에 출발합니다',
#  '저는 이제 곧 출발합니드아~',
#  '나도!',
#  '가서 집 청소해놔야겠다',
#  '뭐 먹지?',
#  '마트 좌표점',
#  '우리가 물어봤던거 왜니가 되묻냐',
#  '고기나 회',
#  '회+보족',
#  '가즈아!!!',
#  '집에서 고기굽기 가능??',
#  '불가능할듯 ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '아개춥네 오늘',
#  '불가',
#  '나 보족집 알아',
#  '마트에 회 팜!',
#  '나7시10분예상',
#  '집앞도찯이?',
#  '나 설대입구 도착이',
#  '쟈철',
#  '오 족발 시켜야겠다',
#  '중짜 시키고 회 사자',
#  'ㅇㅇ',
#  '사진',
#  '마트랑 집머냐',
#  '불족?',
#  '매운거 못먹는디',
#  '국수포함이면 소가 나을듯',
#  '마트가까움',
#  '소 앖음',
#  '그럼 짐좀놓고가자',
#  '걍와 아저씨',
#  'ㅇㅋ',
#  '안돼',
#  '그래그럼',
#  '담에내림',
#  '몇번출구?',
#  '마트어뎌',
#  '어디냐고 아저씨',
#  '집으로와',
#  '지도 위에보고',
#  '으 배불러',
#  '집',
#  '맛있게 먹은듯ㅋㅋㅋㅋ',
#  '담엔 우리집 초대함',
#  '오키도키 ㅋㅋㅋㅋ 기대하겠으~',
#  '다들 조심히 들어가시길ㅋㅋㅋ',
#  '너만 집가면 댜 ㅋㅋ',
#  'ㅋㅋㅋㅋㅋ거의 다 왔다 ㅋㅋㅋㅋ',
#  '사진',
#  'ㄱㅅㄱㅅ!',
#  '우리 물을 너무안마신듯',
#  '집에오니까 엄청 목마르네',
#  '아 그렇긴한듯...',
#  '집에가서 물 엄청 마셔야겠다',
#  '잔다 ㅅㄱ',
#  'ㅇㅇ ㅂㅂ',
#  '아 나도 스피 다시할까..',
#  'ㅋㅋ',
#  '거노 너하는거 머라거?',
#  'ㅋㅋㅋㅋㅋㅋㅋ얌맠ㅋㅋㅋㅋ',
#  '마지막은 나도 궁금하다',
#  '골드스푼!',
#  '앜ㅋㅋㅋ',
#  '야 이거 가입 못하겠넼ㅋㅋㅋㅋ',
#  '나는 안되겠다 ㅠ 이거 골드스푼이란 게 금수저였구낰ㅋㅋㅋ',
#  '뭐 조건이 뭔데',
#  '수입차량 보유',
#  '저것 중에 하나라도 있어야 함ㅋㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '안해',
#  '허허',
#  '연세메일 없어졌어',
#  '???',
#  '있는데?',
#  '아니야',
#  '서비스 종룐데?',
#  '뭐보고 있다는거지',
#  '아 기존꺼?',
#  '바뀐거 지메일아냐?',
#  '욘세이는 없어진거 아냐?',
#  'ㅇㅇ 그건 없어졌지',
#  '스피에서 학교인증 메일로 하는데',
#  '슈발 어쩌지',
#  '그거 그냥 gmail안게서',
#  '에서',
#  'yonsei.ac.kr 주소쓰는 계정 만들어',
#  '그런것이 있어?',
#  'https://library.yonsei.ac.kr/bbs/content/1_72104?mId=&os=desc&countPerPage=10&searchKey=%EB%A9%94%EC%9D%BC&dateTo=&searchKind=title&dateFrom=&oi=insert_date&',
#  '저기서 하라는 대로 하면 돼',
#  '글고 연세메일 구글드라이브 무제한이니',
#  '유용히 쓰길',
#  '헐진짜?!',
#  '구글드라이브 무제한?!',
#  'ㅇㅇㅇㅇ',
#  '이걸 모르는 사람이 꽤 많네 ㄷㄷ',
#  '2. 기능 및 특징',
#  '원래 쓰던 지메일이랑 별도로 계정하나 만드는건가?',
#  '이거는 연세대가 지메일 시스템 이용하는 대신',
#  'yonsei.ac.kr라는 도메인은 계속 쓸 수 있게 해주는 구조인듯',
#  '이해 안가는 1인',
#  '사진',
#  '그럼 여기서',
#  '저 지메일 누르는게 아니고',
#  '뭐 어째',
#  '아 이따 다시해봐야지',
#  '그냥 로그인 할때',
#  '아이디@yonsei.ac.kr',
#  '해',
#  '아 됐네 ㅎ',
#  '간단한거였군',
#  'ㅇㅇ 굳',
#  '아니 근데',
#  '연세메일로 구글로그인해도',
#  '왜 기존계정으로 자꾸 보이는거야',
#  '사진',
#  '여기가',
#  '이쒸',
#  '통합되는거여?',
#  '오른쪽에',
#  'Google.com',
#  '들어가서 오른쪽 상단 동그라미 눌러서',
#  '계정 yonsei 그걸로 바꿔',
#  'co.kr은 안되고',
#  '.com만 되는건가?',
#  '안됐었는디',
#  '? 너가 어떻게 로그인한지는 모르겠지만',
#  '기존계정 접속한 상태에서 다른 계정 또 들어가면',
#  '사진',
#  '사진',
#  '그래',
#  '이렇게 선택 가능해',
#  '저기서 선택했는데',
#  '기존계정으로 나오더래니께',
#  '그건 됐고',
#  '아 몰라',
#  '맛점해라 ㅋㅋ',
#  '너도 맛점 ㅋㅋㅋ 걍 안되면 기존꺼 다 로그아웃하고',
#  'Yosei껄로 들어가',
#  '그럼 바로 나오겠지 ㅋㅋㅋ 그래도 원래 계정 나오면 너가 링크를 뭔가 잘못 건거일테고',
#  '이거 자세교정이 되긴함',
#  '다리 안꼬게됨',
#  'ㅋㅋㅋㅋ잘 샀군ㅋㅋㅋ',
#  '인생개노잼',
#  '뭐 할게없다',
#  '코로나때문에',
#  'ㅋㅋ심심하긴 하네',
#  '노래방도 못가',
#  '꽃보러도 못가',
#  '여행도 못가',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '하 졸빡',
#  '책읽어 ㅋㅋㅋ',
#  '심지어 운동도 못함',
#  '소설 고고',
#  '그래.. 많이 읽어라',
#  '요즘엔 책시즌 아니다',
#  'ㅋㅋㅋ너무 답답하면',
#  '근처 동네 한바퀴 돌아 ㅋㅋ',
#  '그 정도는 괜찮을듯 싶은데',
#  '여자친구랑 실내에만 있는거 아냐?',
#  '했지',
#  '그것은 아님',
#  '먹으러는 잘다님',
#  '동네 도는것도 노잼',
#  '왜캐추운겨',
#  '하긴 ㅋㅋㅋ 좀 추웠으',
#  '우리나라 겨울이 너무긺',
#  '얘들아',
#  'AWS 써봤니?',
#  '안했다고 말해야지',
#  '선생님 쟤 해봤대요!ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '그거 기업에서 많이들 쓰는거 같던데',
#  '어때? 기능이나 편의성 같은게?',
#  '음 사실 비교대상이 없어서',
#  '걍 쓰는거야ㅋㅋ',
#  '삼성에서 씁니다',
#  '마이크로소프트 점유율 높여가고 있던데',
#  '어떻게 보십니까 성생님',
#  '마소도 뭐 만든게 있어?',
#  '클라우드는 마소, 구글 다 가지고 있지 ㅋㅋ',
#  '마이크로소프트 애저는 2010년 시작된 마이크로소프트의 클라우드 컴퓨팅 플랫폼이다. 2011년 PaaS에 이어 2013년 IaaS 서비스를 시작하였다. 아마존 웹 서비스 등과 경쟁하고 있다',
#  '애저',
#  '이름이',
#  '새끼돼지통구이 요리이름 같네',
#  'bright blue in color like a cloudless sky',
#  '원래 이런뜻',
#  '아무튼',
#  '이번 주말에',
#  'AWS를 공부해야겠어',
#  '오 꾸준히 잘하네ㅋㅋ',
#  '오 ㅋㅋㅋㅋ',
#  '종범이도 이쪽으로 오는건가 ㅋㅋㅋ',
#  '이미 나',
#  '그런 업무만 하고있어',
#  'ㅋㅋ 인생 참',
#  '모른단말이지',
#  'ㅋㅋㅋ오 업무 뭐뭐함?',
#  '와우 ㅋㅋㅋㅋㅋ',
#  '궁금',
#  '저번에 본부장님 앞에서 발표했는데',
#  '꼭 성공시키라고',
#  '신신당부 하심',
#  '뭔디',
#  '뭘 발표한거여 ㅋㅋㅋㅋ',
#  '여러개 할건데',
#  '그중 발표한거는',
#  '적정 분양가 예측?',
#  '적정한 경쟁률로 완판될수있는 분양가랄까',
#  '오 분양가 옵티마이제이션~',
#  '오 성공하면 리얼',
#  '고속승진할듯',
#  '근데 데이터가 없어',
#  '나중에는 돈주고 사고 이럴모양이고',
#  '부동산114 이용해서 앞으로 축적하고',
#  '이럴 계획',
#  '잘 발전시켜서 업무협약 같은거 맺어야할듯',
#  '굳굳',
#  '크으 종범이도 빨리 부자되면 좋겠넹ㅋㅋ',
#  '다들 화이팅',
#  '님들',
#  'XGB나 lightGBM 잘 아는분?',
#  '써본분?',
#  '뒤에꺼는 머르겠다ㅋㅋ',
#  'Xgb는 잠깐 써봄',
#  'lghtGBM이 XGB보다 더 강력하다는 말이 있던데',
#  '요즘에 실거래가 분석하는데',
#  'XGB 쓰고있거든',
#  '하이퍼파라미터들이랑',
#  '플롯 임포턴스의 의미',
#  '이런거 어렵다',
#  '하이퍼파라미터 어떻게 설정해야될지 모르겄네',
#  '엄청 많던데',
#  '이모티콘',
#  'ㅋㅋ그건 노가다해서 감을 찾던가 hyperparameter tuning 이런쪽 찾아봐야해',
#  '으 랜덤포레스트 궁금해서 싸이킷런 코드 뜯어보는데 겁나 복잡하네',
#  'XGB좀 뜯어봐줘 ㅋㅋ',
#  '일단 트리모델부터 공부하겠습니다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ엄청난 조력자다',
#  '넌 왜 공부해?',
#  '쓸일있어?',
#  '나는 나중에 쓸일 있을까봐ㅋㅋ',
#  '내 사업에 또는 ml로 전직할때?',
#  '건호 사업 잘 되감?ㅋㅋ',
#  '3월 매출은 800 순수익 300정도 나왔으',
#  '와ㅋㅋㅋ엄청나다',
#  '매출이 한 두배는 되어야',
#  '수익률 엄청 높네',
#  '월급만큼 순수익 나올듯',
#  '월매출 2000되면 퇴사해도 되겠다',
#  '많이 올랐네 ㅋㅋ',
#  '건호 월급 하늘에 있는거니 ㄷㄷ',
#  '우리 술 언제 머금',
#  '월매출 2000이면 괜찮을듯?',
#  '곧?',
#  '언제 머금',
#  'ㅋㅋ나 바빠..',
#  'ㅋㅋㅋㅋ건호 월매출 2000찍으면?',
#  'ㅋㅋㅋㅋ',
#  '연말에 봅시다',
#  'ㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '사진',
#  '저 학군정보 같은 텍스트는',
#  '어떻게 가져올수있는 거지',
#  '그냥 xpath로는 안되는데',
#  '지원서 지금까지 10명정도 왔다 ㅋㅋ',
#  '연대애들이 반이네',
#  '해외대 애들도 두명이나 있어 ㅋㅋ',
#  '오우 ㅋㅋ 지원 꽤 되는구만',
#  '유디버시티 오브 버지니아 석사 이런애들 뭐야',
#  '왜 이런애들이 지원하는거야..',
#  '취업시장이 얼어서?',
#  '홍콩과학기술대학교 뭐야',
#  'ㅋㅋㅋㅋㅋ아닠ㅋㅋㅋㅋ',
#  '홍코과기대가 왜 거기있엌ㅋㅋㅋㅋ',
#  '오버스펙인데;',
#  '유니버스티 오브 로체스터 뭐야',
#  '무서워',
#  'ㄷㄷㄷ하네...',
#  '다들 월급 얼마 주는지 알고서 지원한건가...',
#  '명시해놨지',
#  '진짜 취업이 안되나부다',
#  '뭐지...저 정도 스펙이면 다른데서도',
#  '잘 나갈거 같은디',
#  '네이버 들어갈만한 애들이',
#  '지원했어',
#  '그러니까 ㄷㄷㄷ',
#  '와 그러게ㅋㅋ',
#  '미쵸따리',
#  '엄청 부담되네',
#  '아니 카네기 멜런 대학교 뭐야',
#  '뭐야 대체',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '어벤져스냨ㅋㅋㅋㅋ',
#  '이러다 하버드생 지원할 기세;;',
#  '버지니아 공대 없는데 다행이다',
#  '너네 회사 대단한듯',
#  '하 얘네들 일시킬 만한',
#  '대가리 없는데...',
#  'ㅋㅋㅋㅋㅋㅋ',
#  '일 시키면',
#  "'이걸 왜 이렇게 하지?'",
#  '이러는거 아녀?ㅋㅋㅋ',
#  '우리회사 와보면',
#  '문화충격 클텐데',
#  '그리고 그렇게 뛰어난 친구가 짠 코드',
#  '1도 이해 못할 자신 있다',
#  'ㅋㅋㅋㅋㅋ그런 친구가 짠 코드를 이해할 수 있으면',
#  '이직 고고하자',
#  '지금 회사에는 있기 아까운 인재다 ㅋㅋ',
#  '긍정적으로 생각하면',
#  '엄청나게 많이 배우겠다',
#  '맨날 야근해야겠다... 지금까지도 공부한다고 야근 많이 했는데',
#  '오호 gradient boosting 이 이런것이었군!',
#  '깨달음의 경지?ㅋㅋㅋ',
#  '개념 자체도 어려버~',
#  '애들 이런거 물어보려고 하는데 면접때',
#  '어떤거 같음?',
#  '사진',
#  'ㅋㅋㅋ질문에 어제 형이 해본것도 넣었네ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '맞아써',
#  'ㅋㅋ트리모델을 사용하기로 내부적으로 결정한거야?',
#  '아니 전에 썼던게 주로 트리 모델이라 ㅎㅎ',
#  '언제든지 바꿀수 있지',
#  '성능만 좋으면',
#  'ㅋㅋ좋구만',
#  '똑똑한 인턴애가 이거 쓰자 그러면 상황봐서 바꿀것',
#  'MLP도 썼었는데 성능이 별로더라고 그거 짠애가 잘못 짰었는지 어쨌는지',
#  '아 뉴럴넷은 잘되는 데이터가 있고 아닌게 있어서',
#  '형이 쓰는 데이터는 기존 ml이 더 잘될거야',
#  '왜??',
#  '어떻게 알아?',
#  '나는 해봤으니까ㅋㅋ',
#  '캐글타이타닉 이런 데이터셋 딥러닝으로 하면 겁나 안됨',
#  '카테고리컬 데이터랑 수치 데이터랑',
#  '다 노멀라이즈 안된 상태로 들어가고',
#  '노멀라이즈해도',
#  '뉴럴넷이 멍청해서 그 변수들간의 차이나 특성을 잘 못배워',
#  '이미지나 음성 같이 데이터가 풍부하거나',
#  '텍스트도 데이터 겁나 많아야 학습되고',
#  '워드투벡 처럼 프리 트레이닝이 있어야 좀 성능 나는데',
#  '형네 데이타는 컬럼도 적고 다른 의미를 가지고',
#  '암튼 mlp는 멍청해서 그런거 잘 못해',
#  '호',
#  '글쿠나',
#  '우리 하는건 그럼',
#  '그래서 아주 예전에 mlp가 찬밥 신세였던거야',
#  '딥러닝보다 머신러닝이 적합한건가',
#  'ㅇㅇ',
#  '오케이',
#  '좋은 어드바이스였어',
#  '이모티콘',
#  'ㅋㅋ',
#  '그럼 나도 인강듣기로한거',
#  '딥러닝입문말고 머신러닝 심화를 듣는게나으려나',
#  'ㅇㅇㅇ',
#  '아님 머신러닝은 독학으로 되려나',
#  '그걸 추천함',
#  '그래?',
#  '난 유츕으로 들어',
#  '난 영어 못해.. ㅋㅋ',
#  'XGBoost Regressor: https://www.youtube.com/watch?v=OtD8wVaFm6E',
#  '딥러닝 배워도 별로여?',
#  'ㅋㅋ나는 들으면서 깃헙에 정리중',
#  '딥러닝 배우는건 좋지',
#  '땡큐땡큐',
#  '근데 형의 문제를 해결하기에 적합한건 ml',
#  '이거 다 영어야',
#  'ㅋㅋㅋㅋ',
#  '미래를 생각해서 딥러닝 들을라했던거야',
#  '머신러닝은 독학하고',
#  '음 딥러닝 미래는 어떨지 모르겠음',
#  '데이터 많은게 짱이야',
#  'xgb를 쓸때도 범주형 변수에 대해서 dummification과 encoding 중 encoding을 사용하는게 맞다고 나와있는데',
#  '그게 맞는거야??',
#  'https://stackoverrun.com/ko/q/9444853',
#  '여기선 그렇게 설명하고 있네',
#  'dummification은 클래스 간에 상관관계가 있다고 학습시킬 우려가 있다는 것 같은데',
#  '번역 이상해서 오히려 이해가 안도ㅑ',
#  '영문인데?',
#  '너가 번역된 페이지 보고있는거 아냐?',
#  '사진',
#  'ㅇㅇ 영문이자나?',
#  '아 그니까 클래스대로 1,2,3 대신 원핫엔코딩',
#  '형 링크는 한글이라 바꿈',
#  'a b c를 단순히 0, 1, 2로 변환해선 안되고',
#  '원핫엔코딩이 좋다는 맞음',
#  '1,0,0 0,1,0 이렇게 넣으라는 거자나?',
#  '저게 정답인지 그냥 의견인지',
#  '어떻게 생각해?',
#  '아 맞다고?',
#  '나는 동의함',
#  '추가적으로 원핫 엔코딩도 한계가 있어서 특정 길이 벡터공간에 임베딩해서 사용하기도 함',
#  '0, 1, 2로 바꾸면 연속형 변수로 오해할수 있나?',
#  'ㅇㅇ',
#  '그렇군',
#  '벡터공간 임베딩은 뭔말인지 모르곘네 ㅠ',
#  '예를 들어 0,1,2 밖에 없던 세상에 새로운 카테고리가 생기면',
#  '3을 만들어야하는디',
#  '그렇지',
#  '처음부터 [1,0,0] [0,1,0] 이러면 나중에 문제가 되기도 하고',
#  '그러네',
#  ...]

# %%
msgs_joined = " ".join(msgs)

tot_tkns = morphs(msgs_joined)
tot_tkns = [tkn for tkn in tot_tkns if tkn not in sw and len(tkn)>=2]

# %%
tot_tkns
# Out:
# ['우당',
#  '예약',
#  '불가',
#  '빨리',
#  '사람',
#  '웨이팅',
#  '고고',
#  '정도',
#  '식당',
#  '빨리',
#  '갑니다',
#  '오키',
#  '도키',
#  '도착',
#  '가능',
#  '10',
#  '아님',
#  '10',
#  'ㅋㅋ',
#  '깨알',
#  '10',
#  '대역',
#  '낙성대',
#  '간지러움',
#  '망한',
#  '안쪽',
#  '가렵',
#  '다고',
#  '몰러',
#  '마스크',
#  '오래',
#  '껴서',
#  '그런가',
#  '이제',
#  '내림',
#  '정거장',
#  '빠른',
#  '보다',
#  'ㅋㅋ',
#  '사람',
#  '별로',
#  '도착',
#  '도착',
#  '아서',
#  '시키',
#  'ㅇㅋ',
#  '간장',
#  '새우',
#  '시킴',
#  '재밌',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '아직',
#  '사당',
#  '생일',
#  '즈음',
#  '봅시다',
#  '택시',
#  'ㅋㅋ',
#  '재미있',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '오키',
#  'ㅌㅋㅋ',
#  '이미',
#  '지하철',
#  'ㅌㅋㅋㅋ',
#  '술집',
#  '48000',
#  '분식',
#  '100',
#  '노가',
#  '대접',
#  '으니까',
#  '내자',
#  '벌써',
#  '보내',
#  '버림',
#  'ㅋㅋㅋ',
#  '감사',
#  '술값',
#  '얼만데',
#  '그렇',
#  '다면',
#  '모임',
#  'ㅋㅋㅋ',
#  '근데',
#  'ㅋㅋㅋ',
#  '그러',
#  'ㅋㅋㅋ',
#  'ㅋㅋ',
#  'array',
#  'shape',
#  '함수',
#  '인지',
#  '알려',
#  '근데',
#  '34',
#  '23',
#  '이러',
#  '의미',
#  '인자',
#  '나타내',
#  '는겨',
#  '모든',
#  '때문',
#  'ㅋㅋㅋ',
#  '코드',
#  '올려',
#  'ㅋㅋ',
#  '위쪽',
#  '함수',
#  '어서',
#  'ㅋㅋ',
#  '차원',
#  '크기',
#  '파이',
#  '차원',
#  '대체',
#  'def',
#  'create',
#  'dataset',
#  'data',
#  'look',
#  'back',
#  'train',
#  '차원',
#  '인데',
#  'trainX',
#  '차원',
#  '사진',
#  'lstm',
#  '려고',
#  '52',
#  '인데',
#  '생김',
#  'ㅋㅋㅋ',
#  'lstm',
#  '입력',
#  '차원',
#  '필요',
#  '한지',
#  '그거',
#  '맞춰서',
#  '데이터',
#  '형태',
#  '변형',
#  '많이',
#  'ㅋㅋ',
#  '51',
#  '297',
#  '만든',
#  '건가',
#  'ㅋㅋ',
#  'ㅇㅇ',
#  '주피터',
#  'plt',
#  'show',
#  '그래프',
#  '자유',
#  '확대',
#  '축소',
#  '려면',
#  '해야',
#  '팝업',
#  '띄움',
#  '피터',
#  '별도',
#  '그냥',
#  '그려',
#  '는데',
#  '코드',
#  '파이썬',
#  '파일',
#  '실행',
#  '시켜',
#  '주피터',
#  '코드',
#  '복사',
#  '해서',
#  'py',
#  '파일',
#  '만들',
#  '어서',
#  '실행',
#  '시키',
#  '크기',
#  '조절',
#  '가능',
#  '주피터',
#  '원래',
#  '도창',
#  'matplotlib',
#  'tk',
#  '이렇게',
#  '더니',
#  '도창',
#  '멈춰',
#  '버린다',
#  '검색',
#  '방법',
#  '방법',
#  '은데',
#  '마우스',
#  '포인터',
#  '빙빙',
#  '응답',
#  '젠가',
#  'ㅋㅋㅋ',
#  '알려준',
#  '방법',
#  'visual',
#  'studio',
#  '실행',
#  '시켜',
#  '랬더니',
#  '모듈',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '에라이',
#  '..',
#  'Vs',
#  'code',
#  '그냥',
#  '파이썬',
#  '실행',
#  '려고',
#  '는데',
#  '열리',
#  '더니',
#  '꺼짐',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '정도',
#  '병신',
#  ';;',
#  '아닐',
#  'ㅋㅋ',
#  '세팅',
#  '어려워',
#  '잘래',
#  'ㅋㅋㅋ',
#  '고생',
#  '화이팅',
#  '시더',
#  'ㅋㅋ',
#  '열심히',
#  '뿌듯',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '멋지',
#  'ㅋㅋ',
#  '시도',
#  '이미',
#  '성공',
#  '프로',
#  '배터리',
#  '프로',
#  '배터리',
#  '체감',
#  '보조',
#  '배터리',
#  '충전',
#  '계속',
#  '모드',
#  '여분',
#  '배터리',
#  '교체',
#  '내장',
#  '아님',
#  '동적',
#  '크롤링',
#  '..',
#  '막혔',
#  '는데',
#  '진행',
#  '된다',
#  '모르',
#  '곘음',
#  'ㅠㅠ',
#  '??',
#  '사진',
#  '고고',
#  'from',
#  'selenium',
#  'import',
#  'webdriver',
#  '실행',
#  '사진',
#  '화면',
#  '나오',
#  '검색창',
#  '검색어',
#  '으려고',
#  '는데',
#  'driver',
#  'find',
#  'element',
#  'by',
#  'css',
#  'selector',
#  "'#",
#  'mainframe',
#  '\\.',
#  'VFrameSet',
#  '\\.',
#  'HFrameSet',
#  '\\.',
#  'VFrameSet',
#  '\\.',
#  'frameTop',
#  '\\.',
#  'form',
#  '\\.',
#  'edtMenuSearch',
#  '\\:',
#  'input',
#  "').",
#  'send',
#  'keys',
#  'cost',
#  'center',
#  "')",
#  '코드',
#  'driver',
#  'find',
#  'element',
#  'by',
#  'css',
#  'selector',
#  "'.",
#  'VFrameSet',
#  'nexacontainer',
#  'nexainput',
#  "').",
#  'send',
#  'keys',
#  'cost',
#  'center',
#  "')",
#  '..',
#  '오류',
#  '메시지',
#  '사진',
#  '엘레',
#  '사진',
#  '원래',
#  '기능',
#  '는데',
#  '당연',
#  '배운',
#  '대로',
#  '는데',
#  '지금',
#  '어서',
#  '파악',
#  '된다',
#  'ㅠㅠ',
#  '내일',
#  '고고',
#  '오늘',
#  '미안',
#  '허이',
#  'ㅠㅠㅠ',
#  '혜영',
#  '이랑',
#  '영화',
#  'ㅋㅋㅋ',
#  'ㅋㅋ',
#  '리얼',
#  '취해서',
#  '파악',
#  'ㅋㅋ',
#  '아직',
#  '오늘',
#  '는데',
#  '대박',
#  '사건',
#  '근데',
#  '저거',
#  '해결',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '웃기',
#  'ㅋㅋㅋ',
#  'ㅋㅋ',
#  '이동',
#  '해야',
#  '므로',
#  '이동',
#  '면서',
#  'ㅋㅋㅋ',
#  '..',
#  'ㅠㅠ',
#  '는데',
#  '알바',
#  '카페',
#  '알바',
#  'ㅋㅋㅋ',
#  '끝나',
#  '는데',
#  'ㅋㅋ',
#  '일산',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '끝나',
#  '기다려서',
#  '만나',
#  '데이트',
#  '한다',
#  '..',
#  '불가',
#  '이건',
#  '완전',
#  '연인',
#  '인데',
#  '12',
#  '끝남',
#  '그럼에도',
#  '불구',
#  '지극정성',
#  'ㅋㅋㅋ',
#  '남친',
#  '는지',
#  '확인',
#  '화요일',
#  '만나',
#  '니까',
#  '확인',
#  '려고',
#  '는데',
#  '저녁',
#  '그냥',
#  '메뉴',
#  '아직',
#  '정함',
#  '소주',
#  '삼겹살',
#  '정한',
#  '자고',
#  'ㅋㅋ',
#  '으면',
#  '무조건',
#  '소주',
#  '아녀',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '제안',
#  '봐야',
#  '종범',
#  '저거',
#  '아직',
#  '해결',
#  '처리',
#  '어서',
#  '이제',
#  '은디',
#  '돼서',
#  '포기',
#  '검색창',
#  '검색어',
#  '으려면',
#  'css',
#  'selector',
#  '으면',
#  '는지',
#  'ㅠㅠ',
#  '그거',
#  '버튼',
#  '클릭',
#  '볼려고',
#  '해도',
#  '된다',
#  ';;',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅠㅠ',
#  '오키',
#  'find',
#  'element',
#  'by',
#  'class',
#  '이걸로',
#  '건가',
#  'class',
#  'name',
#  '써도',
#  '상관없',
#  'ㅇㅇ',
#  '그걸로',
#  '그렇게',
#  '해도',
#  '기능',
#  'element',
#  '더라구',
#  '근데',
#  '곘어',
#  '검색창',
#  '이랑',
#  '버튼',
#  '저건',
#  '돌려',
#  '봐야',
#  '은디',
#  '카페',
#  '아직',
#  '동중',
#  '엌ㅋㅋㅋ',
#  '공부',
#  '진짜',
#  '구나',
#  '내영',
#  'ㅋㅋㅋ',
#  '종로',
#  '어서',
#  '건디',
#  '이렇게',
#  '예상',
#  'ㅋㅋㅋ',
#  '종로',
#  '일산',
#  '이랑',
#  '상관',
#  'ㅋㅋㅋ',
#  'ㅋㅋ',
#  '서울',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '려고',
#  'ㅋㅋㅋ',
#  '그냥',
#  '다고',
#  'ㅋㅋㅋ',
#  'https',
#  'stackoverflow',
#  'com',
#  'questions',
#  '19536954',
#  'what',
#  'is',
#  'the',
#  'best',
#  'way',
#  'to',
#  'avoid',
#  'nosuchelementexception',
#  'in',
#  'selenium',
#  '그거',
#  'element',
#  '어서',
#  '그런',
#  '문제',
#  '때문',
#  '그런',
#  '링크',
#  '페이지',
#  '넘어가',
#  '엘레',
#  '다는',
#  '건가',
#  '아직',
#  'ㅇㅇ',
#  '맞음',
#  '페이지',
#  '아서',
#  '변경',
#  '그걸',
#  '는데',
#  'wait',
#  '답변',
#  '잖수',
#  'ㅇㅇㅇ',
#  '그거',
#  '대로',
#  '설정',
#  '해서',
#  '돌려',
#  '영어',
#  '너무',
#  '..',
#  '오케이',
#  '보통',
#  '오류',
#  '오류',
#  '메시지',
#  '구글',
#  '그거',
#  '문제',
#  '해결',
#  '빠름',
#  '한글',
#  '아서',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '한글',
#  '나옴',
#  'ㅋㅋㅋ',
#  '이거',
#  '내영',
#  '준다',
#  'ㅋㅋㅋ',
#  '는디',
#  '..',
#  'driver',
#  'find',
#  'element',
#  'by',
#  'xpath',
#  '"//',
#  'input',
#  'class',
#  "='",
#  'nexainput',
#  '\']").',
#  'send',
#  'keys',
#  '협력',
#  '회사',
#  '조회',
#  "')",
#  '니까',
#  '...',
#  'Xpath',
#  '해야',
#  '건가',
#  '이유',
#  '봐야',
#  '이해',
#  '간다',
#  '그런지',
#  '근데',
#  'double',
#  'click',
#  'reacterable',
#  '다고',
#  '사이트',
#  '더블클릭',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ActionChains',
#  '니까',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '계속',
#  '카페',
#  'ㅋㅋ',
#  '저녁',
#  '약속',
#  '어서',
#  'ㅋㅋㅋ',
#  '만나',
#  'ㅋㅋ',
#  '일산',
#  '사당',
#  '겁나',
#  '내영',
#  '동거리',
#  '방금',
#  '바라',
#  '대로',
#  '코딩',
#  '완료',
#  '모든',
#  '메뉴',
#  '들어가',
#  '스크린',
#  '들어가',
#  '멋지',
#  '만들',
#  '동영상',
#  '존나',
#  '도와',
#  'ㅜㅜ',
#  '건호',
#  '스스로',
#  '다고',
#  '지켜보',
#  '역할',
#  'ㅋㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '구만',
#  '크으',
#  '멋지',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '자극',
#  '니당',
#  'ㅋㅋ',
#  'ㅋㅋㅋ',
#  '주인공',
#  '성장',
#  '소년',
#  '만화',
#  'ㅋㅋ',
#  '히밤',
#  '출근',
#  '눈감',
#  '누워',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '려고',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '숫자',
#  '10',
#  '15',
#  '미만',
#  '15',
#  '30',
#  '미만',
#  '30',
#  '구간',
#  '나누',
#  '함수',
#  '나눌',
#  '코드',
#  '구간',
#  '만큼',
#  'if',
#  'Case',
#  '따로',
#  '함수',
#  '만들',
#  'input',
#  'output',
#  '정의',
#  '원하',
#  '느냐',
#  '달라서',
#  'Switch',
#  'ㅋㅋㅋ',
#  '검색',
#  '오키',
#  '찾아보',
#  '근디',
#  '저거',
#  '써도',
#  '똑같',
#  '아녀',
#  'switch',
#  '부등호',
#  '아냐',
#  '생각',
#  '구간',
#  '구나',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '머신',
#  '러닝',
#  '계약',
#  '라는',
#  'feature',
#  '20190324',
#  '테스트',
#  '계약',
#  '가까운',
#  '보다',
#  '가격',
#  '영향',
#  '아냐',
#  '그런',
#  '가까움',
#  '멂을',
#  '학습',
#  '해서',
#  '가격',
#  '반영',
#  '그냥',
#  '단순히',
#  '숫자',
#  '20190324',
#  '라던지',
#  '20200120',
#  '이라던지',
#  '숫자',
#  '집어넣',
#  '어도',
#  '고려',
#  '단순히',
#  '숫자',
#  '고려',
#  '건가',
#  '저걸',
#  '시작점',
#  '에서부터',
#  '거리',
#  '거리',
#  '걸로',
#  '변환',
#  '거나',
#  '해야지',
#  '차이',
#  '그냥',
#  '월일',
#  '으면',
#  '된다',
#  '2020',
#  '으면',
#  '2020',
#  '31',
#  '기준',
#  '월일',
#  '변환',
#  '해야',
#  '한다',
#  '수치',
#  '그냥',
#  '이해',
#  '그러',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '이렇게',
#  '으나',
#  '이렇게',
#  '으나',
#  '동일',
#  '건가',
#  '컴퓨터',
#  '서로',
#  '숫자',
#  '인가',
#  '컴퓨터',
#  '숫자',
#  '불과',
#  '다고',
#  '2016',
#  '헷갈릴',
#  '1000',
#  '23',
#  '34',
#  '이렇게',
#  '아무렇',
#  '동일',
#  '한가',
#  '데이터',
#  '노멀',
#  '라이즈',
#  '찾아봐',
#  '데이터',
#  '정규',
#  '모르',
#  '찾아봐',
#  '공부',
#  '세욧',
#  '이씨',
#  'ㅋㅋㅋ',
#  '근데',
#  'feature',
#  '일정',
#  '상수',
#  '돌려봐도',
#  'feature',
#  'importance',
#  '동일',
#  '나오',
#  '는데',
#  'feature',
#  '뭔데',
#  '그니까',
#  '정리',
#  '해서',
#  '여줌',
#  '사진',
#  '가지',
#  'price',
#  '예측',
#  '머신',
#  '러닝',
#  '구축',
#  '한다고',
#  '저대',
#  '학습',
#  '시킨',
#  'lat',
#  '127',
#  '161875',
#  '이렇게',
#  '만든',
#  'lat',
#  '이랑',
#  '학습',
#  '시켰',
#  '결과',
#  '똑같',
#  '더라구',
#  '정규',
#  '의미',
#  '라는',
#  '결론',
#  '나올',
#  '아냐',
#  'ㅋㅋ',
#  '모델',
#  'xgb',
#  '정규',
#  '니까',
#  '그렇',
#  '입력',
#  '지금',
#  '여러',
#  '들어가',
#  '는데',
#  '입력',
#  '크기',
#  '정규',
#  '한다고',
#  '정규',
#  '목적',
#  'feature',
#  '숫자',
#  '크기',
#  '통일',
#  '시킨다',
#  '아냐',
#  'Feature',
#  '라고',
#  '127',
#  '뺀다는',
#  '127',
#  '언저리',
#  '줄였',
#  '는데',
#  '결과',
#  '똑같',
#  'Feature',
#  '니까',
#  '정규',
#  '모든',
#  'feature',
#  '대해',
#  '해야',
#  'target',
#  'value',
#  '해야',
#  '분류',
#  '수치',
#  '수치',
#  'price',
#  '예측',
#  '니까',
#  '공부',
#  '해야',
#  '곘다',
#  '..',
#  'ㅋㅋ',
#  '인턴',
#  '엄청',
#  '다가',
#  '어떨',
#  '몰라',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '종범',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '전공',
#  'ㅋㅋㅋ',
#  '시작',
#  '했으니',
#  '빨리',
#  '배워야지',
#  '크으',
#  '멋지',
#  '구만',
#  'ㅋㅋㅋ',
#  '진짜',
#  '들어가',
#  '니까',
#  '죄다',
#  '수학',
#  '구나',
#  '이걸',
#  '이렇게',
#  '빨리',
#  '깨닫',
#  '다니',
#  'ㅋㅋㅋ',
#  'ㅋㅋㅋ',
#  '종범',
#  '학습',
#  '능력',
#  'ㅋㅋㅋ',
#  '그것',
#  '블로그',
#  '탐방',
#  '별별',
#  '수학',
#  '개념',
#  ...]

# %%
text = nltk.Text(tot_tkns)

text.vocab().most_common(20)
# Out:
# [('ㅋㅋ', 239),
#  ('ㅋㅋㅋ', 189),
#  ('는데', 42),
#  ('사진', 30),
#  ('건호', 20),
#  ('오키', 17),
#  ('그냥', 17),
#  ('이렇게', 17),
#  ('..', 17),
#  ('으면', 17),
#  ('데이터', 16),
#  ('건가', 16),
#  ('ㅇㅇ', 16),
#  ('근데', 15),
#  ('해서', 15),
#  ('https', 15),
#  ('그런', 15),
#  ('러닝', 15),
#  ('어서', 14),
#  ('이거', 14)]

# %%
plt.style.use("dark_background")

plt.figure(figsize=(10, 6))

text.plot(30)

plt.savefig("most_common.png")

# %%
words = text.vocab().most_common(1000)

# %%
wc = WordCloud(font_path="C:/Windows/Fonts/HMKMRHD.TTF", background_color="white", width=400, height=400, max_words=30000, max_font_size=80)
wc.generate_from_frequencies(dict(words))

plt.imshow(wc)

wc.to_file("test.png")
