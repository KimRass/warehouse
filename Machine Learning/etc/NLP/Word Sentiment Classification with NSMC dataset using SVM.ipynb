# %%
import json

import os

import re

from pprint import pprint

import string

import json

from tqdm.notebook import tqdm

import MeCab

import nltk

import platform

import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

import numpy as np

# %%
def pos(text):
    p = re.compile(".+\t[A-Z]+")
    return [tuple(p.match(line).group().split("\t")) for line in MeCab.Tagger().parse(text).splitlines()[:-1]]

def morphs(text):
    p = re.compile(".+\t[A-Z]+")
    return [p.match(line).group().split("\t")[0] for line in MeCab.Tagger().parse(text).splitlines()[:-1]]

def nouns(text):
    p = re.compile(".+\t[A-Z]+")
    temp = [tuple(p.match(line).group().split("\t")) for line in MeCab.Tagger().parse(text).splitlines()[:-1]]
    nouns=[]
    for word in temp:
        if word[1] in ["NNG", "NNP", "NNB", "NNBC", "NP", "NR"]:
            nouns.append(word[0])
    return nouns

def cln(text):
    return re.sub("[^가-힣 ]", "", text)

def def_sw(path):
    sw = set()
    for i in string.punctuation:
        sw.add(i)
    with open(path, encoding="utf-8") as f:
        for word in f:
            sw.add(word.split("\n")[0])
    return sw

# %%
sw = def_sw("C:/Users/5CG7092POZ/stopwords-ko.txt")

# %%
# %%time
with open("C:/Users/5CG7092POZ/nsmc-master/ratings_train.txt", encoding="utf-8") as f:
    train_docs = [line.split("\t") for line in f.read().splitlines()][1:]
    
train_data = []
for line in tqdm(train_docs):
    review = line[1]
    label = line[2]
    review_tkn = morphs(cln(review))
    review_tkn = [word for word in review_tkn if (word not in sw)]
    train_data.append((review_tkn, label))

with open("C:/Users/5CG7092POZ/train_data (2).json", "w", encoding="utf-8") as f:
    json.dump(train_data, f, ensure_ascii=False, indent="\t")
    
with open("C:/Users/5CG7092POZ/nsmc-master/ratings_test.txt", encoding="utf-8") as f:
    test_docs = [line.split("\t") for line in f.read().splitlines()][1:]

test_data = []
for line in tqdm(test_docs):
    review = line[1]
    label = line[2]
    review_tkn = morphs(cln(review))
    review_tkn = [word for word in review_tkn if (word not in sw)]
    test_data.append((review_tkn, label))
    
with open("C:/Users/5CG7092POZ/test_data (2).json", "w", encoding="utf-8") as f:
    json.dump(test_data, f, ensure_ascii=False, indent="\t")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=150000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# Wall time: 15min 14s

# %%
train_data
# Out:
# [(['더', '빙', '진짜', '짜증', '네요', '목소리'], '0'),
#  (['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '가볍', '지', '않', '구나'], '1'),
#  (['너무', '재', '밓었다그래서보는것을추천한다'], '0'),
#  (['교도소', '이야기', '구먼', '솔직히', '재미', '는', '없', '다', '평점', '조정'], '0'),
#  (['사이몬페그',
#    '익살',
#    '스런',
#    '연기',
#    '돋보였',
#    '던',
#    '영화',
#    '스파이더맨',
#    '늙',
#    '보이',
#    '기',
#    '만',
#    '했',
#    '던',
#    '커스틴',
#    '던스트',
#    '너무나',
#    '도',
#    '이뻐',
#    '보였',
#    '다'],
#   '1'),
#  (['막',
#    '걸음마',
#    '뗀',
#    '세',
#    '초등',
#    '학교',
#    '학년',
#    '생',
#    '인',
#    '살용',
#    '영화',
#    '별',
#    '반개',
#    '도',
#    '아까움'],
#   '0'),
#  (['원작', '긴장감', '제대로', '살려', '내', '지', '못했', '다'], '0'),
#  (['별',
#    '반개',
#    '도',
#    '아깝',
#    '다',
#    '욕',
#    '나온다',
#    '이응경',
#    '길용우',
#    '연기',
#    '생활',
#    '인지',
#    '정말',
#    '발',
#    '해도',
#    '그것',
#    '보단',
#    '낫',
#    '겟',
#    '다',
#    '납치',
#    '감금',
#    '만',
#    '반복',
#    '반복',
#    '드라마',
#    '는',
#    '가족',
#    '도',
#    '없',
#    '다',
#    '연기',
#    '못',
#    '는',
#    '사람',
#    '만',
#    '모엿'],
#   '0'),
#  (['액션', '없', '는데', '도', '재미', '있', '는', '안', '되', '는', '영화'], '1'),
#  (['케',
#    '평점',
#    '낮',
#    '은',
#    '건데',
#    '꽤',
#    '볼',
#    '만',
#    '헐리우드',
#    '식',
#    '화려',
#    '함',
#    '만',
#    '너무',
#    '길들여져',
#    '있'],
#   '1'),
#  (['걍인피니트가짱이다진짜짱이다'], '1'),
#  (['볼',
#    '마다',
#    '눈물나',
#    '서',
#    '죽',
#    '겠',
#    '다',
#    '대',
#    '향수',
#    '자극',
#    '허진호',
#    '는',
#    '감성',
#    '절제',
#    '멜로',
#    '달인',
#    '다'],
#   '1'),
#  (['울',
#    '면서',
#    '손들',
#    '고',
#    '횡단',
#    '보도',
#    '건널',
#    '뛰쳐나올',
#    '뻔',
#    '이범수',
#    '연기',
#    '드럽',
#    '게',
#    '못해'],
#   '0'),
#  (['담백',
#    '고',
#    '깔끔',
#    '해서',
#    '좋',
#    '다',
#    '신문',
#    '기사',
#    '만',
#    '보다',
#    '보',
#    '면',
#    '자꾸',
#    '잊어버린다',
#    '도',
#    '사람',
#    '었',
#    '다는'],
#   '1'),
#  (['취향',
#    '은',
#    '존중',
#    '한다지만',
#    '진짜',
#    '내생',
#    '극장',
#    '본',
#    '영화',
#    '중',
#    '가장',
#    '노',
#    '잼',
#    '노',
#    '감동',
#    '임',
#    '스토리',
#    '도',
#    '거지',
#    '고',
#    '감동',
#    '도',
#    '어거지'],
#   '0'),
#  (['냥', '긴장', '되', '고', '재', '밋', '음'], '1'),
#  (['사람',
#    '웃긴',
#    '게',
#    '바스코',
#    '이기면',
#    '락스',
#    '코',
#    '라고',
#    '까',
#    '고',
#    '바비',
#    '이기',
#    '면',
#    '아이돌',
#    '라고',
#    '깐다',
#    '그냥',
#    '까',
#    '고',
#    '싶',
#    '어서',
#    '안달',
#    '난',
#    '처럼',
#    '보인다'],
#   '1'),
#  (['굿바이', '레닌', '표절', '인', '은', '이해', '는데', '뒤', '갈수록', '재미없', '지', '냐'], '0'),
#  (['이건',
#    '정말',
#    '깨알',
#    '캐스팅',
#    '질퍽',
#    '지',
#    '않',
#    '은',
#    '산뜻',
#    '한',
#    '내용',
#    '구성',
#    '잘',
#    '버',
#    '무',
#    '러진',
#    '깨알',
#    '드'],
#   '1'),
#  (['약탈자', '위한', '변명', '라', '저놈', '은', '착한', '놈', '절대', '아닌걸요'], '1'),
#  (['나름',
#    '심오',
#    '한',
#    '뜻',
#    '도',
#    '있',
#    '는',
#    '듯',
#    '그냥',
#    '학생',
#    '선생',
#    '놀아나',
#    '는',
#    '영화',
#    '는',
#    '절대',
#    '아님'],
#   '1'),
#  (['보', '면서', '웃', '지', '않', '는', '건', '불', '가능', '다'], '1'),
#  (['재미없',
#    '다',
#    '지루',
#    '고',
#    '같',
#    '은',
#    '음식',
#    '영화',
#    '인데',
#    '도',
#    '바베트',
#    '만찬',
#    '고',
#    '넘',
#    '차이',
#    '남',
#    '바베트',
#    '만찬',
#    '은',
#    '이야기',
#    '도',
#    '있',
#    '고',
#    '음식',
#    '보',
#    '는',
#    '재미',
#    '도',
#    '있',
#    '는데',
#    '이건',
#    '볼',
#    '게',
#    '없',
#    '다',
#    '음식',
#    '도',
#    '별로',
#    '안',
#    '나오',
#    '고',
#    '핀란드',
#    '풍경',
#    '라도',
#    '구경',
#    '할',
#    '랫',
#    '는데',
#    '그것',
#    '도',
#    '별로',
#    '안',
#    '나옴'],
#   '0'),
#  (['절대', '평범', '한', '영화', '아닌', '수작', '라는', '걸', '말씀', '드립니다'], '1'),
#  (['주제', '는', '좋', '은데', '중반', '지루', '다'], '0'),
#  (['다',
#    '짤랐',
#    '꺼',
#    '납득',
#    '할',
#    '수',
#    '없',
#    '었',
#    '던',
#    '거',
#    '그럴',
#    '꺼',
#    '꼭',
#    '그랬',
#    '던',
#    '걸',
#    '꺼야'],
#   '0'),
#  (['고추', '털', '버려야', '할텐데'], '1'),
#  (['카밀라벨', '발연기'], '0'),
#  (['재', '밋', '는', '뎅'], '1'),
#  (['센스', '있', '는', '연출력', '탁월', '한', '캐스팅', '대', '향수', '점'], '1'),
#  (['엄',
#    '포스',
#    '위력',
#    '다시',
#    '한',
#    '번',
#    '깨닫',
#    '게',
#    '해',
#    '준',
#    '적남',
#    '꽃',
#    '검사',
#    '님',
#    '도',
#    '연기',
#    '정말',
#    '좋',
#    '았',
#    '어요',
#    '완전',
#    '명품',
#    '드라마'],
#   '1'),
#  (['졸', '쓰레기', '진부', '고', '말', '도', '안', '됌', '아까워'], '0'),
#  (['재밌', '는데', '별점', '이리', '낮', '은고'], '1'),
#  (['라도', '기대', '했', '던', '내', '죄인', '입니다', '죄인', '입니다'], '0'),
#  (['아직', '도', '드라마', '는', '내인생의', '최고'], '1'),
#  (['패션', '대한', '열정', '안나', '윈투어'], '1'),
#  (['키이라',
#    '나이틀리',
#    '연기',
#    '고자',
#    '했',
#    '던',
#    '건',
#    '대체',
#    '정신',
#    '장애',
#    '일까',
#    '틱',
#    '장애',
#    '일까'],
#   '0'),
#  (['원', '작가', '정신', '나간', '유령', '라', '재미있', '겠', '네요'], '1'),
#  (['포스터', '는', '있', '보이', '는데', '관객', '은', '명'], '0'),
#  (['영화', '이렇게', '평가', '받', '는지', '모르', '겠', '다'], '1'),
#  (['단순', '면서', '은은', '한', '매력', '영화'], '1'),
#  (['다',
#    '알',
#    '바',
#    '생',
#    '인가',
#    '내용',
#    '도',
#    '없',
#    '고',
#    '무서운',
#    '거',
#    '도',
#    '없',
#    '고',
#    '웃긴',
#    '거',
#    '도',
#    '도',
#    '없',
#    '음',
#    '완전',
#    '별',
#    '싱거운',
#    '영화',
#    '내',
#    '넘',
#    '아까',
#    '움',
#    '완전',
#    '낚',
#    '임'],
#   '0'),
#  (['게', '두', '어라', '서리', '한', '굶주렸', '다'], '1'),
#  (['정말', '맘', '어요', '보', '고', '싶', '은데', '보', '는', '방법', '없'], '1'),
#  (['윤제문',
#    '라는',
#    '멋진',
#    '배우',
#    '발견',
#    '게',
#    '됐',
#    '어요',
#    '소소',
#    '한',
#    '일탈',
#    '잔잔',
#    '한',
#    '미소',
#    '머금',
#    '게',
#    '합니다',
#    '음악',
#    '은',
#    '아쉽',
#    '네요',
#    '점',
#    '주',
#    '고',
#    '싶',
#    '은데',
#    '평점',
#    '올리',
#    '고',
#    '싶',
#    '점',
#    '줄',
#    '게요'],
#   '1'),
#  (['평점', '속지', '마시', '길', '낭비', '돈', '낭비', '임'], '0'),
#  (['리얼리티',
#    '뛰어나',
#    '긴',
#    '큰',
#    '공감',
#    '은',
#    '안',
#    '간다',
#    '이민기',
#    '캐릭터',
#    '는',
#    '정신',
#    '학상',
#    '분노',
#    '조절',
#    '장애',
#    '초기',
#    '증상',
#    '거',
#    '다',
#    '툭하면',
#    '사람',
#    '패',
#    '고',
#    '욕',
#    '고',
#    '물건',
#    '파손',
#    '고',
#    '오바',
#    '였',
#    '음',
#    '극',
#    '초반',
#    '엔',
#    '신선',
#    '했',
#    '는데',
#    '면',
#    '갈수록',
#    '이민기',
#    '정신',
#    '상태',
#    '공감',
#    '불가'],
#   '0'),
#  (['마이너스',
#    '는',
#    '없',
#    '냐',
#    '뮤',
#    '비',
#    '보고',
#    '영화',
#    '수준',
#    '알',
#    '만',
#    '더군',
#    '북한',
#    '거',
#    '만들',
#    '라고',
#    '돈',
#    '대주',
#    '던'],
#   '0'),
#  (['난', '영화', '사랑', '합니다'], '0'),
#  (['데너',
#    '리스',
#    '타르',
#    '가르',
#    '엔',
#    '도',
#    '용',
#    '주인',
#    '되',
#    '고',
#    '싶',
#    '다',
#    '누',
#    '이랑',
#    '근친상간',
#    '이나',
#    '고',
#    '다닐지',
#    '라도',
#    '소설',
#    '속',
#    '에선',
#    '제일',
#    '멋진',
#    '놈',
#    '이메',
#    '라니',
#    '스터',
#    '였',
#    '는데',
#    '드라마',
#    '속',
#    '에선',
#    '드래곤',
#    '용',
#    '제일',
#    '멋지',
#    '웃음',
#    '감독',
#    '님',
#    '토르',
#    '다크',
#    '월드',
#    '는',
#    '말',
#    '잡수셨',
#    '을지라도',
#    '기본',
#    '선방',
#    '은',
#    '했',
#    '음'],
#   '1'),
#  (['영화',
#    '사람',
#    '영혼',
#    '어루만져',
#    '줄',
#    '수',
#    '도',
#    '있',
#    '군요',
#    '거친',
#    '세상사',
#    '잊',
#    '고',
#    '동화',
#    '같',
#    '은',
#    '영화',
#    '행복',
#    '했',
#    '네요'],
#   '1'),
#  (['세르게이', '작', '은', '고추', '매운맛', '보여', '주마', '포', '퐁', '저그', '콩', '진호', '간다'],
#   '0'),
#  (['이렇게', '가슴', '시리', '게', '본', '드라마', '있', '을까', '감동', '자체'], '1'),
#  (['난',
#    '꼬마',
#    '애',
#    '원한',
#    '깊',
#    '길래',
#    '했',
#    '더니',
#    '그냥',
#    '나대',
#    '다',
#    '걸',
#    '어쩌',
#    '라고'],
#   '0'),
#  (['재미있', '어요'], '1'),
#  (['전', '좋', '아요'], '1'),
#  (['최고'], '0'),
#  (['너무',
#    '충격',
#    '적',
#    '엇다',
#    '기분',
#    '완전히',
#    '푹',
#    '꺼지',
#    '게',
#    '는',
#    '느낌',
#    '활력',
#    '라고',
#    '는',
#    '도',
#    '없',
#    '는',
#    '너무나',
#    '도',
#    '무거운',
#    '지독',
#    '고',
#    '차갑',
#    '고',
#    '무자비',
#    '다',
#    '일본인',
#    '상상력',
#    '은',
#    '정말',
#    '대단',
#    '한',
#    '거',
#    '같',
#    '다는',
#    '생각',
#    '든다'],
#   '1'),
#  (['심심', '한', '영화'], '0'),
#  (['백봉기', '언제나', '나요'], '1'),
#  (['보', '는', '내내', '그대로', '들어맞', '는', '예측', '카리스마', '없', '는', '악역'], '0'),
#  (['불알', '나와서', '당황', '아무튼', '영화', '중간', '끝', '는', '느낌'], '0'),
#  (['평범', '함', '속', '녹아든', '평범', '한', '일상', '밋밋', '한', '게', '흠'], '0'),
#  (['보',
#    '던',
#    '거',
#    '라',
#    '계속',
#    '보',
#    '고',
#    '있',
#    '는데',
#    '전개',
#    '도',
#    '느리',
#    '고',
#    '주인공',
#    '인',
#    '은희',
#    '는',
#    '한두',
#    '컷',
#    '나오',
#    '면서',
#    '소극',
#    '적',
#    '인',
#    '모습',
#    '짜증',
#    '맨날',
#    '끝',
#    '나나',
#    '기대',
#    '만',
#    '고',
#    '있',
#    '어요',
#    '전개',
#    '빨리빨리'],
#   '0'),
#  (['사랑',
#    '고',
#    '싶',
#    '게',
#    '는',
#    '가슴속',
#    '온',
#    '감정',
#    '헤집',
#    '놓',
#    '는',
#    '영화',
#    '예요',
#    '정말',
#    '최고'],
#   '1'),
#  (['많',
#    '은',
#    '사람',
#    '다큐',
#    '보',
#    '고',
#    '나라',
#    '슬픈',
#    '현대사',
#    '한',
#    '단면',
#    '대해',
#    '깊이',
#    '생각',
#    '고',
#    '사죄',
#    '고',
#    '잡',
#    '기',
#    '위해',
#    '노력',
#    '했',
#    '으면',
#    '합니다',
#    '말',
#    '만',
#    '듣',
#    '던',
#    '보도',
#    '연맹',
#    '민간',
#    '인',
#    '학살',
#    '정도',
#    '줄',
#    '이건',
#    '명백',
#    '한',
#    '살인',
#    '입니다',
#    '살인자',
#    '은',
#    '다',
#    '있',
#    '나요'],
#   '1'),
#  (['예전',
#    '작품',
#    '캐릭터',
#    '에피소드',
#    '재탕',
#    '탕',
#    '사골',
#    '우려먹',
#    '듯',
#    '고',
#    '내용',
#    '은',
#    '산',
#    '고',
#    '시청',
#    '률',
#    '은',
#    '아예',
#    '안',
#    '나오',
#    '고',
#    '이제',
#    '회중',
#    '반',
#    '인데',
#    '부작',
#    '라니'],
#   '0'),
#  (['김남길',
#    '백',
#    '점',
#    '짜리',
#    '연기력',
#    '초반',
#    '몰',
#    '입도',
#    '도',
#    '불구',
#    '고',
#    '지루',
#    '고',
#    '손예진'],
#   '0'),
#  (['재밌', '비슷', '한', '영화', '안', '보', '신', '분', '한테', '는', '재미있', '듯'], '1'),
#  (['노래', '실력', '뽑', '는', '게', '맞', '냐', '박시환', '나가', '면', '진짜', '망신', '다'],
#   '0'),
#  (['일본', '영화', '다', '건가', '유치', '다'], '0'),
#  (['이틀',
#    '만',
#    '다',
#    '봤',
#    '어요',
#    '재밌',
#    '어요',
#    '근데',
#    '차',
#    '안',
#    '물건',
#    '넣',
#    '조작',
#    '려고',
#    '면',
#    '차',
#    '안',
#    '열려',
#    '있',
#    '다던지',
#    '집',
#    '안',
#    '활짝',
#    '열려서',
#    '아무',
#    '들어간다',
#    '던가',
#    '문자',
#    '조작',
#    '려고',
#    '면',
#    '비번',
#    '안',
#    '걸려',
#    '있',
#    '고',
#    '그런',
#    '건',
#    '억지',
#    '스러웠',
#    '는데',
#    '내용',
#    '자체',
#    '는',
#    '좋',
#    '았',
#    '어요'],
#   '1'),
#  (['졸작'], '0'),
#  (['재', '밋', '네요', '달팽이', '빨라서', '더', '재밌', '었', '어요'], '1'),
#  (['어설픈', '전개', '어이없', '는', '결말'], '0'),
#  (['부패',
#    '한',
#    '로마노프',
#    '왕조',
#    '기리',
#    '는',
#    '뭣',
#    '같',
#    '은',
#    '영화',
#    '온몸',
#    '항거',
#    '했',
#    '던',
#    '러시아',
#    '민중',
#    '폭도',
#    '냐'],
#   '0'),
#  (['내용', '전개', '는', '무난', '한', '편', '였', '잘', '보', '았'], '1'),
#  (['매우', '실망'], '0'),
#  (['한국',
#    '영화',
#    '흥행',
#    '코드',
#    '갈등',
#    '갈등',
#    '계',
#    '속',
#    '갈등',
#    '화',
#    '해',
#    '감동',
#    '평점',
#    '점',
#    '남발',
#    '흥행',
#    '뻔',
#    '지',
#    '뭐'],
#   '0'),
#  (['아햏햏', '아햏햏', '아햏햏'], '1'),
#  (['뭐',
#    '냐',
#    '시작',
#    '고',
#    '분',
#    '만',
#    '나왔',
#    '다',
#    '리플릿',
#    '사진',
#    '보',
#    '며',
#    '불안',
#    '더니만'],
#   '0'),
#  (['단연', '최고', '라고', '할', '수', '있', '지'], '1'),
#  (['감독',
#    '럼',
#    '먹',
#    '고',
#    '영화',
#    '만들',
#    '었',
#    '보다',
#    '관객',
#    '뭘',
#    '말',
#    '는지',
#    '도',
#    '모르',
#    '겠',
#    '고',
#    '엉망진창',
#    '개진',
#    '창',
#    '다'],
#   '0'),
#  (['이건', '뭐', '냐', '우뢰매', '냐'], '0'),
#  (['정말', '쓰레기', '영화', '입니다'], '0'),
#  (['진정', '위대', '한', '영화', '최고', '임'], '1'),
#  (['별루', '였', '다'], '0'),
#  (['내일', '기대', '되', '는'], '1'),
#  (['근데', '조미', '막문위', '좋아한', '건가요'], '1'),
#  (['진짜', '골', '깜', '눈', '부라릴', '쓰러짐'], '1'),
#  (['성룡', '영화', '중', '최악', '인', '듯'], '0'),
#  (['골', '때리', '걸스데이', '이혜리', '잘', '되', '라'], '1'),
#  (['서기', '이뻐서'], '1'),
#  (['완전', '재밌', '어요', '백인', '공주', '귀여움'], '1'),
#  (['인상', '적', '인', '영화', '였', '다'], '1'),
#  (['내스', '트', '셀레스틴', '완전', '강추', '요', '정말', '재밌'], '1'),
#  (['재미있', '는', '영화', '입니다'], '1'),
#  (['클라라', '볼라고', '화신', '본', '거', '아닌데'], '0'),
#  (['진짜', '보', '면서', '너무', '슬펐', '던', '영화', '다'], '1'),
#  (['설정',
#    '재밌',
#    '고',
#    '새로운',
#    '에피소드',
#    '내',
#    '메인',
#    '스토리',
#    '도',
#    '차차',
#    '나오',
#    '는',
#    '게',
#    '재밌',
#    '음'],
#   '1'),
#  (['신카이', '마코토', '작화', '미유', '카', '연기', '잘', '해', '줘서', '더', '대박', '였', '다'],
#   '1'),
#  (['재미없', '음', '진심', '훨', '캐스팅', '두', '못한', '듯'], '0'),
#  (['잔잔', '한', '게', '생각', '보다', '볼', '만', '한', '영화', '인', '거', '같'], '1'),
#  (['감독', '님', '고은', '님', '쓰', '면', '영화', '안', '봅니다'], '0'),
#  (['무섭', '지', '도', '않', '았', '고', '스토리', '도'], '0'),
#  (['영화',
#    '속',
#    '억지',
#    '스럽',
#    '고',
#    '노골',
#    '적',
#    '인',
#    '술',
#    '광고',
#    '은은',
#    '고',
#    '센스',
#    '있',
#    '게',
#    '했',
#    '으면',
#    '어땠을까'],
#   '0'),
#  (['킬링', '타임'], '0'),
#  (['크리스마스', '면', '떠오르', '는', '영화'], '1'),
#  (['재미있', '게', '봤', '매력', '적', '인', '행복', '네요'], '1'),
#  (['음악', '완전히', '빠져서', '볼', '수', '있', '었', '던', '영화', '쫌', '산만', '긴', '던데'],
#   '1'),
#  (['태어나', '서', '처음', '영화', '보다', '중간', '나왔', '불륜', '로맨스', '냐'], '0'),
#  (['왕', '짜증', '아주', '전개', '짬뽕', '믹스', '했', '구나', '음향', '만', '무섭', '게', '하네'],
#   '0'),
#  (['솔직히', '난', '별루', '더라', '낭비', '느낌'], '0'),
#  (['대박'], '1'),
#  (['시청',
#    '률',
#    '기준',
#    '되',
#    '는',
#    '패널',
#    '가구',
#    '머',
#    '는',
#    '거',
#    '지',
#    '명작',
#    '드라마',
#    '다',
#    '망치',
#    '내',
#    '다',
#    '서운',
#    '다'],
#   '1'),
#  (['내용', '해'], '0'),
#  (['몬스터', '주식회사', '재밌', '게', '봤', '다'], '1'),
#  (['내용', '전개', '너무나', '느리', '다'], '0'),
#  (['소재', '는', '흥미', '끌', '이야기', '전개', '투박', '해서', '몰입', '안', '되', '는군'], '0'),
#  (['절대', '보', '지', '마', '라', '쓰레기', '영화'], '0'),
#  (['중국인',
#    '특유',
#    '과장',
#    '허풍',
#    '있',
#    '보이',
#    '려고',
#    '안간힘',
#    '쓴',
#    '노력',
#    '은',
#    '가상',
#    '고증',
#    '현실',
#    '감',
#    '떨어지',
#    '는',
#    '설정',
#    '거북',
#    '스럽',
#    '다',
#    '도대체',
#    '은',
#    '이렇게',
#    '스스로',
#    '과대',
#    '포장',
#    '는',
#    '인지'],
#   '0'),
#  (['그냥',
#    '불법체류',
#    '때려잡',
#    '는',
#    '영화',
#    '면',
#    '좋',
#    '았',
#    '텐데',
#    '우상',
#    '화',
#    '만든다고',
#    '미국',
#    '따뜻',
#    '한',
#    '설정',
#    '건',
#    '뭥미'],
#   '0'),
#  (['삶', '속', '주인공', '생애', '드러난', '듯', '다'], '1'),
#  (['별', '점점'], '1'),
#  (['별로', '다'], '0'),
#  (['본지', '꽤', '지난', '후', '남기', '재미있', '었', '음'], '1'),
#  (['이게', '점대', '일까'], '0'),
#  (['지나',
#    '다시',
#    '보',
#    '게',
#    '된',
#    '영화',
#    '다시',
#    '봐도',
#    '순수',
#    '한',
#    '사랑',
#    '감동',
#    '숀펜',
#    '연기'],
#   '1'),
#  (['올레',
#    '공짜',
#    '있',
#    '길래',
#    '봤',
#    '음',
#    '헐',
#    '스토리',
#    '문제',
#    '라',
#    '연기자',
#    '전혀',
#    '배역',
#    '이랑',
#    '어울리',
#    '지',
#    '않',
#    '음',
#    '상대',
#    '배우',
#    '하고',
#    '다',
#    '따로',
#    '노',
#    '는',
#    '거',
#    '같',
#    '음',
#    '이건',
#    '연기자',
#    '도',
#    '문제',
#    '있',
#    '음',
#    '보',
#    '는',
#    '진심',
#    '완전',
#    '별로',
#    '임',
#    '라미란',
#    '하고',
#    '아들',
#    '젤',
#    '볼',
#    '만',
#    '했',
#    '음'],
#   '0'),
#  (['너무',
#    '욕심',
#    '많',
#    '았',
#    '던',
#    '영화',
#    '한',
#    '쪽',
#    '만',
#    '이라도',
#    '제대로',
#    '보여',
#    '줬',
#    '다면'],
#   '0'),
#  (['빵점'], '0'),
#  (['베', '댓', '말', '아주', '잘', '써놨'], '1'),
#  (['아주', '모자라', '진', '않', '다'], '0'),
#  (['영화',
#    '도둑',
#    '이나',
#    '뫼비우스',
#    '고',
#    '같',
#    '은',
#    '나라',
#    '만들',
#    '졌',
#    '다는',
#    '게',
#    '믿',
#    '지',
#    '냐'],
#   '0'),
#  (['온몸', '찌릿', '짜릿', '두', '용기', '가져야지'], '1'),
#  (['정말', '재미있', '고', '교훈', '적', '인', '영화', '네요'], '1'),
#  (['당시', '상황', '주제', '주입식', '아닌', '긴장감', '있', '고', '재밌', '게', '전하', '는', '작품'],
#   '1'),
#  (['케이블', '그만', '나와', '줬', '으면'], '0'),
#  (['다르덴', '이냐리투', '차이밍량', '도', '안', '섞인', '채', '짬뽕', '그릇', '담겨', '있', '다'],
#   '0'),
#  (['여군',
#    '잼',
#    '없',
#    '음',
#    '뭐',
#    '는',
#    '건지',
#    '잼',
#    '없',
#    '음',
#    '엠',
#    '비씨',
#    '다',
#    '잼',
#    '없',
#    '음',
#    '질린다',
#    '이제'],
#   '0'),
#  (['좋', '구나'], '1'),
#  (['한석규', '김혜수', '연기', '만', '돋보인', '영화', '어딘지', '모르', '게', '많이', '어설픈', '영화'],
#   '0'),
#  (['솔직히',
#    '에볼라',
#    '바이러스',
#    '떠들석',
#    '해서',
#    '보',
#    '게',
#    '된',
#    '영화',
#    '인데',
#    '작품',
#    '성',
#    '이나',
#    '면',
#    '도',
#    '여년',
#    '전',
#    '영화',
#    '라고',
#    '보',
#    '기엔',
#    '믿',
#    '기',
#    '힘들',
#    '정도',
#    '정말',
#    '잘',
#    '만들',
#    '었',
#    '다고',
#    '본다',
#    '마지막',
#    '후반부',
#    '살짝',
#    '아쉽',
#    '긴',
#    '정도',
#    '면',
#    '수작',
#    '라고',
#    '본다',
#    '아깝',
#    '지',
#    '않',
#    '은',
#    '영화'],
#   '1'),
#  (['볼', '만', '해'], '0'),
#  (['재미있', '다고', '허풍', '떨', '지', '마세요'], '0'),
#  (['용가리', '진짜', '짱짱', '맨', '다'], '0'),
#  (['영화',
#    '이제서야',
#    '보',
#    '다니',
#    '감히',
#    '내',
#    '인생',
#    '최고',
#    '영화',
#    '중',
#    '꼽',
#    '수',
#    '있',
#    '만',
#    '한',
#    '작품',
#    '살',
#    '할지',
#    '위한',
#    '고민',
#    '한번',
#    '더',
#    '게',
#    '되',
#    '는',
#    '모건',
#    '프리먼',
#    '은',
#    '나이',
#    '들어도',
#    '섹시',
#    '다'],
#   '1'),
#  (['작가',
#    '별로',
#    '다',
#    '내용',
#    '진짜',
#    '별로',
#    '임',
#    '맨날',
#    '그냥',
#    '기대',
#    '고',
#    '재방송',
#    '면',
#    '혹시나',
#    '고',
#    '줘도',
#    '답',
#    '없',
#    '다',
#    '진짜'],
#   '0'),
#  (['명작', '도', '명작', '있', '을까', '싶', '다', '보', '고', '봐도', '여운', '남', '는', '영화'],
#   '1'),
#  (['진짜',
#    '만',
#    '더',
#    '손',
#    '보',
#    '면',
#    '왠만',
#    '한',
#    '상업',
#    '영화',
#    '못지',
#    '않',
#    '게',
#    '퀄리티',
#    '쩔',
#    '게',
#    '만들',
#    '질',
#    '수',
#    '있',
#    '었',
#    '는데',
#    '아쉽',
#    '네요',
#    '충분히',
#    '재미있',
#    '었',
#    '개인',
#    '적',
#    '만',
#    '더',
#    '잔인',
#    '게',
#    '더',
#    '자극',
#    '적',
#    '노출',
#    '씬',
#    '도',
#    '화끈',
#    '게',
#    '했',
#    '더라면',
#    '어땠을까',
#    '는',
#    '국산',
#    '영화',
#    '라',
#    '많이',
#    '아낀',
#    '듯',
#    '보임'],
#   '1'),
#  (['그만', '끌', '고', '이제', '끝', '내라', '지겹', '다', '지겨워'], '0'),
#  ([], '0'),
#  (['역시', '드니로', '연기', '는', '일품', '도', '맥스', '샘', '죽이', '길', '바랬', '다'], '1'),
#  (['나름', '괜찮', '은', '작품', '입니다'], '1'),
#  (['너무', '좋', '은', '영화'], '1'),
#  (['정말', '실망', '스러', '웟음'], '0'),
#  (['배우',
#    '은',
#    '지네',
#    '안',
#    '뜨',
#    '니까',
#    '영화',
#    '찍',
#    '껀',
#    '데',
#    '안',
#    '뜨',
#    '는지',
#    '진짜',
#    '모르',
#    '는',
#    '거',
#    '면상',
#    '보',
#    '면',
#    '알',
#    '겠',
#    '구만',
#    '지네',
#    '은',
#    '모를까'],
#   '0'),
#  (['어린이', '좋', '할', '듯', '내', '릴', '적', '동심', '은', '멀리', '떠', '낫', '보', '다'],
#   '0'),
#  (['무술', '인', '총', '드'], '0'),
#  (['점'], '1'),
#  (['크리스토퍼', '왈츠', '타란티노', '조합', '이란'], '1'),
#  (['한국',
#    '에선',
#    '유명',
#    '한',
#    '편',
#    '은',
#    '외국',
#    '에선',
#    '상상',
#    '초월',
#    '한',
#    '유명',
#    '한',
#    '영화',
#    '입니다'],
#   '1'),
#  (['오랜만', '재', '밋', '는', '영화', '봤', '네요'], '1'),
#  (['종방',
#    '되',
#    '아쉬워',
#    '요',
#    '오늘',
#    '막',
#    '방',
#    '도',
#    '잘',
#    '봤',
#    '어요',
#    '방송',
#    '대본',
#    '꽤',
#    '완성',
#    '도',
#    '있',
#    '다는',
#    '느낌',
#    '받',
#    '았',
#    '고요',
#    '요즘',
#    '드라마',
#    '막장',
#    '지쳐',
#    '있',
#    '었',
#    '는데',
#    '수백',
#    '향',
#    '은',
#    '정말',
#    '바른',
#    '드라마',
#    '였',
#    '던',
#    '듯',
#    '악역',
#    '도',
#    '그리',
#    '심하',
#    '게',
#    '어이없',
#    '지',
#    '도',
#    '않',
#    '았',
#    '고요',
#    '화이팅'],
#   '1'),
#  (['평점',
#    '조절',
#    '위원회',
#    '나왔',
#    '웃음',
#    '김혜선',
#    '은',
#    '내일',
#    '면',
#    '김순',
#    '정순정',
#    '역할',
#    '제일',
#    '다',
#    '팜',
#    '므파탈로써그',
#    '정도',
#    '잘',
#    '해낼',
#    '줄',
#    '은',
#    '정말',
#    '의외',
#    '였',
#    '연기',
#    '한',
#    '사람',
#    '요즘',
#    '사극',
#    '벌어지',
#    '고',
#    '있',
#    '는',
#    '그녀',
#    '대한',
#    '연기',
#    '논란',
#    '은',
#    '왠지',
#    '코미디',
#    '한',
#    '장면',
#    '같',
#    '음',
#    '웃음'],
#   '0'),
#  (['영화',
#    '끝',
#    '나갈',
#    '쯤',
#    '멍하',
#    '다가',
#    '다',
#    '보',
#    '고',
#    '면',
#    '한',
#    '마디',
#    '나올',
#    '거',
#    '임',
#    '같',
#    '다'],
#   '1'),
#  (['공유', '존', '잘'], '1'),
#  (['상쾌',
#    '발랄',
#    '한',
#    '영화',
#    '다',
#    '말',
#    '기',
#    '껄',
#    '끄',
#    '런',
#    '성',
#    '란',
#    '소재',
#    '유쾌',
#    '게',
#    '해설',
#    '했',
#    '다'],
#   '1'),
#  (['소파', '죽', '치', '고', '앉', '지켜', '볼', '이유', '없', '는', '작품'], '0'),
#  (['로큰롤'], '1'),
#  (['주',
#    '된',
#    '타',
#    '겟',
#    '어린이',
#    '니',
#    '일반',
#    '적',
#    '인',
#    '논리',
#    '통하',
#    '지',
#    '않',
#    '는',
#    '건',
#    '알',
#    '겠',
#    '다',
#    '게임',
#    '은',
#    '흥미',
#    '롭',
#    '지',
#    '않',
#    '고',
#    '요원',
#    '라는',
#    '주인공',
#    '너무',
#    '무',
#    '능력',
#    '해서',
#    '별로',
#    '재미없',
#    '다',
#    '배경',
#    '도',
#    '거슬린다'],
#   '0'),
#  (['뮤지컬',
#    '영화',
#    '인데',
#    '사운드',
#    '녹음',
#    '엉망',
#    '남',
#    '주',
#    '는',
#    '춤',
#    '도',
#    '못추',
#    '고',
#    '내용',
#    '은',
#    '뻔할',
#    '뻔',
#    '주인공',
#    '목소리',
#    '도',
#    '너무',
#    '안',
#    '어울리',
#    '고',
#    '어제',
#    '뛰',
#    '나가',
#    '려다',
#    '았',
#    '진심',
#    '말리',
#    '고',
#    '싶',
#    '영국',
#    '예산',
#    '용',
#    '영화',
#    '뮤지컬',
#    '영화',
#    '아닙니다',
#    '맘마',
#    '미아',
#    '도',
#    '안',
#    '됨'],
#   '0'),
#  (['어린', '나이', '봤', '음', '도', '꽤', '좋', '했', '던', '로맨틱', '코미디'], '1'),
#  (['게이', '물', '인', '줄', '모르', '고', '봤'], '0'),
#  (['알바', '는', '꺼', '라'], '0'),
#  (['영화',
#    '머',
#    '임내',
#    '받',
#    '봤',
#    '을까',
#    '그것',
#    '알',
#    '고',
#    '싶',
#    '다',
#    '영화',
#    '는',
#    '배우',
#    '스텝',
#    '감독',
#    '꼭두각시',
#    '였',
#    '음'],
#   '0'),
#  (['대', '라니', '최악'], '0'),
#  (['정말', '아름다운', '영화', '입니다'], '1'),
#  (['자극', '적', '인', '익숙', '해진', '현대인', '봐도', '눈', '떼', '기', '힘든', '연출력'], '1'),
#  (['뻑뻑', '잘', '읽', '볼', '걸', '도', '당했', '음'], '1'),
#  (['정말',
#    '짜증',
#    '극치',
#    '보여',
#    '주',
#    '는',
#    '영화',
#    '굉장히',
#    '언',
#    '밸',
#    '러스',
#    '한',
#    '느낌',
#    '뚱뚱',
#    '고',
#    '못생긴',
#    '남자',
#    '애',
#    '발연기',
#    '시종일관',
#    '봐야',
#    '는',
#    '게',
#    '고역',
#    '인',
#    '듯',
#    '간간히',
#    '흘러나오',
#    '는',
#    '잔잔',
#    '한',
#    '클래식',
#    '풍',
#    '음악',
#    '도',
#    '듣',
#    '기',
#    '싫',
#    '짜증',
#    '날',
#    '정도',
#    '상당히',
#    '싫',
#    '은',
#    '영화'],
#   '0'),
#  (['감동', '감동', '정말', '최고', '네요'], '1'),
#  (['별점',
#    '주',
#    '기',
#    '도',
#    '아깝',
#    '네요',
#    '내용',
#    '진부',
#    '한지',
#    '욕',
#    '밖',
#    '안',
#    '나오',
#    '네요',
#    '보',
#    '고',
#    '재밌',
#    '다고',
#    '는',
#    '사람',
#    '초딩',
#    '인가요',
#    '죄송',
#    '너무',
#    '화',
#    '서',
#    '아무',
#    '도',
#    '볼',
#    '게',
#    '없',
#    '보',
#    '지',
#    '마세요',
#    '그냥',
#    '티',
#    '비판',
#    '짜집기',
#    '한',
#    '거',
#    '같',
#    '네요'],
#   '0'),
#  (['왠만해서', '짜증', '안', '내', '는데'], '0'),
#  (['돼지',
#    '피',
#    '먹',
#    '고',
#    '닭목',
#    '따',
#    '는',
#    '장면',
#    '에선',
#    '우',
#    '웩',
#    '역시',
#    '무당',
#    '은',
#    '아무',
#    '는',
#    '게',
#    '다'],
#   '0'),
#  (['버려'], '0'),
#  (['유치', '고', '지루', '고', '잠', '왔', '다'], '0'),
#  (['류', '풍', '판타지', '점', '만', '가져가'], '0'),
#  (['윤종신',
#    '복귀',
#    '는',
#    '좋',
#    '았',
#    '이하늘',
#    '은',
#    '도대체',
#    '뽑혔',
#    '는지',
#    '알',
#    '수',
#    '없',
#    '다',
#    '참가자',
#    '실력',
#    '따지',
#    '기',
#    '전',
#    '심사',
#    '위원',
#    '인격',
#    '실력',
#    '쌓',
#    '고',
#    '시',
#    '길',
#    '어허',
#    '그만',
#    '고요'],
#   '0'),
#  (['광장', '한', '작품', '옛날', '도', '보', '고', '싶', '다'], '1'),
#  (['내', '생', '최고', '영화'], '1'),
#  (['어린',
#    '시절',
#    '너무',
#    '무섭',
#    '고',
#    '재미있',
#    '게',
#    '봤',
#    '던',
#    '추억',
#    '판타지',
#    '영화',
#    '절대',
#    '나쁜',
#    '짓',
#    '은',
#    '금물',
#    '지옥',
#    '가요'],
#   '1'),
#  (['기존',
#    '멜',
#    '영화',
#    '형식',
#    '탈피',
#    '려고',
#    '였으나',
#    '감정',
#    '절제',
#    '지나쳐',
#    '너무',
#    '담백',
#    '한',
#    '영화'],
#   '0'),
#  (['난',
#    '사랑',
#    '비',
#    '서준',
#    '쏙',
#    '빠져',
#    '버렸',
#    '초',
#    '만',
#    '쏙',
#    '난',
#    '절대',
#    '잊',
#    '지',
#    '도',
#    '않',
#    '고',
#    '후회',
#    '도',
#    '안',
#    '할',
#    '거'],
#   '1'),
#  (['영화',
#    '보',
#    '니까',
#    '교훈',
#    '주',
#    '네요',
#    '도',
#    '남',
#    '은',
#    '인생',
#    '화려',
#    '게',
#    '살',
#    '겟',
#    '다',
#    '말',
#    '밖에',
#    '안',
#    '나오',
#    '네요'],
#   '1'),
#  (['나름',
#    '추억',
#    '젖어들',
#    '고',
#    '좋',
#    '았',
#    '음',
#    '아무',
#    '생각없이',
#    '가볍',
#    '게',
#    '보',
#    '고',
#    '기',
#    '추천요'],
#   '1'),
#  (['단순', '한', '싸이코', '물', '벗어난'], '1'),
#  (['이게',
#    '도',
#    '만들',
#    '진',
#    '건가요',
#    '면',
#    '예전',
#    '만든',
#    '거',
#    '다시',
#    '개봉',
#    '한',
#    '건가요',
#    '너무',
#    '허접'],
#   '0'),
#  (['넘', '사랑', '스러운', '영화', '다', '보', '고', '연이', '봤', '다', '넘', '귀여워'], '1'),
#  (['청춘',
#    '영화',
#    '만',
#    '줄',
#    '수',
#    '있',
#    '는',
#    '감성',
#    '넘쳐난다',
#    '순간',
#    '지나가',
#    '면',
#    '다시',
#    '돌아오',
#    '지',
#    '않',
#    '테',
#    '순간',
#    '만큼',
#    '은',
#    '무한',
#    '할',
#    '젊음',
#    '줄',
#    '수',
#    '있',
#    '는',
#    '그런',
#    '감성'],
#   '1'),
#  (['용', '건담', '시리즈', '중', '아직', '도', '최고봉'], '1'),
#  (['개콘', '은', '요즘', '갈수록', '코너', '다노', '잼', '고', '웃음', '안', '난다'], '0'),
#  (['사다코', '한', '서린', '우물', '펀치', '감동'], '1'),
#  (['후세',
#    '사랑',
#    '게',
#    '된',
#    '결정',
#    '적',
#    '계기',
#    '표현',
#    '되',
#    '지',
#    '않',
#    '았',
#    '으며',
#    '시',
#    '람',
#    '생명',
#    '빼앗',
#    '만',
#    '는',
#    '이유',
#    '시노',
#    '출현',
#    '는',
#    '연극',
#    '으',
#    '더',
#    '알려',
#    '주',
#    '었',
#    '으면',
#    '는',
#    '생각',
#    '든다',
#    '시노',
#    '본능',
#    '절제',
#    '히',
#    '면서',
#    '시랑',
#    '려고',
#    '노력',
#    '는지',
#    '더',
#    '보여',
#    '줬',
#    '다면',
#    '좋',
#    '았',
#    '뻔',
#    '했',
#    '다'],
#   '0'),
#  (['새벽', '는', '일본', '영화', '은', '개', '졸작', '다', '일본', '영화', '원래', '다'], '0'),
#  (['강수연', '나가', '있', '최정원', '신', '음신'], '0'),
#  (['정말', '김혜성', '너무', '예쁘', '네요', '이현진', '도', '웃', '는', '거', '정말'], '1'),
#  (['가발', '쓰', '고', '싶', '다'], '0'),
#  (['화려', '한', '여정', '인상깊', '어요', '재', '밋', '어요', '배두나', '연기', '정말', '잘'], '1'),
#  (['대', '위한', '성적', '호기심', '영화'], '0'),
#  (['감동', '적', '인', '영화'], '1'),
#  (['이건', '말', '필요', '없', '다', '그냥', '닥치', '고'], '1'),
#  (['각기', '사람', '재밌', '고', '멋진', '사랑', '영화'], '1'),
#  (['역시',
#    '미국',
#    '드라마',
#    '파워',
#    '정말',
#    '알',
#    '수',
#    '없',
#    '는',
#    '미묘',
#    '함',
#    '사로잡',
#    '버렸',
#    '다',
#    '최고'],
#   '1'),
#  (['너무너무', '훈훈', '네요'], '1'),
#  (['이거', '응답', '라', '은지', '원원', '도', '스스로', '욕하', '지', '않'], '0'),
#  (['너무', '웃기', '고', '배꼽', '빠질', '뻔', '했', '내', '컴', '영화', '있', '는데'], '1'),
#  (['구성', '상당히', '부실', '한', '영화', '역시', '네이버', '평점', '은', '믿', '수', '없', '다'],
#   '0'),
#  (['장끌로드', '몰락', '가져온', '오우삼', '헐리우드', '작품', '중', '가장', '재미없', '었', '던', '졸작'],
#   '0'),
#  (['적', '영웅본색', '연출', '인지', '현실', '성', '제로인', '영화'], '0'),
#  (['작',
#    '은',
#    '거',
#    '도',
#    '설레',
#    '했',
#    '던',
#    '학창',
#    '시절',
#    '느낌',
#    '다시',
#    '느껴볼',
#    '수',
#    '있',
#    '는',
#    '었',
#    '다',
#    '장면',
#    '대',
#    '배경',
#    '음악',
#    '버릴',
#    '게',
#    '없',
#    '는',
#    '드라마'],
#   '1'),
#  (['진심', '재미', '없', '는데', '너무', '평점', '높', '아서', '화남'], '0'),
#  (['더럽',
#    '게',
#    '재미없',
#    '다',
#    '형태',
#    '도',
#    '닿',
#    '지',
#    '않',
#    '는',
#    '허무',
#    '고',
#    '완벽히',
#    '지루',
#    '한',
#    '영화',
#    '고',
#    '영양가',
#    '도',
#    '없',
#    '는',
#    '영화',
#    '다'],
#   '0'),
#  (['이승기', '정말', '연기', '잘', '는', '조연', '도', '연기', '정말', '잘', '고'], '1'),
#  (['현실', '은', '꿈', '꿈', '은', '현실'], '1'),
#  (['오늘',
#    '현충일',
#    '특집',
#    '프로',
#    '보',
#    '게',
#    '되',
#    '었',
#    '도의',
#    '매우',
#    '훌륭',
#    '한',
#    '작품',
#    '입니다'],
#   '1'),
#  (['판의', '미로', '동급'], '0'),
#  (['제대', '고', '보', '니까', '더', '재밌', '네요'], '1'),
#  (['영화',
#    '보',
#    '는',
#    '만',
#    '도',
#    '마음',
#    '휴가',
#    '다녀온',
#    '느낌',
#    '소박',
#    '지고',
#    '잔잔',
#    '지루',
#    '지',
#    '않',
#    '은',
#    '다시',
#    '보',
#    '고',
#    '싶',
#    '은',
#    '영화',
#    '햇살',
#    '가득',
#    '한',
#    '비이',
#    '부엌',
#    '요리',
#    '도',
#    '인상',
#    '적'],
#   '1'),
#  (['코믹', '한', '건', '좋', '았', '는데', '짜임새', '너무', '허술', '다'], '0'),
#  (['당시',
#    '는',
#    '나라',
#    '판타지',
#    '로맨스',
#    '없',
#    '었',
#    '다',
#    '아직',
#    '도',
#    '신현준',
#    '황장',
#    '군',
#    '연기',
#    '는',
#    '음',
#    '괜찮',
#    '한석규',
#    '전성시대',
#    '열린',
#    '영화',
#    '한석규',
#    '한테',
#    '뿅',
#    '갔었',
#    '다'],
#   '1'),
#  (['재생', '면', '괴물', '같', '은', '서스펜스', '귀신', '같', '은', '흡입력'], '1'),
#  (['진짜',
#    '댓글',
#    '보',
#    '고',
#    '한',
#    '번',
#    '쯤',
#    '볼',
#    '만',
#    '한',
#    '영화',
#    '인',
#    '거',
#    '같',
#    '아서',
#    '봤',
#    '기',
#    '찬다',
#    '이게',
#    '버킷',
#    '리스트',
#    '인가',
#    '죽',
#    '기',
#    '직전',
#    '소원',
#    '주',
#    '기',
#    '내',
#    '보',
#    '기엔',
#    '죽',
#    '기',
#    '직전',
#    '막',
#    '살',
#    '인',
#    '거',
#    '같',
#    '다',
#    '감동',
#    '도',
#    '없',
#    '고',
#    '진짜',
#    '버킷',
#    '리스트',
#    '란',
#    '영화',
#    '발톱',
#    '만큼',
#    '도',
#    '못',
#    '따라가',
#    '는',
#    '쓰레기',
#    '영화',
#    '완존',
#    '실망'],
#   '0'),
#  (['밝',
#    '고',
#    '긍정',
#    '적',
#    '인',
#    '드라마',
#    '보',
#    '고',
#    '싶',
#    '어서',
#    '보',
#    '긴',
#    '보',
#    '는데',
#    '오버',
#    '는',
#    '연기',
#    '거슬리',
#    '네요',
#    '연기',
#    '인',
#    '게',
#    '너무',
#    '표나',
#    '요',
#    '홍혜정',
#    '역',
#    '그나마',
#    '도',
#    '후련',
#    '기',
#    '도',
#    '고',
#    '시원',
#    '고',
#    '나머진',
#    '다',
#    '답답',
#    '네요',
#    '낼',
#    '월요일',
#    '인데',
#    '해피',
#    '한',
#    '만',
#    '보',
#    '고',
#    '싶',
#    '네요'],
#   '0'),
#  (['정치인', '모순', '인가', '정치범', '모순', '인가'], '0'),
#  (['상상', '대단', '다'], '1'),
#  (['어렵', '기', '도', '고', '전쟁', '대한', '묘사', '잘', '모르', '겠', '다'], '0'),
#  (['일본', '주년', '극장판', '만드', '는데', '나라', '에선', '주년', '재개봉', '니', '이건', '아님'],
#   '0'),
#  (['한대희', '개그콘서트', '본다고', '내', '전화', '끊', '음', '개그콘서트', '없애', '주', '세요'], '0'),
#  (['한물', '간', '동서양', '두', '배우', '싸움판'], '0'),
#  (['푸하하하', '이거', '기대', '안', '했', '역시', '구만'], '0'),
#  (['세계', '최초', '반공', '애', '니매', '션', '라는', '역사', '적', '가치', '있', '다'], '1'),
#  (['감각', '적', '인', '바라보', '는', '색다른', '느낌', '사랑', '문학', '적'], '1'),
#  (['엄마', '는', '무고', '한', '지', '딸', '감옥살이', '시켜', '시켜', '이해', '안', '돼요'], '0'),
#  (['영화',
#    '는',
#    '제발',
#    '책',
#    '보',
#    '세여',
#    '감독',
#    '미친',
#    '겁니다',
#    '이따위',
#    '만들',
#    '놓',
#    '고',
#    '화',
#    '날',
#    '정도'],
#   '0'),
#  (['신나', '는', '흑인', '음악', '아이스', '큐브', '뿐', '남', '는', '게', '없', '다'], '0'),
#  (['드럽', '게', '재미없', '돈', '다', '내', '은', '어쩔', '건데'], '0'),
#  (['뿐', '알리', '시'], '1'),
#  (['진짜', '생생', '게', '느낄', '수', '있', '었', '다'], '1'),
#  (['재밌', '는데', '평점', '다', '싶', '정도', '낮', '다'], '1'),
#  (['옥소리',
#    '프로필',
#    '사진',
#    '점',
#    '남기',
#    '고',
#    '갑니다',
#    '완전',
#    '대박',
#    '다',
#    '진짜',
#    '아우',
#    '짜증'],
#   '0'),
#  (['드라마', '너무', '재', '밓당'], '1'),
#  (['진짜', '너무', '좋', '아요', '짱짱'], '1'),
#  (['연기', '굿'], '1'),
#  (['영화',
#    '다시',
#    '는',
#    '안',
#    '나오',
#    '겠',
#    '지',
#    '시절',
#    '잘',
#    '나타내',
#    '주',
#    '었',
#    '던',
#    '거',
#    '같',
#    '아요'],
#   '1'),
#  (['중간', '정도', '봤', '는데', '도', '꽤', '대단', '군요'], '1'),
#  (['콩', '은', '까', '맛', '콩', '은', '까', '맛'], '0'),
#  (['이적', '소설', '재미없', '다'], '0'),
#  (['액션',
#    '영화',
#    '다',
#    '범죄',
#    '느와르',
#    '영화',
#    '다',
#    '허나',
#    '범죄',
#    '느와르',
#    '영화',
#    '로서',
#    '도',
#    '실패작'],
#   '0'),
#  (['뭔가', '알', '수', '없', '는', '매력', '빠져드', '는', '영화'], '1'),
#  (['모녀',
#    '토막',
#    '살해',
#    '한',
#    '살인자',
#    '부성애',
#    '라니',
#    '말',
#    '되',
#    '감동',
#    '받',
#    '은',
#    '사람',
#    '본인',
#    '피해자',
#    '되',
#    '도',
#    '감동',
#    '받',
#    '았',
#    '다고',
#    '할',
#    '수',
#    '있',
#    '을까',
#    '진심',
#    '묻',
#    '고',
#    '싶'],
#   '0'),
#  (['재밌', '는데', '평점', '이렇게', '구리지'], '1'),
#  (['기', '이걸', '본', '내', '눈', '아깝', '다', '진짜', '놔', '진짜', '기', '명작', '네요'],
#   '0'),
#  (['필름', '값', '아깝', '다', '재미', '더럽', '게', '없', '다', '점', '점수', '준', '매미'],
#   '0'),
#  (['보', '고', '싶', '은데', '서', '보', '죠'], '1'),
#  (['영화', '재미있', '드만'], '1'),
#  (['남',
#    '주인공',
#    '연기력',
#    '안습',
#    '네요',
#    '혀',
#    '짧',
#    '은',
#    '소리',
#    '듣',
#    '기',
#    '도',
#    '너무',
#    '힘들',
#    '었',
#    '네요',
#    '매니저',
#    '역활',
#    '분',
#    '남',
#    '주인공',
#    '는',
#    '게',
#    '훨',
#    '좋',
#    '았',
#    '겠',
#    '다는',
#    '생각',
#    '정도',
#    '영화',
#    '자체',
#    '는',
#    '적당히',
#    '볼',
#    '만',
#    '합니다'],
#   '0'),
#  (['점', '액션', '스릴러', '인데', '액션', '스릴', '없', '다'], '0'),
#  (['완전', '스토리', '도', '엉망', '완전', '비추'], '0'),
#  (['영화', '뭘', '전달', '려는지', '모르', '겠', '오글거리', '고'], '0'),
#  (['좋', '은', '영화'], '1'),
#  (['더', '빙', '할머니', '는', '월래', '익숙', '한'], '0'),
#  (['이게', '편', '나왔'], '0'),
#  (['모든', '게', '씩', '다', '부족', '했', '다', '씩'], '0'),
#  (['정말', '말', '그대로', '쇼', '는', '영화'], '0'),
#  (['전',
#    '봐서',
#    '기억',
#    '질',
#    '않',
#    '진개',
#    '천카이거',
#    '감독',
#    '이름',
#    '세',
#    '는',
#    '기억',
#    '해',
#    '두',
#    '었',
#    '던'],
#   '1'),
#  (['정은지',
#    '언니',
#    '연기',
#    '잘',
#    '노래',
#    '도',
#    '잘',
#    '부르',
#    '시',
#    '고',
#    '마지막',
#    '회',
#    '웃',
#    '으면서',
#    '즐겁',
#    '게',
#    '봤',
#    '트로트',
#    '연인'],
#   '1'),
#  (['이게', '웃겨'], '0'),
#  (['망함'], '0'),
#  (['시선', '보', '는', '전쟁', '보', '는', '내내', '가슴', '먹먹', '했', '다는'], '1'),
#  (['사람',
#    '재미없',
#    '다고',
#    '해서',
#    '레알',
#    '기대',
#    '안',
#    '했',
#    '는데',
#    '생각',
#    '보다',
#    '볼',
#    '만',
#    '함',
#    '근데',
#    '여자',
#    '애',
#    '랑',
#    '복',
#    '순',
#    '이랑',
#    '다투',
#    '는',
#    '장면',
#    '그건',
#    '굳이',
#    '없',
#    '어도',
#    '됐',
#    '다고',
#    '생각',
#    '함',
#    '몰입',
#    '도',
#    '겁나',
#    '없애',
#    '고',
#    '어색',
#    '해',
#    '보였',
#    '음'],
#   '0'),
#  (['설정', '연속극', '같', '은', '느낌', '든다', '배우', '연기', '뛰어나', '다'], '1'),
#  (['여주인공',
#    '인터뷰',
#    '할',
#    '지루',
#    '해',
#    '죽',
#    '는',
#    '줄',
#    '알',
#    '았',
#    '음',
#    '그냥저냥',
#    '킬링',
#    '타임',
#    '용',
#    '스릴러'],
#   '0'),
#  (['전미',
#    '박스',
#    '오피스',
#    '위',
#    '그냥',
#    '몰아주',
#    '기',
#    '는',
#    '건가',
#    '영화',
#    '위',
#    '지',
#    '옛날',
#    '대',
#    '우뢰매',
#    '수준',
#    '물',
#    '폭탄',
#    '싸움',
#    '손',
#    '빔',
#    '나가',
#    '손',
#    '물',
#    '폭탄',
#    '나가',
#    '다를',
#    '게',
#    '뭐',
#    '지'],
#   '0'),
#  (['감독', '여자', '다', '보', '니', '기량', '많이', '딸리'], '0'),
#  (['보', '고', '울', '었', '다'], '1'),
#  (['영화',
#    '는',
#    '개연',
#    '성',
#    '만',
#    '없',
#    '어도',
#    '허무',
#    '게',
#    '만들',
#    '버린다',
#    '조디포스터',
#    '이쁜',
#    '모습',
#    '만',
#    '남',
#    '영화'],
#   '0'),
#  (['굳', '굳'], '1'),
#  (['스토리',
#    '도',
#    '말',
#    '안',
#    '되',
#    '고',
#    '개막',
#    '장',
#    '사랑',
#    '이야기',
#    '도',
#    '예요',
#    '이걸',
#    '보',
#    '고',
#    '계신다면',
#    '돈',
#    '아낀',
#    '거',
#    '예요',
#    '본다면',
#    '호구'],
#   '0'),
#  (['네놈을', '살려', '두', '기', '엔', '쌀', '아까워', '세기', '명대사'], '1'),
#  (['평점',
#    '너무',
#    '높',
#    '다',
#    '전혀',
#    '재미있',
#    '지',
#    '않',
#    '았',
#    '다',
#    '쓸데없이',
#    '말',
#    '만',
#    '많',
#    '음',
#    '류',
#    '영화',
#    '는',
#    '조연',
#    '뒷받침',
#    '중요',
#    '조연',
#    '내용',
#    '자체',
#    '전혀',
#    '없',
#    '음',
#    '여배우',
#    '도',
#    '별로',
#    '매력',
#    '없',
#    '었',
#    '다',
#    '이틀',
#    '전',
#    '저스트',
#    '고',
#    '위드',
#    '잇',
#    '애니스톤',
#    '보',
#    '고',
#    '영화',
#    '봐서',
#    '그런가',
#    '실망',
#    '했',
#    '음'],
#   '0'),
#  (['맛깔', '는', '드라마'], '1'),
#  (['시베리아', '인가', '거기', '서', '훈련', '할', '나오', '는', '개작', '살'], '1'),
#  (['이건',
#    '시종일관',
#    '질질',
#    '제목',
#    '야경',
#    '꾼',
#    '일지',
#    '냐고',
#    '지금',
#    '회',
#    '넘어가',
#    '는데',
#    '달',
#    '넘어가',
#    '는데',
#    '앞',
#    '누군가',
#    '얘기',
#    '더만',
#    '이거',
#    '부작',
#    '냐고',
#    '그러',
#    '다',
#    '한',
#    '순간',
#    '모든',
#    '걸',
#    '훅',
#    '진짜',
#    '지루함',
#    '지존'],
#   '0'),
#  (['나이', '수록', '이해', '는', '영화'], '1'),
#  (['슬픔'], '1'),
#  (['장면',
#    '개연',
#    '성',
#    '도',
#    '없',
#    '고',
#    '아역',
#    '은',
#    '연기',
#    '도',
#    '못하',
#    '고',
#    '추노',
#    '나오',
#    '는',
#    '민폐',
#    '언년',
#    '외',
#    '국판',
#    '인',
#    '줄',
#    '초반',
#    '만',
#    '그럴싸한',
#    '저급',
#    '영화'],
#   '0'),
#  (['영화', '정말', '별루', '예요', '결말'], '0'),
#  (['딱히', '재미', '는', '없', '네요', '킁'], '0'),
#  (['송강호',
#    '는',
#    '정말',
#    '연기',
#    '기',
#    '위해',
#    '태어났',
#    '고',
#    '인해',
#    '는',
#    '즐거움',
#    '느낀다',
#    '역시',
#    '송강호',
#    '는',
#    '연기파',
#    '다'],
#   '1'),
#  (['일본',
#    '영화',
#    '수입',
#    '금지',
#    '시절',
#    '도',
#    '비디오',
#    '테이프',
#    '돌려',
#    '봤',
#    '던',
#    '불후',
#    '명작',
#    '그립',
#    '다'],
#   '1'),
#  (['살인',
#    '소재',
#    '한',
#    '영화',
#    '이토록',
#    '재밌',
#    '줄',
#    '이야',
#    '살인',
#    '대한',
#    '감독',
#    '해석',
#    '정말',
#    '재',
#    '치',
#    '있',
#    '다',
#    '대',
#    '배우',
#    '님',
#    '여년',
#    '전',
#    '모습',
#    '도',
#    '새롭',
#    '웠고',
#    '정말',
#    '유쾌',
#    '고',
#    '재밌',
#    '다'],
#   '1'),
#  (['누미', '라파스', '신봉선', '닮', '아서', '안', '본다'], '0'),
#  (['케이블', '그만', '재탕', '해라'], '0'),
#  (['멋졌', '다', '정말', '지', '멋지', '다는', '말', '이외', '엔', '할', '말', '없', '다'], '1'),
#  (['어떻',
#    '게',
#    '영화',
#    '만들',
#    '졌',
#    '는지',
#    '의문',
#    '당대',
#    '최고',
#    '영화',
#    '지금',
#    '봐도',
#    '퀄',
#    '결코',
#    '떨어지',
#    '지',
#    '않',
#    '아요'],
#   '1'),
#  (['지금', '이거', '티비', '돈', '내', '고', '보', '고', '있', '는', '내', '한심', '다'], '0'),
#  (['쓰레기', '연예인', '재기', '장', '그러'], '0'),
#  (['굿', '좋'], '0'),
#  (['많', '은', '감동', '준', '드라마', '다'], '1'),
#  (['발',
#    '만든',
#    '영화',
#    '지진',
#    '서',
#    '주인공',
#    '넘어지',
#    '는데',
#    '뒤',
#    '사람',
#    '유유히',
#    '걸어다니',
#    '고',
#    '있',
#    '음',
#    '발',
#    '발연기',
#    '발',
#    '시나리오',
#    '내용',
#    '도',
#    '정말',
#    '뭐',
#    '같',
#    '음'],
#   '0'),
#  (['적당히', '해야지', '끝나', '는', '인가'], '0'),
#  (['잊', '수', '없', '는', '안개', '낀', '워터', '루', '다리', '마스코트'], '1'),
#  (['곤사토시',
#    '감독',
#    '안타깝',
#    '게',
#    '돌아가',
#    '셔서',
#    '가슴',
#    '먹먹',
#    '합니다',
#    '정말',
#    '천재',
#    '적',
#    '인',
#    '감독',
#    '인데',
#    '암',
#    '가시',
#    '다니',
#    '이제',
#    '와서',
#    '다시',
#    '봐도',
#    '모든',
#    '작품',
#    '대작'],
#   '1'),
#  (['많',
#    '은',
#    '생각',
#    '게',
#    '됐',
#    '뼈지',
#    '고',
#    '싶',
#    '은',
#    '맘',
#    '은',
#    '있',
#    '었',
#    '과하',
#    '면',
#    '독',
#    '겠',
#    '네요'],
#   '1'),
#  (['츠', '무구', '만', '없', '지', '면', '별', '개', '줄게'], '0'),
#  (['어릴',
#    '땐',
#    '조폭',
#    '영화',
#    '알',
#    '다가',
#    '나이',
#    '수록',
#    '이게',
#    '인생',
#    '구나',
#    '고',
#    '뭉클',
#    '해',
#    '지',
#    '는',
#    '영화',
#    '세상',
#    '살아가',
#    '면',
#    '갈수록',
#    '닿',
#    '는',
#    '게',
#    '많',
#    '지',
#    '네요',
#    '세상',
#    '은',
#    '비정',
#    '비정',
#    '함마',
#    '져도',
#    '따뜻',
#    '해',
#    '지',
#    '는',
#    '게',
#    '친구',
#    '라고'],
#   '1'),
#  (['영상', '너무나', '도', '멋지', '다'], '1'),
#  (['비디오',
#    '있',
#    '어서',
#    '봤',
#    '는데',
#    '도인',
#    '줄모',
#    '정도',
#    '잘',
#    '만들',
#    '었',
#    '긴장감',
#    '도',
#    '있',
#    '고'],
#   '1'),
#  (['처', '주'], '1'),
#  (['만들',
#    '진',
#    '치곤',
#    '재밌',
#    '음',
#    '영화',
#    '길',
#    '어서',
#    '다듬',
#    '었',
#    '으면',
#    '소재',
#    '도',
#    '좋',
#    '고',
#    '몰',
#    '입감',
#    '도',
#    '기대',
#    '매끄럽',
#    '지',
#    '못한',
#    '부분',
#    '도',
#    '있',
#    '연기',
#    '는',
#    '다',
#    '잘',
#    '한',
#    '듯'],
#   '1'),
#  (['철',
#    '지난',
#    '조폭',
#    '코미디',
#    '뼈대',
#    '있',
#    '는',
#    '가문',
#    '이야기',
#    '섞',
#    '었',
#    '다',
#    '지루',
#    '다',
#    '박정아',
#    '비롯',
#    '해',
#    '배우',
#    '은',
#    '보',
#    '기',
#    '민망',
#    '한',
#    '연기',
#    '펼치',
#    '고',
#    '기억',
#    '남',
#    '는',
#    '건',
#    '도',
#    '없',
#    '다'],
#   '0'),
#  (['군더더기', '없이', '잘', '진행', '되', '는', '데', '재미', '도', '없', '는', '게', '문제'],
#   '0'),
#  (['심심',
#    '해서',
#    '봤',
#    '는데',
#    '재밌',
#    '네요',
#    '탑',
#    '연기',
#    '못',
#    '할',
#    '줄',
#    '알',
#    '았',
#    '는데',
#    '배우',
#    '포스',
#    '고',
#    '잘',
#    '군요'],
#   '1'),
#  (['고다미', '괜찮', '음'], '1'),
#  (['지대', '짜증', '아빠', '랑', '봣는데', '민망', '해', '죽', '는', '줄'], '0'),
#  (['점', '은', '못', '주', '냐'], '0'),
#  (['빠', '순', '영화', '훈훈', '긔', '재', '밋', '쎠'], '1'),
#  (['최악', '애니메이션', '지루', '고', '재미없', '고', '스토리', '진부', '다'], '0'),
#  (['좋', '은', '의도', '는', '다르', '게', '불쾌', '한', '표현법'], '0'),
#  (['줄리아로버츠', '귀여운', '연인', '은', '이거', '보다', '전', '꺼', '다'], '0'),
#  (['신선'], '0'),
#  (['예술가',
#    '한',
#    '사람',
#    '인생',
#    '당시',
#    '시대',
#    '적',
#    '상황',
#    '질',
#    '느낄',
#    '수',
#    '있',
#    '었',
#    '던',
#    '명작'],
#   '1'),
#  (['관객',
#    '수',
#    '너무',
#    '아쉬운',
#    '영화',
#    '베테랑',
#    '보다',
#    '도',
#    '더',
#    '류승완',
#    '감독',
#    '역작',
#    '고',
#    '더',
#    '강한',
#    '악역',
#    '다'],
#   '1'),
#  (['한창', '핵', '펭귄', '남북', '거짓', '평화', '전', '국민', '속이', '던', '만들', '진', '영화'],
#   '0'),
#  (['지금', '티비', '는데', '못', '보', '겠', '다'], '0'),
#  (['여자',
#    '애',
#    '한',
#    '명',
#    '잘',
#    '못',
#    '해서',
#    '명',
#    '죽',
#    '는',
#    '거',
#    '답',
#    '도',
#    '없',
#    '다'],
#   '0'),
#  (['성룡', '헐리', '웃', '작', '중', '단연', '최고', '지'], '1'),
#  (['안습'], '0'),
#  (['감독', '의도', '전혀', '알아차리', '지', '못했', '다'], '0'),
#  (['하나님',
#    '가정',
#    '온전히',
#    '만든다',
#    '진리',
#    '신',
#    '분',
#    '만든',
#    '영화',
#    '눈',
#    '만',
#    '보',
#    '지',
#    '말',
#    '고',
#    '마음'],
#   '1'),
#  (['편도', '나름', '흥미진진', '한', '데', '핀', '헤드', '죽', '은', '게', '아쉬운', '점', '랄까'],
#   '1'),
#  (['국산',
#    '코미디',
#    '영화',
#    '중',
#    '난',
#    '신라',
#    '달밤',
#    '제일',
#    '좋',
#    '았',
#    '음',
#    '뭔가',
#    '푸근',
#    '고',
#    '따뜻',
#    '함'],
#   '1'),
#  (['최악', '다', '영화', '보', '다가', '잠', '긴', '첨', '임', '지루', '해', '둑', '뻔'], '0'),
#  (['탄탄', '한', '배우', '될', '고', '머', '는', '건지'], '0'),
#  (['영화',
#    '점점',
#    '끝',
#    '달려',
#    '갈수록',
#    '몰',
#    '입도',
#    '더',
#    '높',
#    '진',
#    '영화',
#    '는',
#    '처음',
#    '네요'],
#   '1'),
#  (['감독',
#    '고',
#    '싶',
#    '은',
#    '의견',
#    '지존파',
#    '핑계',
#    '려고',
#    '한',
#    '듯',
#    '지존파',
#    '살인',
#    '은',
#    '정당',
#    '화',
#    '고',
#    '정부',
#    '탓',
#    '였',
#    '다는',
#    '사회',
#    '탓',
#    '라는'],
#   '0'),
#  (['사실',
#    '떠나',
#    '알',
#    '고',
#    '왔',
#    '던',
#    '아더',
#    '너무',
#    '매칭',
#    '안',
#    '돼',
#    '더라',
#    '원탁',
#    '기사',
#    '중',
#    '실제',
#    '검술',
#    '최고',
#    '수',
#    '는',
#    '랜',
#    '슬롯',
#    '알',
#    '고',
#    '있',
#    '는데',
#    '트리스탄',
#    '보다',
#    '못',
#    '고',
#    '싸우',
#    '는',
#    '검술',
#    '은',
#    '중국',
#    '검술',
#    '흉내',
#    '낸',
#    '거',
#    '같',
#    '은',
#    '게',
#    '란슬롯',
#    '실제',
#    '는',
#    '쌍검',
#    '였',
#    '너무',
#    '매칭',
#    '안대',
#    '하튼',
#    '기',
#    '네비',
#    '어역',
#    '도',
#    '미스'],
#   '0'),
#  (['대한민국', '영화', '수준', '평균치', '하락', '시키', '기', '충분', '한', '급', '영상물'], '0'),
#  (['점', '은', '없'], '0'),
#  (['재밌', '는데'], '1'),
#  (['재미없', '다', '기대', '완전', '했', '는데', '완전', '못', '함', '실망'], '0'),
#  (['종착역', '없', '는', '인생', '대유', '트레비스', '는', '흘러간다'], '1'),
#  (['돈', '아까운', '영화'], '0'),
#  (['러',
#    '티',
#    '브',
#    '는',
#    '도',
#    '없',
#    '는',
#    '예쁜',
#    '음악',
#    '동영상',
#    '취미',
#    '영화',
#    '만드',
#    '는',
#    '은',
#    '이걸로',
#    '끝나',
#    '길',
#    '잘',
#    '는',
#    '음악',
#    '올',
#    '인',
#    '길'],
#   '0'),
#  (['배우', '연기', '는', '좋', '았', '는데', '뭘', '말', '려는', '건지'], '0'),
#  (['학위',
#    '위',
#    '조성',
#    '범죄자',
#    '문제자',
#    '만',
#    '모아서',
#    '영화',
#    '찍',
#    '음',
#    '그랬',
#    '으까',
#    '제작비',
#    '아끼',
#    '려구',
#    '패자',
#    '부',
#    '활전',
#    '냐'],
#   '0'),
#  (['솔직히'], '0'),
#  (['완전', '재미있', '어요', '애', '도', '보', '기', '알맞', '는', '듯'], '1'),
#  (['잔인', '기', '도', '고', '무서웠', '어요', '탑', '은', '멋있', '더라구요'], '0'),
#  (['무섭', '지', '도', '않', '고', '기분', '만', '나쁘', '고', '쩝'], '0'),
#  (['군더더기', '없', '는', '깔끔', '한', '강한', '메세지', '전달', '뜻밖', '좋', '은', '영화'], '1'),
#  (['영화', '는', '최고', '다', '그냥', '최고', '그런', '줄', '알'], '1'),
#  (['그랜드', '부다페스트', '호텔', '시리즈', '같', '캐스팅', '아까워'], '0'),
#  (['빨리',
#    '감기',
#    '해서',
#    '봤',
#    '음',
#    '투자',
#    '비',
#    '는',
#    '많이',
#    '었',
#    '같',
#    '은데',
#    '영화사',
#    '망했'],
#   '0'),
#  (['도대체',
#    '뭐',
#    '재밌',
#    '다는',
#    '건지',
#    '모르',
#    '겠',
#    '네요',
#    '아이언',
#    '맨',
#    '시리즈',
#    '개그',
#    '도',
#    '뛰어넘',
#    '는다',
#    '는데',
#    '서',
#    '웃',
#    '어야',
#    '할지',
#    '도',
#    '모르',
#    '겠',
#    '고',
#    '내용',
#    '도',
#    '뭔지',
#    '뜬금없',
#    '는',
#    '히어로',
#    '놀이',
#    '는',
#    '뭔지',
#    '이렇게',
#    '평점',
#    '높',
#    '은지',
#    '모르',
#    '겠'],
#   '0'),
#  (['극',
#    '끌어가',
#    '는',
#    '중심',
#    '있',
#    '는',
#    '캐릭터',
#    '있',
#    '어야',
#    '는지',
#    '알',
#    '게',
#    '된',
#    '영화',
#    '살인마',
#    '대적',
#    '는',
#    '사건',
#    '해결',
#    '는',
#    '인물',
#    '없',
#    '고',
#    '마지막',
#    '다',
#    '탈출',
#    '해',
#    '놓',
#    '고',
#    '서',
#    '잡히',
#    '고',
#    '죽임',
#    '당하',
#    '는지',
#    '이해',
#    '할',
#    '수',
#    '없',
#    '다',
#    '대체',
#    '조달환',
#    '정유미',
#    '는',
#    '나옴'],
#   '0'),
#  (['진',
#    '짜',
#    '리얼',
#    '개',
#    '쓰레기',
#    '영화',
#    '다',
#    '보',
#    '고',
#    '면',
#    '정말',
#    '찝찝',
#    '해',
#    '지',
#    '는',
#    '영화',
#    '절대',
#    '보',
#    '지',
#    '마'],
#   '0'),
#  (['로봇',
#    '점차',
#    '인간',
#    '감정',
#    '가지',
#    '고',
#    '대해',
#    '고민',
#    '면서',
#    '인간',
#    '되',
#    '죽',
#    '는',
#    '앤드류',
#    '모습',
#    '내',
#    '봤',
#    '던',
#    '영화',
#    '중',
#    '도',
#    '최고',
#    '감동',
#    '선사',
#    '한',
#    '영화'],
#   '1'),
#  (['영구', '땡', '시리즈', '는', '레전드', '영화', '다'], '1'),
#  (['초딩',
#    '친척',
#    '형',
#    '비디오',
#    '빌려',
#    '와서',
#    '봤',
#    '던',
#    '기억',
#    '난',
#    '다',
#    '너무',
#    '재미',
#    '없',
#    '었',
#    '다',
#    '근데',
#    '나중',
#    '우연히',
#    '다시',
#    '보',
#    '니',
#    '재밌',
#    '더라',
#    '땐',
#    '그렇게',
#    '재미',
#    '없',
#    '었',
#    '을까',
#    '면',
#    '내',
#    '초등',
#    '학교',
#    '학년',
#    '니까',
#    '사촌',
#    '형',
#    '당시',
#    '나름',
#    '최신',
#    '비디오',
#    '빌려',
#    '온',
#    '거',
#    '같',
#    '다'],
#   '1'),
#  (['지루', '할', '만큼', '고요', '고', '서글픈', '시선', '속', '머문', '깊', '은', '성찰', '사색'],
#   '1'),
#  (['영화', '진짜', '보', '고', '펑펑', '울', '었', '너무', '슬픈', '거', '같', '아요'], '1'),
#  (['누가', '더', '혀', '짧', '은가', '내', '기', '면', '박빙', '같', '다'], '0'),
#  (['애', '딸린', '심은하', '눈부신', '미모', '아름다운', '영상', '메인', '주제'], '1'),
#  (['기',
#    '나오',
#    '겠',
#    '죠',
#    '아직',
#    '안',
#    '풀린',
#    '이야기',
#    '많',
#    '은데',
#    '극장판',
#    '은',
#    '정말',
#    '는',
#    '줄',
#    '도',
#    '모르',
#    '고',
#    '봤',
#    '네요',
#    '역시',
#    '싸',
#    '패'],
#   '1'),
#  (['개', '노', '잼', '뭔가', '스토리', '도', '부족', '고', '다', '함', '진짜'], '0'),
#  (['답', '없', '뭐', '는', '건지'], '0'),
#  (['절망',
#    '슬픔',
#    '속',
#    '도',
#    '챙겨야',
#    '만',
#    '는',
#    '삶',
#    '잔인',
#    '함',
#    '거부',
#    '한',
#    '비참',
#    '함',
#    '대하'],
#   '1'),
#  (['페이스', '거', '같', '음'], '0'),
#  (['흘러도', '퇴색', '되', '지', '않', '는', '맛', '있', '는', '영화'], '1'),
#  (['진짜', '어마어마', '한', '여운', '주', '는', '멜', '영화', '요'], '1'),
#  (['소피마르소',
#    '말',
#    '같',
#    '지',
#    '도',
#    '않',
#    '은',
#    '불륜',
#    '내용',
#    '다',
#    '망침',
#    '실제',
#    '역사',
#    '는',
#    '그런',
#    '똥',
#    '같',
#    '은',
#    '이야기',
#    '는',
#    '전혀',
#    '없',
#    '었',
#    '음',
#    '주인공',
#    '죽',
#    '공주',
#    '는',
#    '살',
#    '었',
#    '음',
#    '미국인',
#    '맞서',
#    '싸우',
#    '는',
#    '아메리칸',
#    '원주민',
#    '자유',
#    '투쟁기',
#    '였',
#    '으면',
#    '절대',
#    '아카데미상',
#    '못',
#    '받',
#    '았',
#    '음'],
#   '0'),
#  (['훈훈', '고', '따뜻', '한', '부정', '느낄', '수', '잇', '엇', '음'], '1'),
#  (['잼'], '1'),
#  (['전', '정말', '재미있', '게', '봤'], '1'),
#  (['어딘가',
#    '일어나',
#    '고',
#    '같',
#    '은',
#    '느낌',
#    '강하',
#    '다',
#    '우베볼',
#    '영화',
#    '만드',
#    '는',
#    '이유',
#    '는',
#    '누군가',
#    '실제로',
#    '했',
#    '으면',
#    '고',
#    '바라',
#    '는',
#    '같',
#    '은데',
#    '정장',
#    '월가',
#    '있',
#    '는',
#    '애',
#    '보',
#    '면',
#    '웃',
#    '겠',
#    '지'],
#   '1'),
#  (['림프',
#    '비즈킷',
#    '만',
#    '점',
#    '개봉',
#    '당시',
#    '극장',
#    '봤',
#    '는데',
#    '영화',
#    '내내',
#    '오우',
#    '쥑이',
#    '고',
#    '싶',
#    '었',
#    '던'],
#   '0'),
#  (['견자단', '대박', '엽문', '시리즈', '는', '계속', '된다'], '1'),
#  (['정말',
#    '오월',
#    '멜',
#    '는',
#    '정말로',
#    '보',
#    '고',
#    '보',
#    '고',
#    '봐도',
#    '계속',
#    '보',
#    '고',
#    '싶',
#    '은',
#    '영화',
#    '순위',
#    '순위',
#    '다',
#    '늦',
#    '은',
#    '밤',
#    '라',
#    '그런지',
#    '야릇',
#    '한',
#    '느낌',
#    '었',
#    '다'],
#   '1'),
#  (['흥미', '롭', '게', '봤', '어요', '여배우', '이쁘', '네요', '반했', '음'], '1'),
#  (['스토리',
#    '액션',
#    '그래픽',
#    '머',
#    '건질',
#    '게',
#    '없',
#    '는',
#    '망',
#    '작',
#    '그냥',
#    '게임',
#    '즐기',
#    '셔'],
#   '0'),
#  (['그냥', '레전드', '다', '레전드'], '1'),
#  (['평론가',
#    '명치',
#    '겁나',
#    '때리',
#    '고',
#    '싶',
#    '다',
#    '정말',
#    '영화',
#    '재미없',
#    '거',
#    '라',
#    '생각',
#    '했',
#    '는데',
#    '재미',
#    '도',
#    '있',
#    '고',
#    '내',
#    '인생',
#    '도움',
#    '가장',
#    '큰',
#    '영화',
#    '입니다',
#    '본인',
#    '깨달',
#    '고',
#    '싶',
#    '으면',
#    '꼭',
#    '보',
#    '세요',
#    '인생',
#    '바꿔',
#    '줄',
#    '겁니다'],
#   '1'),
#  (['키아누', '리브스', '최고', '액션', '영화'], '1'),
#  (['소재',
#    '아름다운',
#    '영화',
#    '아쉬운',
#    '부분',
#    '있',
#    '는',
#    '이유',
#    '는',
#    '영화',
#    '는',
#    '영화',
#    '스러운',
#    '극',
#    '적',
#    '로맨스',
#    '보단',
#    '더',
#    '사실',
#    '적',
#    '한',
#    '남자',
#    '마음',
#    '시선',
#    '말',
#    '고',
#    '싶',
#    '었',
#    '기',
#    '때문',
#    '아닐까'],
#   '1'),
#  (['영화',
#    '평론가',
#    '는',
#    '좋',
#    '았',
#    '다',
#    '한번',
#    '보',
#    '고',
#    '마',
#    '는',
#    '영화',
#    '아닌',
#    '울림',
#    '있',
#    '는',
#    '영화'],
#   '1'),
#  (['역시', '효', '느', '역시', '재밌', '다', '재탕', '중'], '1'),
#  (['대강'], '1'),
#  (['간첩', '색', '휘', '애쓴다', '밥', '은', '먹', '고', '다니', '냐'], '0'),
#  (['검증', '된', '애', '출현', '시켜라', '이탈리아', '특집', '장난', '냐'], '0'),
#  (['정말', '짜증', '절', '보', '지', '말', '껄', '욕', '나옴'], '0'),
#  (['슬프', '다'], '1'),
#  (['최악', '환경', '속', '만화', '라도', '만든', '사람', '경의', '보낸다'], '1'),
#  ([], '0'),
#  (['여운', '엄청', '길', '게', '남', '는', '영화', '이이경', '사랑', '게', '는', '영화'], '1'),
#  (['이딴', '게', '한국', '영화', '라니'], '0'),
#  (['짜', '인가', '이게', '뭐', '뭔'], '0'),
#  (['굿', '다라'], '1'),
#  (['짱',
#    '다',
#    '자식',
#    '키우',
#    '며',
#    '살아온',
#    '엄마',
#    '아들',
#    '힘들',
#    '게',
#    '살아오',
#    '면서',
#    '서로',
#    '예민',
#    '해',
#    '지',
#    '고',
#    '날카로워',
#    '질',
#    '도',
#    '잇',
#    '엇',
#    '가족',
#    '아빠',
#    '라는',
#    '사람',
#    '도',
#    '생각',
#    '보다',
#    '최악',
#    '고',
#    '여자',
#    '는',
#    '확실히',
#    '요구',
#    '면',
#    '도와',
#    '준다는',
#    '말',
#    '왠지',
#    '짠하',
#    '게',
#    '닿',
#    '는다',
#    '괜히',
#    '끙끙거리',
#    '지',
#    '말',
#    '단순',
#    '한',
#    '생각',
#    '든다'],
#   '1'),
#  (['도', '별로', '고', '전개', '도', '별로', '고', '연기', '도', '별로', '고', '재미없', '다'],
#   '0'),
#  (['번지수', '잃', '고', '갈팡질팡'], '0'),
#  ([], '1'),
#  (['너무', '사랑', '스럽', '고', '감동', '적', '인', '영화', '정말', '좋', '어요'], '1'),
#  (['최고', '영화'], '1'),
#  (['전',
#    '영활',
#    '다시',
#    '보',
#    '니',
#    '공효진',
#    '코',
#    '평수',
#    '줄이',
#    '고',
#    '콧대',
#    '높였',
#    '완전',
#    '못생겼',
#    '호',
#    '권상우',
#    '는',
#    '화산고',
#    '왼쪽',
#    '팔자',
#    '심하',
#    '더니',
#    '지금',
#    '사라지',
#    '고',
#    '더',
#    '잘생겨',
#    '졌',
#    '고',
#    '장혁',
#    '은',
#    '멋지',
#    '게',
#    '늙',
#    '었',
#    '다시',
#    '보',
#    '니',
#    '웃겨'],
#   '1'),
#  (['말랑말랑'], '0'),
#  (['공부', '열심히', '합시다', '공부', '안', '면', '저런', '인생', '삽니다'], '1'),
#  (['그냥', '최고', '다'], '1'),
#  (['전쟁',
#    '이후',
#    '아픔',
#    '잘',
#    '그린',
#    '영화',
#    '마지막',
#    '장면',
#    '압권',
#    '유대',
#    '인',
#    '줄',
#    '알',
#    '더럽',
#    '게',
#    '도움',
#    '필요',
#    '니',
#    '동행',
#    '했',
#    '던',
#    '토마스',
#    '더러운',
#    '유태인',
#    '라고',
#    '말',
#    '한',
#    '장면',
#    '유대인',
#    '인척',
#    '한',
#    '사실',
#    '유대',
#    '인',
#    '가족',
#    '사진',
#    '보',
#    '면서',
#    '미묘',
#    '한',
#    '감정',
#    '사슴',
#    '인형',
#    '밟',
#    '까',
#    '며',
#    '대변',
#    '한다',
#    '므찐',
#    '영화'],
#   '1'),
#  (['오랜만', '동화', '다운', '동화', '본', '기분', '다'], '1'),
#  (['감사', '합니다', '정말로', '감사', '합니다'], '1'),
#  (['걍', '다', '변태'], '0'),
#  (['샤넬', '인생', '성공', '라', '샤넬', '남자'], '0'),
#  (['영화', '내용', '없', '다'], '0'),
#  (['십수',
#    '세월',
#    '찰나',
#    '순간',
#    '처럼',
#    '찰나',
#    '순간',
#    '영원',
#    '한',
#    '기억',
#    '남기',
#    '는',
#    '상대',
#    '성',
#    '이론',
#    '관하'],
#   '1'),
#  (['니노', '이중인격', '연기', '두근거리', '네요'], '1'),
#  (['보', '다가', '울컥', '핫', '영화', '재미', '도', '있', '고', '먼가', '감동', '적', '임'],
#   '1'),
#  (['열정', '만', '돌진', '고', '싶', '게', '만드', '는', '영화'], '1'),
#  (['연기력', '유혹', '지', '못한다'], '0'),
#  (['난감',
#    '다',
#    '재미',
#    '도',
#    '없',
#    '고',
#    '세상',
#    '깜짝',
#    '놀라',
#    '게',
#    '는',
#    '센세이션',
#    '도',
#    '없',
#    '다'],
#   '0'),
#  (['아무리', '노력', '했어도', '차이나타운', '대놓고', '베낀', '은', '용서', '안', '됨'], '0'),
#  (['신화', '화이팅', '에릭', '화이팅', '힘내', '요'], '1'),
#  (['엔딩', '넘', '슬퍼요'], '1'),
#  (['영화관', '서', '보', '면', '더', '좋', '았', '걸', '어린', '시절', '돌아간', '느낌', '만감'],
#   '1'),
#  (['정말', '최고', '였', '어요', '이민정', '씨', '신하균', '씨', '연기', '너무', '좋', '았', '어요'],
#   '1'),
#  (['안', '되', '는', '재밌', '게', '본', '영화'], '1'),
#  (['교양',
#    '보',
#    '고',
#    '충격',
#    '먹',
#    '은',
#    '영화',
#    '마지막',
#    '너무',
#    '슬펐',
#    '다',
#    '빨갱이',
#    '라',
#    '소리지르',
#    '던',
#    '몬',
#    '초',
#    '갑자기',
#    '단어',
#    '말',
#    '한',
#    '건',
#    '선생',
#    '님',
#    '대한',
#    '그리움',
#    '미안',
#    '함',
#    '슬픔',
#    '었',
#    '까몬',
#    '초',
#    '마지막',
#    '울먹',
#    '인',
#    '거',
#    '같',
#    '기',
#    '도',
#    '고'],
#   '1'),
#  (['잘', '봤'], '1'),
#  (['안', '무서워', '귀신', '애기', '라', '그런', '건지', '그냥', '깜놀', '기', '만', '할', '뿐'],
#   '0'),
#  (['뭐', '자는', '건', '쥐', '모든', '다', '어설프', '고'], '0'),
#  (['배우',
#    '따뜻',
#    '한',
#    '연기',
#    '도',
#    '일상',
#    '힘겨움',
#    '그리',
#    '는',
#    '현실',
#    '감',
#    '도',
#    '다',
#    '좋',
#    '았',
#    '어요'],
#   '1'),
#  (['남자',
#    '배우',
#    '정말',
#    '미스',
#    '캐스팅',
#    '연기력',
#    '안습',
#    '조은숙',
#    '김유미',
#    '연기',
#    '땜',
#    '고',
#    '봤',
#    '다'],
#   '0'),
#  (['차',
#    '세계',
#    '대전',
#    '피',
#    '고',
#    '진',
#    '청춘',
#    '무기',
#    '기술력',
#    '은',
#    '세기',
# ...
#    '모든',
#    '인물',
#    '컴퓨터',
#    '할',
#    '손',
#    '찍',
#    '는데',
#    '키보드',
#    '누르',
#    '지',
#    '도',
#    '않',
#    '고',
#    '컴퓨터',
#    '화면',
#    '은',
#    '똑같',
#    '은',
#    '파트',
#    '만',
#    '무한',
#    '반복',
#    '되',
#    '고',
#    '허접',
#    '해도',
#    '너무',
#    '허접',
#    '배우',
#    '연기',
#    '도',
#    '개떡',
#    '고'],
#   '0'),
#  (['최고', '농촌', '드라마'], '1'),
#  (['독립영화',
#    '실력자',
#    '스타',
#    '리그',
#    '옴니버스',
#    '라는',
#    '피로감',
#    '극복',
#    '되',
#    '는',
#    '수준',
#    '다',
#    '얼음',
#    '강',
#    '은',
#    '단독',
#    '장편',
#    '만들',
#    '었',
#    '어도',
#    '좋',
#    '았',
#    '듯',
#    '주인공',
#    '혹여',
#    '평소',
#    '라면',
#    '도',
#    '공감',
#    '안',
#    '되',
#    '는',
#    '여호와',
#    '증인',
#    '라도',
#    '납득',
#    '될',
#    '정도',
#    '감정',
#    '설득',
#    '는',
#    '솜씨',
#    '탁월',
#    '다'],
#   '1'),
#  (['비',
#    '비',
#    '그러',
#    '는데',
#    '비',
#    '아닙니다',
#    '우주',
#    '아름다움',
#    '미쳐',
#    '버린',
#    '인간',
#    '뿐',
#    '충분히',
#    '가능',
#    '한',
#    '죠'],
#   '1'),
#  (['개', '재미없', '음', '막장', '스토리', '어거지'], '0'),
#  (['뭐', '흠잡', '없', '다', '최고'], '1'),
#  (['좋', '은', '영화'], '1'),
#  (['탁재훈',
#    '나오',
#    '믄',
#    '재밌',
#    '는',
#    '데',
#    '라지',
#    '스토리',
#    '중반',
#    '너무',
#    '쳐',
#    '짐',
#    '약해',
#    '약해',
#    '약해',
#    '지겨워',
#    '뒈지',
#    '는',
#    '줄',
#    '알'],
#   '0'),
#  (['서스펜스', '도', '없', '고', '스릴', '도', '없', '다'], '0'),
#  (['나라', '정서', '하고', '안', '맞', '다'], '0'),
#  (['선가', '많이', '본', '흔한', '스토리'], '0'),
#  (['최고', '드라마'], '1'),
#  (['는', '누군가', '섬머', '였', '다'], '1'),
#  (['힘', '알', '없', '는', '주인공', '맥', '다', '빠진다'], '0'),
#  (['너무너무', '귀여운', '영화'], '1'),
#  (['전형', '적', '인', '일본식', '엽기', '괴짜', '코메디', '특이', '함', '끌리', '는', '건', '왜지'],
#   '0'),
#  (['이걸', '점', '준', '사람', '은', '뭐', '지', '나루토', '극장판', '중', '가장', '쓰래', '기'],
#   '0'),
#  (['정당',
#    '한',
#    '노력',
#    '란',
#    '보상',
#    '받',
#    '게',
#    '마련',
#    '다',
#    '나름',
#    '일정',
#    '성취',
#    '있',
#    '고',
#    '좋',
#    '은',
#    '결실',
#    '거둔',
#    '작품'],
#   '0'),
#  (['아씨', '울', '었', '다'], '1'),
#  (['기적', '은', '이미', '일어났', '다'], '1'),
#  (['보', '기', '좋', '았', '그냥', '그래요'], '0'),
#  (['전', '율', '느꼈', '다'], '1'),
#  (['여기저기',
#    '지저분',
#    '한',
#    '내용',
#    '이기',
#    '적',
#    '인',
#    '사람',
#    '역겨운',
#    '연애',
#    '마지막',
#    '갈수록',
#    '시청',
#    '률',
#    '안',
#    '나오',
#    '니까',
#    '막',
#    '갈겨쓴',
#    '내용'],
#   '0'),
#  (['별로', '완전', '별로', '마지막', '빼', '고', '넘', '유치', '고', '재미없', '고'], '0'),
#  (['세월',
#    '지나',
#    '서',
#    '다시',
#    '보',
#    '니',
#    '뭔가',
#    '먹먹',
#    '함',
#    '다르',
#    '더군요',
#    '공감',
#    '는',
#    '사람',
#    '라면',
#    '가슴',
#    '속',
#    '명작',
#    '남',
#    '듯'],
#   '1'),
#  (['보', '기', '엔', '좋', '을지', '도'], '0'),
#  (['보', '니까', '선정', '성', '세', '같', '음', '액션', '은', '좋', '음'], '1'),
#  (['카타르시스', '느끼', '기에', '충분', '한', '값진', '영화', '였', '다'], '1'),
#  (['여주',
#    '린제이',
#    '로한',
#    '닮',
#    '았',
#    '다',
#    '전체',
#    '적',
#    '인',
#    '분위기',
#    '배경',
#    '은',
#    '좋',
#    '았',
#    '내용',
#    '은',
#    '지루',
#    '했',
#    '다'],
#   '0'),
#  (['솔로', '면', '영화', '보', '지', '마세요'], '0'),
#  (['남',
#    '차안',
#    '전화',
#    '통화',
#    '는',
#    '걸',
#    '분',
#    '가까이',
#    '구경',
#    '고',
#    '있',
#    '으라고',
#    '폰부스',
#    '는',
#    '명작',
#    '라',
#    '생각',
#    '영화',
#    '는',
#    '진짜',
#    '장난'],
#   '0'),
#  (['전형', '적', '인', '저질', '영화'], '0'),
#  (['답', '알', '려고', '지', '마', '라'], '1'),
#  (['재미', '잇', '음', '매우'], '1'),
#  (['진짜', '잘', '만든', '수작'], '1'),
#  (['제발', '찍', '주', '세요', '현기증', '난단', '말', '에요'], '1'),
#  (['너무나',
#    '도',
#    '따뜻',
#    '한',
#    '마음',
#    '따뜻',
#    '해',
#    '지',
#    '는',
#    '한',
#    '번',
#    '쯤',
#    '되돌아보',
#    '게',
#    '만드',
#    '는',
#    '영화'],
#   '1'),
#  (['뭔가', '씩', '부족', '한', '영화', '놀래', '킬', '려면', '확', '놀래키', '던지', '어정쩡', '한'],
#   '0'),
#  (['이거',
#    '소재',
#    '는',
#    '좋',
#    '은데',
#    '내용',
#    '전개',
#    '개판',
#    '사람',
#    '수',
#    '도',
#    '많',
#    '고',
#    '총',
#    '도',
#    '있',
#    '는데',
#    '그걸',
#    '지',
#    '끼리',
#    '서로',
#    '다',
#    '흩어져서',
#    '일방',
#    '적',
#    '밀리',
#    '거기',
#    '다',
#    '식인종',
#    '라면서',
#    '표현',
#    '비',
#    '해',
#    '놓',
#    '으면',
#    '어쩌',
#    '잔',
#    '거',
#    '식인',
#    '인해',
#    '인성',
#    '말살',
#    '되',
#    '고',
#    '짐승',
#    '화',
#    '되',
#    '었',
#    '다는',
#    '표현',
#    '라도',
#    '있',
#    '던가'],
#   '0'),
#  (['포스터',
#    '만',
#    '그럴싸하',
#    '다',
#    '구역',
#    '라는',
#    '이름',
#    '만',
#    '가져다',
#    '쓴',
#    '영화',
#    '완전',
#    '졸작',
#    '다',
#    '액션',
#    '신도',
#    '개',
#    '허술',
#    '고',
#    '스토리',
#    '도',
#    '다'],
#   '0'),
#  (['대체', '재미없', '다는', '거', '지난', '존나', '재밌', '던데'], '1'),
#  (['늑대',
#    '여정',
#    '너무',
#    '낭만',
#    '적',
#    '었',
#    '던',
#    '애니',
#    '스토리',
#    '도',
#    '좋',
#    '음악',
#    '은',
#    '일본',
#    '애니',
#    '중',
#    '탑',
#    '뛰어나',
#    '다'],
#   '1'),
#  (['미국', '흑인', '민권', '운동사', '완벽', '게', '요약', '했', '다'], '1'),
#  (['뛰어내리', '지', '않', '았', '다면', '되', '었', '을까'], '1'),
#  (['점대',
#    '는',
#    '나와야지',
#    '그냥',
#    '단순',
#    '한',
#    '액션',
#    '공포물',
#    '아닌데',
#    '도',
#    '긴장감',
#    '공포감',
#    '연출',
#    '쩔',
#    '고',
#    '음악',
#    '도',
#    '좋',
#    '고',
#    '지나',
#    '도',
#    '기억나',
#    '는',
#    '인상',
#    '적',
#    '인',
#    '비',
#    '물',
#    '인데',
#    '평점',
#    '너무',
#    '짜',
#    '서',
#    '줌'],
#   '1'),
#  (['아역', '연기', '는', '좋', '았', '으나', '내용', '은', '쓰레기'], '0'),
#  (['진짜',
#    '재미없',
#    '다',
#    '극장',
#    '볼',
#    '거',
#    '없',
#    '어서',
#    '걍',
#    '스릴러',
#    '라길래',
#    '봤',
#    '는데',
#    '웃음',
#    '밖에',
#    '안',
#    '나온다',
#    '혹시나',
#    '해서라도',
#    '절대',
#    '보',
#    '지',
#    '마',
#    '라',
#    '진짜',
#    '제발'],
#   '0'),
#  (['평점', '은', '믿', '지', '마', '셈', '재밌', '음'], '1'),
#  (['이거', '좋', '다는', '놈', '은', '뭐', '는'], '0'),
#  (['이게', '영화', '냐', '도', '영화', '냐', '쓰', '래', '기'], '0'),
#  (['믿', '으려는'], '0'),
#  (['너무', '구식', '웃길려고', '함', '보', '는', '내내', '지겨움'], '0'),
#  (['거', '좋', '는', '사람', '정신', '세계', '궁금', '다'], '0'),
#  (['연예계',
#    '현실',
#    '알리',
#    '고자',
#    '는',
#    '마음',
#    '은',
#    '알',
#    '겠',
#    '영화',
#    '재미',
#    '는',
#    '없',
#    '었',
#    '다',
#    '지루',
#    '해',
#    '죽',
#    '뻔',
#    '했',
#    '음'],
#   '0'),
#  (['아주', '재미있', '고', '책', '봐도', '정말', '재미있', '다'], '1'),
#  (['끝내', '주', '게', '재밌', '다'], '1'),
#  (['유투',
#    '브',
#    '동영상',
#    '돈',
#    '내',
#    '고',
#    '보',
#    '는',
#    '게',
#    '낫',
#    '다는',
#    '생각',
#    '게',
#    '한',
#    '영화'],
#   '0'),
#  (['아쉬운',
#    '점',
#    '도',
#    '있',
#    '스토리',
#    '맞',
#    '는',
#    '분위기',
#    '배경',
#    '지하철',
#    '기관사',
#    '삶',
#    '잘',
#    '묘사'],
#   '1'),
#  (['스타워즈',
#    '편',
#    '맞아떨어지',
#    '도록',
#    '잘',
#    '만든',
#    '영화',
#    '최고',
#    '에피소드',
#    '다스',
#    '베이더',
#    '탄생',
#    '루크',
#    '레이어',
#    '운명',
#    '알',
#    '수',
#    '있',
#    '는',
#    '레전드'],
#   '1'),
#  (['소희', '귀엽', '다', '귀엽', '다', '졸', '귀'], '1'),
#  (['소문난', '잔치', '호화', '캐스팅', '먹', '건', '없', '다'], '0'),
#  (['주성치', '영화', '최고', '졸작'], '0'),
#  (['우우', '웃'], '1'),
#  (['딱히', '흠잡', '도', '두근거릴', '도', '없', '는', '교과서', '적', '플레이'], '0'),
#  (['영화', '중심', '은', '역시', '스토리', '인', '반전', '반전', '너무', '재미있', '다'], '1'),
#  (['라', '아닌가'], '1'),
#  (['재미있', '었', '다', '연기', '발', '는', '삼류', '배우', '얼굴', '보', '면서'], '0'),
#  (['재밌', '군'], '1'),
#  (['도', '재밌', '는데'], '1'),
#  (['점',
#    '도',
#    '아깝',
#    '다',
#    '평',
#    '쓰',
#    '는',
#    '도',
#    '귀찮',
#    '다',
#    '보',
#    '는',
#    '내내',
#    '글',
#    '거려서',
#    '손발',
#    '사라지',
#    '는',
#    '줄',
#    '알',
#    '았',
#    '다'],
#   '0'),
#  (['기대',
#    '안',
#    '고',
#    '봤',
#    '는데',
#    '영화',
#    '보',
#    '는',
#    '내내',
#    '몰입',
#    '해서',
#    '재미있',
#    '게',
#    '봤',
#    '어요'],
#   '1'),
#  (['유쾌',
#    '함',
#    '스릴러',
#    '적',
#    '인',
#    '요소',
#    '잘',
#    '어울려',
#    '진',
#    '명작',
#    '후속작',
#    '보다',
#    '매력',
#    '있',
#    '음',
#    '두',
#    '고',
#    '두',
#    '고',
#    '간직',
#    '해',
#    '두',
#    '면서',
#    '꺼내',
#    '보',
#    '고',
#    '싶',
#    '은',
#    '영화'],
#   '1'),
#  (['좋', '괜찮', '고'], '1'),
#  (['명작',
#    '너무',
#    '좋',
#    '았',
#    '던',
#    '드라마',
#    '스토리',
#    '캐스팅',
#    '연기',
#    '음악',
#    '연출',
#    '완벽',
#    '했',
#    '던'],
#   '1'),
#  (['괜찮',
#    '은',
#    '영화',
#    '영화',
#    '도',
#    '괜찮',
#    '았',
#    '나영언',
#    '니',
#    '완전',
#    '머',
#    '싯',
#    '고',
#    '예뻤',
#    '음'],
#   '1'),
#  (['재미있',
#    '다',
#    '고래',
#    '마리',
#    '국가',
#    '적',
#    '호들갑',
#    '떠',
#    '는',
#    '게',
#    '오버',
#    '스럽',
#    '겠',
#    '그런',
#    '모습',
#    '는',
#    '도와',
#    '며',
#    '살',
#    '는',
#    '지구',
#    '생명',
#    '란',
#    '메세지',
#    '는',
#    '참으로',
#    '감동',
#    '적',
#    '다'],
#   '1'),
#  (['지금',
#    '첨',
#    '봤',
#    '는데',
#    '회',
#    '만',
#    '볼까',
#    '고',
#    '봤',
#    '다가',
#    '주말',
#    '밤새',
#    '완주',
#    '였',
#    '다',
#    '여운',
#    '많이',
#    '남',
#    '는',
#    '드라마'],
#   '1'),
#  (['애니메이션',
#    '뮬란',
#    '아쉽',
#    '다',
#    '전쟁',
#    '씬',
#    '도',
#    '그렇',
#    '고',
#    '연기',
#    '도',
#    '그렇',
#    '고',
#    '이야기',
#    '도',
#    '그렇',
#    '고'],
#   '0'),
#  (['기대', '않', '고', '봣는데', '진짜', '내용', '도', '좋', '고', '재미', '도', '있', '네요'],
#   '1'),
#  (['좋', '았', '다'], '1'),
#  (['슬픈', '맑음', '파문', '주목', '라'], '1'),
#  (['김윤진', '좋', '니깐'], '1'),
#  (['재밌', '따'], '1'),
#  (['무리수', '되', '버린', '코미디', '기획', '상품'], '0'),
#  (['홀로', '집', '더불', '최고', '영화'], '1'),
#  (['는', '떠올랐', '다', '옛날', '국산', '애니', '아마겟돈', '악몽'], '0'),
#  (['완전', '역겨운', '쓰레기', '영화', '다', '기술', '적', '수준', '떠나', '각본', '무', '개념'],
#   '0'),
#  (['고결', '한', '신사', '께서', '짓', '셧', '을까'], '1'),
#  (['캬', '개', '안음'], '1'),
#  (['보', '는', '내내', '너무너무', '재미있', '었', '음'], '1'),
#  (['김소현', '팬', '됬', '너무', '재밌', '음'], '1'),
#  (['삐', '에로', '흑인', '남자', '싸웠', '재미있', '었', '다', '웃겨'], '1'),
#  (['유럽',
#    '영화',
#    '정부',
#    '많이',
#    '들어와',
#    '즐겁',
#    '긴',
#    '내용',
#    '이리',
#    '진부',
#    '한',
#    '걸까',
#    '유럽',
#    '영화',
#    '욕되',
#    '게',
#    '고',
#    '있',
#    '단',
#    '소리',
#    '다'],
#   '0'),
#  (['왠만', '한', '허접', '영화', '도', '재미있', '게', '보', '는데', '이건', '도', '넘어섰', '다'],
#   '0'),
#  (['도', '삶', '죽음', '대해', '왈가왈부', '할', '순', '없', '다'], '1'),
#  (['굿', '굿', '굿', '해라', '해라', '제발'], '1'),
#  (['주', '님', '께서', '부르', '셔서', '있', '나이다'], '1'),
#  (['미성년자',
#    '돈',
#    '많',
#    '은',
#    '아저씨',
#    '순결',
#    '바치',
#    '고',
#    '데인',
#    '후',
#    '정신',
#    '차리',
#    '고',
#    '공부',
#    '해거',
#    '명문대가',
#    '는',
#    '진부',
#    '한',
#    '결말'],
#   '0'),
#  (['정말', '재밌', '게', '봤', '고', '빈센트', '도', '꼬마', '도', '연기', '너무', '잘', '네요'],
#   '1'),
#  (['솔직히', '원작', '보다', '낫', '다', '원작', '인간', '말', '도', '못하', '게', '설정', '해놨'],
#   '1'),
#  (['말', '필요', '없', '음', '진심', '개', '재밌', '다'], '1'),
#  (['보', '니까', '양반', '다', '세포', '소녀', '감독'], '0'),
#  (['굿', '잡', '친구', '랑', '보', '고', '싶', '네요'], '1'),
#  (['재미', '진짜', '근데', '새끼', '관', '종', '인가'], '1'),
#  (['야경', '꾼', '보다', '엉망', '지루함'], '0'),
#  (['예원', '찡', '그만', '울'], '1'),
#  (['근',
#    '본',
#    '모든',
#    '영화',
#    '통틀',
#    '어서',
#    '최악',
#    '영화',
#    '남아돌',
#    '봐도',
#    '아까운',
#    '역대',
#    '급',
#    '쓰레기',
#    '영화'],
#   '0'),
#  (['감동',
#    '다',
#    '참고',
#    '영화',
#    '보',
#    '신',
#    '분',
#    '마지막',
#    '엔딩',
#    '부분',
#    '자막',
#    '나오',
#    '는',
#    '부분',
#    '잇',
#    '죠',
#    '이게',
#    '영화',
#    '상',
#    '실화',
#    '라는',
#    '거',
#    '지',
#    '진짜',
#    '레알',
#    '현재',
#    '실제로',
#    '실화',
#    '라는',
#    '말',
#    '에요',
#    '전지현',
#    '피디',
#    '잔',
#    '아요',
#    '다큐',
#    '찍',
#    '는',
#    '거',
#    '다큐',
#    '엔딩',
#    '장면',
#    '지',
#    '진짜',
#    '실제',
#    '에여',
#    '쨋',
#    '든'],
#   '1'),
#  (['달기',
#    '지미',
#    '니어',
#    '쳐',
#    '티',
#    '팍팍',
#    '던',
#    '데우',
#    '뢔매',
#    '보',
#    '는',
#    '줄',
#    '알',
#    '았',
#    '다',
#    '특수',
#    '효과',
#    '감독',
#    '심형래'],
#   '0'),
#  (['재미', '드럽', '게', '없', '다'], '0'),
#  (['세르게이', '작', '은', '고추', '매운맛', '보여', '주', '마'], '0'),
#  (['정여립',
#    '정철',
#    '기축옥사',
#    '스토리',
#    '탄탄',
#    '해서',
#    '좋',
#    '배우',
#    '도',
#    '연기',
#    '잘',
#    '고',
#    '남녀',
#    '주인공',
#    '케미',
#    '도',
#    '좋',
#    '고',
#    '챙겨',
#    '볼',
#    '수',
#    '밖',
#    '없',
#    '는',
#    '드라마'],
#   '1'),
#  (['개', '영화', '네요', '내용', '도', '없', '고', '그냥', '심심', '해서', '만든', '영화'], '0'),
#  (['두',
#    '개',
#    '는',
#    '줄려고',
#    '했',
#    '는데',
#    '알',
#    '바',
#    '많',
#    '아서',
#    '아후',
#    '볼',
#    '거',
#    '없',
#    '어서',
#    '채널',
#    '돌려도',
#    '다시',
#    '데',
#    '돌리',
#    '게',
#    '만드',
#    '는구나'],
#   '0'),
#  (['점', '은', '줄', '수', '없', '나요'], '0'),
#  (['영화사', '남', '작품', '실험', '영화', '완성', '본'], '1'),
#  (['자식', '그렇게', '때리', '냐'], '0'),
#  (['이게', '대체', '내용'], '0'),
#  (['옛다',
#    '점',
#    '이나',
#    '처먹',
#    '랔',
#    '이게',
#    '점급',
#    '건',
#    '점',
#    '짜리',
#    '내용',
#    '도',
#    '결말',
#    '도',
#    '살',
#    '다',
#    '살',
#    '다',
#    '뭐',
#    '이딴'],
#   '0'),
#  (['감동', '적', '였', '고', '좋', '았'], '1'),
#  (['초반',
#    '개',
#    '재미없',
#    '었',
#    '는데',
#    '볼수록',
#    '점점',
#    '재밌',
#    '짐',
#    '외계인',
#    '내',
#    '알',
#    '던',
#    '에일리언',
#    '나오',
#    '던',
#    '외계인'],
#   '1'),
#  (['쇼핑백', '잊혀', '지', '지', '않', '는다'], '0'),
#  (['의도', '는', '좋', '너무', '몰입', '안', '되', '는', '걸', '어떡', '해'], '0'),
#  (['유치', '가볍', '게', '볼', '만', '함'], '0'),
#  (['화려',
#    '한',
#    '색채',
#    '때문',
#    '눈',
#    '아프',
#    '나름',
#    '대로',
#    '화려',
#    '연예계',
#    '여자',
#    '욕망',
#    '대해',
#    '표현',
#    '해냈',
#    '던',
#    '거',
#    '같',
#    '다',
#    '보',
#    '는',
#    '내내',
#    '진짜',
#    '리리',
#    '코',
#    '심정',
#    '가진',
#    '연',
#    '옌',
#    '도',
#    '있',
#    '거',
#    '같',
#    '고',
#    '한',
#    '번',
#    '도',
#    '보',
#    '지',
#    '못하',
#    '고',
#    '알',
#    '지',
#    '못하',
#    '는',
#    '사람',
#    '날',
#    '사랑',
#    '냐',
#    '그런',
#    '대사',
#    '나왔',
#    '소름',
#    '돋',
#    '더라',
#    '연예인',
#    '은',
#    '많',
#    '은',
#    '사랑',
#    '받',
#    '으면서',
#    '도',
#    '허전',
#    '할',
#    '듯'],
#   '1'),
#  (['본지',
#    '수이',
#    '지나',
#    '도',
#    '아직',
#    '도',
#    '생생',
#    '함',
#    '고양이',
#    '귀신',
#    '복수',
#    '진짜',
#    '무서웠',
#    '지'],
#   '1'),
#  (['영상',
#    '대학교',
#    '졸업',
#    '작품',
#    '같',
#    '아서',
#    '그렇',
#    '지',
#    '꽤',
#    '많',
#    '은',
#    '걸',
#    '담',
#    '놓',
#    '은',
#    '영화',
#    '임',
#    '는',
#    '분명',
#    '다'],
#   '1'),
#  (['최강', '전차', '부대'], '0'),
#  ([], '0'),
#  (['진짜',
#    '어이없',
#    '는',
#    '소재',
#    '라고',
#    '생각',
#    '며',
#    '보',
#    '는데',
#    '개',
#    '웃겨',
#    '남자',
#    '로서',
#    '는',
#    '솔직히',
#    '은',
#    '부러울',
#    '수',
#    '도',
#    '있',
#    '는'],
#   '1'),
#  (['전기세', '아까웠', '다'], '0'),
#  (['초등',
#    '학교',
#    '선생',
#    '님',
#    '보여',
#    '주',
#    '신',
#    '영화',
#    '흘러서',
#    '기억나',
#    '는',
#    '건',
#    '에이즈',
#    '걸렸',
#    '던',
#    '남자',
#    '운동화',
#    '였',
#    '고',
#    '봤',
#    '던',
#    '영화',
#    '뭐였을까',
#    '궁금',
#    '했었',
#    '는데',
#    '영화',
#    '굿바이',
#    '마이',
#    '프렌드',
#    '였',
#    '다',
#    '전',
#    '이나',
#    '후',
#    '명작',
#    '은',
#    '흘러도',
#    '명작',
#    '다'],
#   '1'),
#  (['넘', '재밌', '었', '어요'], '1'),
#  (['설리', '생', '인데', '도', '영화', '나오', '져'], '1'),
#  (['샷', '연결', '아닌', '충돌', '만큼', '이나', '거룩', '한', '제목', '인상', '적', '구려'], '1'),
#  (['재미없', '음'], '0'),
#  (['오오',
#    '난',
#    '여태',
#    '맷데이먼',
#    '최고',
#    '영화',
#    '는',
#    '본',
#    '얼티메이텀',
#    '라이언',
#    '일병',
#    '구하',
#    '기',
#    '뿐',
#    '인',
#    '줄',
#    '알',
#    '았',
#    '음',
#    '굿',
#    '윌',
#    '헌팅',
#    '도',
#    '쩐',
#    '당'],
#   '1'),
#  (['이야기', '자체', '흥미', '끌', '지', '못하', '는군'], '0'),
#  (['날', '로그인', '게', '만들', '다니', '청춘', '영원', '라'], '1'),
#  (['현정', '언니', '짱', '죠', '완전', '잼', '잇', '어요'], '1'),
#  (['영상미',
#    '예쁘',
#    '고',
#    '좋',
#    '러닝',
#    '타임',
#    '넘',
#    '는데',
#    '초반',
#    '분',
#    '줄거리',
#    '다',
#    '나갔',
#    '고',
#    '엄청',
#    '지루',
#    '한',
#    '화보',
#    '집',
#    '보',
#    '는',
#    '기분',
#    '일본',
#    '영화',
#    '특유',
#    '이해',
#    '못',
#    '할',
#    '희한',
#    '함',
#    '있',
#    '음'],
#   '0'),
#  (['스토리',
#    '연결',
#    '전혀',
#    '안',
#    '되',
#    '고',
#    '편집',
#    '해서',
#    '끼워',
#    '맞춘',
#    '드라마',
#    '말아먹',
#    '은',
#    '작품'],
#   '0'),
#  (['여자', '주인공', '예뻐서', '끝', '봤', '다'], '0'),
#  (['지구', '지켜라', '혹', '작품', '보', '고', '만든', '건', '아닌지'], '1'),
#  (['저렇게', '힘들', '게', '영화', '만드', '는데', '한국', '영화', '는', '다', '쓰레기', '냐'], '0'),
#  (['케',
#    '릭터',
#    '살',
#    '있',
#    '었',
#    '으며',
#    '미장센',
#    '훌륭',
#    '했',
#    '다',
#    '이야기',
#    '는',
#    '몰입',
#    '도',
#    '있',
#    '었',
#    '고',
#    '불',
#    '필요',
#    '한',
#    '샷',
#    '은',
#    '존재',
#    '지',
#    '않',
#    '았',
#    '다',
#    '노인',
#    '위한',
#    '나라',
#    '는',
#    '없',
#    '다',
#    '먼저',
#    '봤',
#    '코',
#    '엔',
#    '감독',
#    '매력',
#    '적',
#    '인',
#    '영화',
#    '만드',
#    '는',
#    '멋있',
#    '는',
#    '사람'],
#   '1'),
#  (['마지막', '황당', '했', '좋', '은', '영화'], '1'),
#  (['우연히',
#    '돌려',
#    '보',
#    '다가',
#    '사로잡혔',
#    '다',
#    '최근',
#    '간',
#    '본',
#    '코미디',
#    '영화',
#    '중',
#    '최고'],
#   '1'),
#  (['연', '기', '굿', '화이팅', '누나'], '1'),
#  (['마이클베이',
#    '최',
#    '근작',
#    '볼',
#    '마다',
#    '느낀다',
#    '블록버스터',
#    '액션',
#    '장르',
#    '라도',
#    '탄탄',
#    '한',
#    '시나리오',
#    '는',
#    '영화',
#    '필수',
#    '라는',
#    '기대',
#    '던',
#    '메간폭스',
#    '는',
#    '늙',
#    '었',
#    '다'],
#   '0'),
#  (['점', '은', '없', '점', '은', '너무', '후하'], '0'),
#  (['미', '달이', '는', '연예계', '바라보', '는', '태도', '고쳐야', '한다'], '0'),
#  (['파괴', '된', '관객'], '0'),
#  (['알콜', '중독자', '덕', '평점', '낮', '은가'], '1'),
#  (['중견',
#    '배우',
#    '만들',
#    '놓',
#    '은',
#    '긴장감',
#    '나름',
#    '긴장감',
#    '있',
#    '게',
#    '싸워',
#    '보',
#    '려',
#    '했',
#    '던',
#    '도술',
#    '헛웃음',
#    '나온다'],
#   '0'),
#  (['남자',
#    '주인공',
#    '늑대',
#    '인간',
#    '변하',
#    '고',
#    '끝나',
#    '네유',
#    '평점',
#    '보',
#    '고',
#    '안',
#    '볼까',
#    '다가',
#    '봤',
#    '는디',
#    '재밌',
#    '네유',
#    '보',
#    '다',
#    '실물',
#    '특수',
#    '효과',
#    '더',
#    '보',
#    '는',
#    '재미',
#    '있',
#    '어유',
#    '웃기',
#    '기',
#    '네유',
#    '근디',
#    '제목',
#    '번역',
#    '은',
#    '바보',
#    '한',
#    '거',
#    '그냥',
#    '늑대',
#    '인간',
#    '잖여'],
#   '1'),
#  ...]

# %%
with open("C:/Users/5CG7092POZ/train_data.json", "r", encoding="utf-8") as f:
    train_data = json.load(f)
    
with open("C:/Users/5CG7092POZ/test_data.json", "r", encoding="utf-8") as f:
    test_data = json.load(f)

# %%
tot_tkns = [word for line in train_data for word in line[0]]

text = nltk.Text(tot_tkns, name='NMSC')

text.vocab().most_common(20)
# Out:
# [('영화', 57601),
#  ('점', 7794),
#  ('거', 7627),
#  ('수', 7489),
#  ('연기', 6826),
#  ('최고', 6575),
#  ('평점', 6277),
#  ('스토리', 5415),
#  ('말', 5213),
#  ('드라마', 5184),
#  ('생각', 5167),
#  ('내', 5054),
#  ('사람', 5037),
#  ('게', 5009),
#  ('듯', 4991),
#  ('감동', 4858),
#  ('배우', 4424),
#  ('내용', 4243),
#  ('감독', 4187),
#  ('재미', 4112)]

# %%
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    mpl.rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = mpl.font_manager.FontProperties(fname=path).get_name()
    mpl.rc('font', family=font_name)

plt.figure(figsize=(16, 10))

text.plot(50)

# %%
train_x = [" ".join(review) for review, _ in train_data]
test_x = [" ".join(review) for review, _ in test_data]
train_y = [label for _, label in train_data]
test_y = [label for _, label in test_data]

train_x = train_x[:50000]
train_y = train_y[:50000]
test_x = test_x[:25000]
test_y = test_y[:25000]

# %%
model1 = Pipeline([("vect", CountVectorizer()), ("model", SGDClassifier(loss="perceptron", penalty="l2", alpha=1e-4, random_state=42, max_iter=100))])

model2 = Pipeline([("vect", CountVectorizer()), ("model", SVC(kernel="linear"))])

model3 = Pipeline([("vect", CountVectorizer()), ("model", SVC(kernel="poly", degree=8))])

model4 = Pipeline([("vect", CountVectorizer()), ("model", SVC(kernel="rbf"))])

model5 = Pipeline([("vect", CountVectorizer()), ("model", SVC(kernel="sigmoid"))])

model6 = Pipeline([("vect", CountVectorizer()), ("model", MultinomialNB())])

model = model2
# Out:
# Wall time: 999 µs

# %%
# %%time
model.fit(train_x, train_y)

train_pred = model.predict(train_x)
train_acc = np.mean(train_pred == train_y)

test_pred = model.predict(test_x)
test_acc = np.mean(test_pred == test_y)

print("train_acc : %.2f" % train_acc)
print("Test_acc : %.2f" % test_acc)
