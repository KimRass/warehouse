# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#정상-데이터를-구할-수-있는-경우" data-toc-modified-id="정상-데이터를-구할-수-있는-경우-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>정상 데이터를 구할 수 있는 경우</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Modeling</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
import tensorflow as tf
from tensorflow.keras import Input, Model, Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Layer, Dense, Flatten, Dropout, Concatenate, Add, Dot, Multiply, Reshape, Activation, BatchNormalization, LayerNormalization, SimpleRNNCell, RNN, SimpleRNN, LSTM, Embedding, Bidirectional, TimeDistributed, Conv1D, Conv1DTranspose, Conv2D, MaxPool1D, MaxPool2D, GlobalMaxPool1D, GlobalMaxPool2D, AveragePooling1D, AveragePooling2D, GlobalAveragePooling1D, GlobalAveragePooling2D, ZeroPadding2D, RepeatVector
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.optimizers import SGD, Adagrad, Adam
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
# MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError, BinaryCrossentropy, CategoricalCrossentropy, SparseCategoricalCrossentropy, CosineSimilarity
from tensorflow.keras import losses
# MeanSquaredError, RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError, BinaryCrossentropy, CategoricalCrossentropy, SparseCategoricalCrossentropy, CosineSimilarity
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.activations import linear, sigmoid, relu
from tensorflow.keras.initializers import RandomNormal, glorot_uniform, he_uniform, Constant

plt.style.use("dark_background")

# %%
cpu_load = pd.read_csv("Datasets/CPU/cpu_load.csv", parse_dates=["timestamp"], infer_datetime_format=True, index_col="timestamp")
cpu_load = cpu_load.asfreq("5T")

# %%
cpu_load.plot.line(figsize=(8, 4));

# %% [markdown]
# # 정상 데이터를 구할 수 있는 경우
# - Known anomaly를 제거합니다.

# %%
cpu_load_normal = pd.read_csv("Datasets/CPU/cpu_load_normal.csv", parse_dates=["timestamp"], infer_datetime_format=True, index_col="timestamp")
cpu_load_normal = cpu_load_normal.asfreq("5T")

# %%
cpu_load_normal.plot.line(figsize=(8, 4));

# %%
mean_tr = cpu_load_normal.mean()
std_tr = cpu_load_normal.std()
cpu_load_sc = (cpu_load_normal - mean_tr)/std_tr

# %%
cpu_load_sc.plot.line(figsize=(8, 4));

# %%
window_size = 288
def blocked_cv(data, window_size=window_size, h=0):
    X = list()
    for i in range(len(data) - window_size - h + 1):
        X.append(data[i:i + window_size])
    return np.array(X)

X_train = blocked_cv(cpu_load_sc)

# %% [markdown]
# # Modeling

# %%
inputs = Input(shape=(288, 1))

# Encoder
z = Conv1D(filters=32, kernel_size=7, strides=2, padding="same", activation="relu")(inputs)
z = Dropout(rate=0.2)(z)
z = Conv1D(filters=16, kernel_size=7, strides=2, padding="same", activation="relu")(z)
z = Conv1D(filters=8, kernel_size=7, strides=2, padding="same", activation="relu")(z)
z = Conv1D(filters=4, kernel_size=7, strides=2, padding="same", activation="relu")(z)
        
# Decoder
z = Conv1DTranspose(filters=8, kernel_size=7, strides=2, padding="same", activation="relu")(z)
z = Conv1DTranspose(filters=16, kernel_size=7, strides=2, padding="same", activation="relu")(z)
z = Dropout(rate=0.2)(z)
z = Conv1DTranspose(filters=32, kernel_size=7, strides=2, padding="same", activation="relu")(z)
z = Conv1DTranspose(filters=32, kernel_size=7, strides=2, padding="same", activation="relu")(z)
outputs = Conv1DTranspose(filters=1, kernel_size=7, strides=1, padding="same")(z)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer=Adam(learning_rate=0.001), loss="mse", metrics=["mse"])
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 288, 1)]          0
#
#  conv1d_36 (Conv1D)          (None, 144, 32)           256
#
#  dropout_17 (Dropout)        (None, 144, 32)           0
#
#  conv1d_37 (Conv1D)          (None, 72, 16)            3600
#
#  conv1d_38 (Conv1D)          (None, 36, 8)             904
#
#  conv1d_39 (Conv1D)          (None, 18, 4)             228
#
#  conv1d_transpose_40 (Conv1D  (None, 36, 8)            232
#  Transpose)
#
#  conv1d_transpose_41 (Conv1D  (None, 72, 16)           912
#  Transpose)
#
#  dropout_18 (Dropout)        (None, 72, 16)            0
#
#  conv1d_transpose_42 (Conv1D  (None, 144, 32)          3616
#  Transpose)
#
#  conv1d_transpose_43 (Conv1D  (None, 288, 32)          7200
#  Transpose)
#
#  conv1d_transpose_44 (Conv1D  (None, 288, 1)           225
#  Transpose)
#
# =================================================================
# Total params: 17,173
# Trainable params: 17,173
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor="val_mse", mode="auto", verbose=1, patience=8)
model_path = "cpu_load_autoencoder.h5"
mc = ModelCheckpoint(filepath=model_path, monitor="val_mse", mode="auto", verbose=1, save_best_only=True)
hist = model.fit(x=X_train, y=X_train, validation_split=0.2, epochs=50, batch_size=128, shuffle=False, verbose=2, callbacks=[es, mc])
# Out:
# Epoch 1/50
#
# Epoch 1: val_mse improved from inf to 0.02763, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0276 - val_mse: 0.0276 - 4s/epoch - 157ms/step
# Epoch 2/50
#
# Epoch 2: val_mse improved from 0.02763 to 0.02533, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0253 - val_mse: 0.0253 - 4s/epoch - 150ms/step
# Epoch 3/50
#
# Epoch 3: val_mse improved from 0.02533 to 0.02453, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0245 - val_mse: 0.0245 - 4s/epoch - 163ms/step
# Epoch 4/50
#
# Epoch 4: val_mse did not improve from 0.02453
# 24/24 - 4s - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0249 - val_mse: 0.0249 - 4s/epoch - 148ms/step
# Epoch 5/50
#
# Epoch 5: val_mse did not improve from 0.02453
# 24/24 - 3s - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0259 - val_mse: 0.0259 - 3s/epoch - 141ms/step
# Epoch 6/50
#
# Epoch 6: val_mse improved from 0.02453 to 0.02442, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0244 - val_mse: 0.0244 - 4s/epoch - 166ms/step
# Epoch 7/50
#
# Epoch 7: val_mse did not improve from 0.02442
# 24/24 - 3s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0249 - val_mse: 0.0249 - 3s/epoch - 134ms/step
# Epoch 8/50
#
# Epoch 8: val_mse did not improve from 0.02442
# 24/24 - 3s - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0261 - val_mse: 0.0261 - 3s/epoch - 145ms/step
# Epoch 9/50
#
# Epoch 9: val_mse did not improve from 0.02442
# 24/24 - 4s - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0246 - val_mse: 0.0246 - 4s/epoch - 157ms/step
# Epoch 10/50
#
# Epoch 10: val_mse improved from 0.02442 to 0.02348, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0235 - val_mse: 0.0235 - 4s/epoch - 147ms/step
# Epoch 11/50
#
# Epoch 11: val_mse improved from 0.02348 to 0.02323, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0232 - val_mse: 0.0232 - 4s/epoch - 162ms/step
# Epoch 12/50
#
# Epoch 12: val_mse did not improve from 0.02323
# 24/24 - 4s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0241 - val_mse: 0.0241 - 4s/epoch - 157ms/step
# Epoch 13/50
#
# Epoch 13: val_mse did not improve from 0.02323
# 24/24 - 3s - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0253 - val_mse: 0.0253 - 3s/epoch - 141ms/step
# Epoch 14/50
#
# Epoch 14: val_mse improved from 0.02323 to 0.02275, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0228 - val_mse: 0.0228 - 4s/epoch - 172ms/step
# Epoch 15/50
#
# Epoch 15: val_mse did not improve from 0.02275
# 24/24 - 3s - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0236 - val_mse: 0.0236 - 3s/epoch - 144ms/step
# Epoch 16/50
#
# Epoch 16: val_mse improved from 0.02275 to 0.02243, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0224 - val_mse: 0.0224 - 4s/epoch - 158ms/step
# Epoch 17/50
#
# Epoch 17: val_mse did not improve from 0.02243
# 24/24 - 4s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0225 - val_mse: 0.0225 - 4s/epoch - 167ms/step
# Epoch 18/50
#
# Epoch 18: val_mse improved from 0.02243 to 0.02156, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0216 - val_mse: 0.0216 - 4s/epoch - 155ms/step
# Epoch 19/50
#
# Epoch 19: val_mse did not improve from 0.02156
# 24/24 - 4s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0221 - val_mse: 0.0221 - 4s/epoch - 147ms/step
# Epoch 20/50
#
# Epoch 20: val_mse did not improve from 0.02156
# 24/24 - 4s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0221 - val_mse: 0.0221 - 4s/epoch - 155ms/step
# Epoch 21/50
#
# Epoch 21: val_mse did not improve from 0.02156
# 24/24 - 3s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0221 - val_mse: 0.0221 - 3s/epoch - 132ms/step
# Epoch 22/50
#
# Epoch 22: val_mse improved from 0.02156 to 0.02070, saving model to cpu_load_autoencoder.h5
# 24/24 - 4s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0207 - val_mse: 0.0207 - 4s/epoch - 167ms/step
# Epoch 23/50
#
# Epoch 23: val_mse did not improve from 0.02070
# 24/24 - 3s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0214 - val_mse: 0.0214 - 3s/epoch - 142ms/step
# Epoch 24/50
#
# Epoch 24: val_mse did not improve from 0.02070
# 24/24 - 3s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0218 - val_mse: 0.0218 - 3s/epoch - 140ms/step
# Epoch 25/50
#
# Epoch 25: val_mse did not improve from 0.02070
# 24/24 - 4s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0209 - val_mse: 0.0209 - 4s/epoch - 152ms/step
# Epoch 26/50
#
# Epoch 26: val_mse did not improve from 0.02070
# 24/24 - 3s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0208 - val_mse: 0.0208 - 3s/epoch - 128ms/step
# Epoch 27/50
#
# Epoch 27: val_mse did not improve from 0.02070
# 24/24 - 4s - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0217 - val_mse: 0.0217 - 4s/epoch - 147ms/step
# Epoch 28/50
#
# Epoch 28: val_mse did not improve from 0.02070
# 24/24 - 4s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0222 - val_mse: 0.0222 - 4s/epoch - 149ms/step
# Epoch 29/50
#
# Epoch 29: val_mse did not improve from 0.02070
# 24/24 - 3s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0220 - val_mse: 0.0220 - 3s/epoch - 136ms/step
# Epoch 30/50
#
# Epoch 30: val_mse did not improve from 0.02070
# 24/24 - 4s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0215 - val_mse: 0.0215 - 4s/epoch - 158ms/step
# Epoch 30: early stopping

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 8))
axes.plot(hist.history["loss"][1:], label="loss");
axes.plot(hist.history["val_loss"][1:], label="val_loss");
axes.legend();

# %%
# 학습 데이터를 그대로 복원 -> 복원된 데이터와 학습 데이터를 비교
y_pred = model.predict(X_train)
mae = np.mean(np.abs(y_pred - X_train), axis=1)

plt.hist(mae, bins=50);
plt.xlabel("Train MAE loss");
plt.ylabel("Number of samples");
# Out:
# 118/118 [==============================] - 3s 21ms/step

# %%
# Get reconstruction loss threshold.
# 학습 데이터의 최대 에러의 95% 수준보다 넘어가는건 이상치다.
thr = np.max(mae)*0.95
print(f"Reconstruction Error Threshold: {thr}")
# Out:
# Reconstruction Error Threshold: 0.10743919293251913

# %%
plt.plot(X_train[0]);
plt.plot(y_pred[0]);

# %%
df_test_value = (cpu_load - mean_tr)/std_tr

df_test_value.plot.line(legend=False);

# Create sequences from test values.
x_test = blocked_cv(df_test_value.values)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)
print("Test input shape: ", x_test.shape)

# Get test MAE loss.
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = test_mae_loss > thr # 학습 데이터의 최대 로스보다 큰 로스 값 index
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Test input shape:  (3745, 288, 1)
# 118/118 [==============================] - 3s 22ms/step
# Number of anomaly samples:  484
# Indices of anomaly samples:  (array([ 212,  213,  214,  218,  219,  779,  781,  782,  783,  784,  785,
#         786,  787,  788,  789,  790,  791,  793,  794,  795,  796,  797,
#         798,  799,  800,  801,  802, 1641, 1642, 1645, 1646, 1647, 1648,
#        1649, 1650, 1651, 1652, 1653, 1654, 1655, 1657, 1658, 1659, 1660,
#        1661, 1662, 1663, 1939, 1940, 1941, 1942, 1943, 1945, 1946, 1947,
#        1948, 1949, 1950, 1951, 2506, 2507, 2510, 2511, 2515, 2516, 2517,
#        2518, 2519, 2521, 2522, 2523, 2524, 2525, 2526, 2527, 2528, 2529,
#        2530, 2538, 2539, 2558, 2574, 2701, 2702, 2703, 2704, 2705, 2706,
#        2707, 2708, 2709, 2710, 2711, 2712, 2713, 2714, 2715, 2716, 2717,
#        2718, 2719, 2720, 2721, 2722, 2723, 2724, 2725, 2726, 2727, 2728,
#        2729, 2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738, 2739,
#        2740, 2741, 2742, 2743, 2744, 2745, 2746, 2747, 2748, 2749, 2750,
#        2751, 2752, 2753, 2754, 2755, 2756, 2757, 2758, 2759, 2760, 2761,
#        2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771, 2772,
#        2773, 2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782, 2783,
#        2784, 2785, 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793, 2794,
#        2795, 2796, 2797, 2798, 2799, 2800, 2801, 2802, 2803, 2804, 2805,
#        2806, 2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814, 2815, 2816,
#        2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826, 2827,
#        2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837, 2838,
#        2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848, 2849,
#        2850, 2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859, 2860,
#        2861, 2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870, 2871,
#        2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881, 2882,
#        2883, 2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892, 2893,
#        2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904,
#        2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914, 2915,
#        2916, 2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926,
#        2927, 2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936, 2937,
#        2938, 2939, 2940, 2941, 2942, 2943, 2944, 2945, 2946, 2947, 2948,
#        2949, 2950, 2951, 2952, 2953, 2954, 2955, 2956, 2957, 2958, 2959,
#        2960, 2961, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2969, 2970,
#        2971, 2972, 2973, 2974, 2975, 2976, 2977, 2978, 2979, 2980, 2981,
#        2982, 2983, 2984, 2985, 2986, 2987, 2988, 2989, 2990, 2991, 2992,
#        2993, 2994, 2995, 2996, 2997, 2998, 2999, 3000, 3001, 3002, 3003,
#        3004, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013, 3014,
#        3015, 3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024, 3025,
#        3026, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 3036,
#        3037, 3038, 3039, 3040, 3041, 3042, 3043, 3044, 3045, 3046, 3047,
#        3048, 3049, 3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057, 3058,
#        3059, 3060, 3061, 3062, 3063, 3064, 3065, 3066, 3067, 3068, 3069,
#        3070, 3071, 3072, 3073, 3074, 3075, 3076, 3077, 3078, 3079, 3080,
#        3081, 3082, 3083, 3084, 3085, 3086, 3087, 3088, 3089, 3090, 3091,
#        3092, 3093, 3094, 3095, 3096, 3097, 3098, 3099, 3100, 3101, 3102],
#       dtype=int64),)

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomaly_idxs = list()
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomaly_idxs.append(data_idx)

# %%
anomalies = cpu_load.iloc[anomalous_data_indices]
fig, ax = plt.subplots(figsize=(8, 4))
cpu_load.plot(legend=False, ax=ax);
anomalies.plot(legend=False, ax=ax, color="r");
