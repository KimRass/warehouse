# %%
def solution(board, r, c):
    cur_row = r
    cur_col = c
    cnt = 0
    # while True:
    stack = list()
    for _ in range(20):
        if sum(sum(board, [])) == 0:
            break
            
        if len(stack) == 1:
            tar = stack[0]
            board_sum = sum(board, [])
            idx = board_sum.index(tar)
            tar_row = idx//4
            tar_col = idx%4
            cnt += (int(tar_row != cur_row) + int(tar_col != cur_col)
            cur_row = tar_row
            cur_col = tar_col
        else:
            if board[cur_row][cur_col] != 0:
                print("ENTER")
                stack.append(board[cur_row][cur_col])
                board[cur_row][cur_col] = 0
                cnt += 1
            elif sum(board[cur_row]) != 0:
                for i, tar in enumerate(board[cur_row]):
                    if tar != 0:
                        stack.append(tar)
                        cur_col = i
            elif sum(board[cur_col]) != 0:
                for i, tar in enumerate(board[cur_col]):
                    if tar != 0:
                        stack.append(tar)
                        cur_row = i
            else:
    print(cnt)
    print(board)
    return None

# %%
    # tar = 
#     same_row = board[cur[0]]
#     same_col = [i[cur[1]] for i in board]
#     same_row_nonzero = [i for i in same_row if i != 0]
#     same_col_nonzero = [i for i in same_col if i != 0]
    
#     tar_row = same_row.index(same_row_nonzero[0]) if sum(same_row_nonzero) != 0 else cur[0]
#     tar_col = same_col.index(same_col_nonzero[0]) if sum(same_row_nonzero) == 0 else cur[1]
    
    # input = list()
def solution(board, r, c):
    cur = [r, c]
    cnt = 0
    # while True:
    for _ in range(20):
        if sum(sum(board, [])) == 0:
            break
        else:
            if board[cur[0]][cur[1]] != 0:
                pass
                # input.append("E")
                cnt += 1
            elif board[cur[0]][cur[1] - 1] != 0:
                cnt += 1
                board[cur[0]][cur[1] - 1] = 0
                cur[1] -= 1
            elif board[cur[0]][cur[1] - 2] != 0:
                cnt += 1
                board[cur[0]][cur[1] - 2] = 0
                cur[1] -= 2
            elif board[cur[0] - 1][cur[1]] != 0:
                board[cur[0] - 1][cur[1]] = 0
                cur[0] -= 1
                cnt += 1
            elif board[cur[0] - 2][cur[1]] != 0:
                board[cur[0] - 2][cur[1]] = 0
                cur[0] -= 2
                cnt += 1
            # cnt += 1
    print(cnt)
    print(board)
    return None
