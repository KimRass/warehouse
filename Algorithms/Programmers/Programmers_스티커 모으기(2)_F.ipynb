# %%
def solution(sticker):
#     if len(sticker) <= 3:
#         return max(sticker)
#     elif len(sticker) == 4:
#         return max(sticker[0] + sticker[2], sticker[1] + sticker[3])
    if sum(sticker) == 0:
        return 0
    else:
#         print(sticker)
        return max(sticker[0] + solution(sticker[2:-1] + [0]), sticker[1] + solution(sticker[3:] + [0]))
#     return None

# %%
sticker = [14, 6, 5, 11, 3, 9, 2, 10, 5, 1, 2, 6, 2, 5, 7, 12, 2, 6, 5, 5, 6, 4, 4, 4]*10

solution(sticker)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-48737e9f51da> in <module>
#       1 sticker = [14, 6, 5, 11, 3, 9, 2, 10, 5, 1, 2, 6, 2, 5, 7, 12, 2, 6, 5, 5, 6, 4, 4, 4]*10
#       2
# ----> 3 solution(sticker)
#
# <ipython-input-22-e5fcb26c7b0f> in solution(sticker)
#       8     else:
#       9 #         print(sticker)
# ---> 10         return max(sticker[0] + solution(sticker[2:-1] + [0]), sticker[1] + solution(sticker[3:] + [0]))
#      11 #     return None
#
# <ipython-input-22-e5fcb26c7b0f> in solution(sticker)
#       8     else:
#       9 #         print(sticker)
# ---> 10         return max(sticker[0] + solution(sticker[2:-1] + [0]), sticker[1] + solution(sticker[3:] + [0]))
#      11 #     return None
#
# <ipython-input-22-e5fcb26c7b0f> in solution(sticker)
#       8     else:
#       9 #         print(sticker)
# ...
