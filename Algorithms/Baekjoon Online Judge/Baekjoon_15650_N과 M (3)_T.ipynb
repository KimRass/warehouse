# %% [markdown]
# Written by KimRass
# - Source: https://www.acmicpc.net/problem/15651

# %%
from itertools import product

N, M = list(map(int, input().split()))

string = "range(1, N + 1), "
for i in eval("product(" + (string*M)[:-2] + ")"):
    for j in i:
        print(j, end=" ")
    print()
# Out:
# 5 3
# 1 1 1
# 1 1 2
# 1 1 3
# 1 1 4
# 1 1 5
# 1 2 1
# 1 2 2
# 1 2 3
# 1 2 4
# 1 2 5
# 1 3 1
# 1 3 2
# 1 3 3
# 1 3 4
# 1 3 5
# 1 4 1
# 1 4 2
# 1 4 3
# 1 4 4
# 1 4 5
# 1 5 1
# 1 5 2
# 1 5 3
# 1 5 4
# 1 5 5
# 2 1 1
# 2 1 2
# 2 1 3
# 2 1 4
# 2 1 5
# 2 2 1
# 2 2 2
# 2 2 3
# 2 2 4
# 2 2 5
# 2 3 1
# 2 3 2
# 2 3 3
# 2 3 4
# 2 3 5
# 2 4 1
# 2 4 2
# 2 4 3
# 2 4 4
# 2 4 5
# 2 5 1
# 2 5 2
# 2 5 3
# 2 5 4
# 2 5 5
# 3 1 1
# 3 1 2
# 3 1 3
# 3 1 4
# 3 1 5
# 3 2 1
# 3 2 2
# 3 2 3
# 3 2 4
# 3 2 5
# 3 3 1
# 3 3 2
# 3 3 3
# 3 3 4
# 3 3 5
# 3 4 1
# 3 4 2
# 3 4 3
# 3 4 4
# 3 4 5
# 3 5 1
# 3 5 2
# 3 5 3
# 3 5 4
# 3 5 5
# 4 1 1
# 4 1 2
# 4 1 3
# 4 1 4
# 4 1 5
# 4 2 1
# 4 2 2
# 4 2 3
# 4 2 4
# 4 2 5
# 4 3 1
# 4 3 2
# 4 3 3
# 4 3 4
# 4 3 5
# 4 4 1
# 4 4 2
# 4 4 3
# 4 4 4
# 4 4 5
# 4 5 1
# 4 5 2
# 4 5 3
# 4 5 4
# 4 5 5
# 5 1 1
# 5 1 2
# 5 1 3
# 5 1 4
# 5 1 5
# 5 2 1
# 5 2 2
# 5 2 3
# 5 2 4
# 5 2 5
# 5 3 1
# 5 3 2
# 5 3 3
# 5 3 4
# 5 3 5
# 5 4 1
# 5 4 2
# 5 4 3
# 5 4 4
# 5 4 5
# 5 5 1
# 5 5 2
# 5 5 3
# 5 5 4
# 5 5 5

# %%
N, M = list(map(int, input().split()))

graph = {i:[j for j in range(N, 0, -1)] for i in range(N, 0, -1)}

stack = [(0, i) for i in range(N, 0, -1)]
res = [0 for _ in range(M)]
while stack:
    i, cur_node = stack.pop()
    res[i] = cur_node
    if i == M - 1:
        for j in res:
            print(j, end=" ")
        print()
    for end in graph[cur_node]:
        if i <= M - 2:
            stack.append((i + 1, end))
