# %%
N, M = list(map(int, input().split()))
cards = list(map(int, input().split()))
# Out:
# 10 500
# 93 181 245 214 315 36 185 318 216 295

# %%
cards
# Out:
# [93, 181, 245, 214, 315, 36, 185, 318, 216, 295]
