# %% [markdown]
# - Source: https://www.acmicpc.net/problem/17298

# %%
arr = [3, 5, 2, 7]

# %%
stack = list()
j = 0
for i in arr:
    if i > j:
        stack.append(i)
    j = i

# %%
stack
# Out:
# [3, 5, 7]
