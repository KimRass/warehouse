# %% [markdown]
# Written by KimRass
# - Source: https://www.acmicpc.net/problem/1300
# - 어떻게 접근해야할 지 전혀 감이 잡히지 않아서 기본 아이디어를 슬쩍 봤는데도 불구하고 구현하는 것조차 매우 어려운 문제였다.

# %%
1 2 3 ... 19
2 4 ... 18
3 6 ... 18
4 8 ... 16
5 10 ... 15

# %%
N = int(input())
k = int(input())

# %%
N = 5
K = 15

left = 1
right = N**2
ans = 0
while left <= right:
    mid = (left + right)//2
    
    cnt = 0
    maxim = 0
    for i in range(1, min(mid, N + 1)):
#         print(i, min((a - 1)//i*i//i, N))
        cnt += min((mid - 1)//i*i//i, N)
        if i*min((mid - 1)//i*i//i, N) > maxim:
            maxim = i*min((a - 1)//i*i//i, N)
#     print(cnt, maxim)
    print(left, mid, right, ans, cnt)

    if cnt == K:
        print("cnt == K")
        breaker = False
        while mid >= 1:
            if breaker == True:
                break
            for j in range(N, 1, -1):
                print(mid, j)
                if mid%j == 0:
                    ans = mid
                    breaker = True
                    break
            mid -= 1
            
        ans = maxim
    elif cnt > K:
        right = mid - 1
    else:
        left = mid + 1
        
print(ans)
# Out:
# 1 13 25 0 19
# 1 6 12 0 10
# 7 9 12 0 14
# 10 11 12 0 17
# 10 10 10 0 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# 10 5
# 10 10 10 10 15
# cnt == K
# ...

# %%
arr = [[i*j for j in range(1, N + 1)] for i in range(1, N + 1)]
arr_1d = sorted(sum(arr, []))

arr
# Out:
# [[1, 2, 3, 4, 5],
#  [2, 4, 6, 8, 10],
#  [3, 6, 9, 12, 15],
#  [4, 8, 12, 16, 20],
#  [5, 10, 15, 20, 25]]

# %%
print(arr_1d)
# Out:
# [1, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6, 8, 8, 9, 10, 10, 12, 12, 15, 15, 16, 20, 20, 25]

# %%
N = 4
a = 13
K = 14
답 12
