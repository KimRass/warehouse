# %% [markdown]
# Written by KimRass
# - Source: https://www.acmicpc.net/problem/1786

# %%
s = "abacaba"

# %%
i = 0
j = 1
f = dict()
while j < len(s):
    temp = s[:j + 1]
    print(i, j, temp, temp[:i + 1], temp[-(i + 1):])
    if temp[:i + 1] == temp[-(i + 1):]:
        f[j] = i + 1
    if i == j - 1:
        j += 1
        i = 0
    else:
        i += 1
# Out:
# 0 1 ab a b
# 0 2 aba a a
# 1 2 aba ab ba
# 0 3 abac a c
# 1 3 abac ab ac
# 2 3 abac aba bac
# 0 4 abaca a a
# 1 4 abaca ab ca
# 2 4 abaca aba aca
# 3 4 abaca abac baca
# 0 5 abacab a b
# 1 5 abacab ab ab
# 2 5 abacab aba cab
# 3 5 abacab abac acab
# 4 5 abacab abaca bacab
# 0 6 abacaba a a
# 1 6 abacaba ab ba
# 2 6 abacaba aba aba
# 3 6 abacaba abac caba
# 4 6 abacaba abaca acaba
# 5 6 abacaba abacab bacaba

# %%
f
# Out:
# {2: 1, 4: 1, 5: 2, 6: 3}

# %%
s
# Out:
# 'abacaba'

# %%
s[6]
# Out:
# 'a'

# %%
s[:7]
# Out:
# 'abacaba'

# %%
i = 0
j = 1
f = {0:0}
while j < len(s):
    print(i, j, s[i], s[j])
    if s[i] == s[j]:
        f[j] = i + 1
        i += 1
        j += 1
    elif i == 0:
        f[j] = 0
        j += 1
    else:
        i = f[i - 1]
# Out:
# 0 1 a b
# 0 2 a a
# 1 3 b c
# 0 3 a c
# 0 4 a a
# 1 5 b b
# 2 6 a a

# %%
f
# Out:
# {0: 0, 1: 0, 2: 1, 3: 0, 4: 1, 5: 2, 6: 3}

# %%
i = 0
j = 1
f = dict()
while j < len(s):
    print(s[i], s[j])
    if s[i] == s[j]:
# Out:
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# a b
# ...
